# %%
pip install requests pandas beautifulsoup4 tqdm unicode rapidfuzz
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: unicode in /usr/local/lib/python3.11/dist-packages (2.9)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 22.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.13.0

# %%
import re
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import pandas as pd
from collections import defaultdict

# Sessão persistente para performance
session = requests.Session()

# Armazena as lutas por slug de lutador
lutas_por_lutador = defaultdict(list)

def slugify_name(full_name: str) -> str:
    """
    Converte um nome completo em slug:
    - remove caracteres que não sejam letra, número, espaço ou hífen
    - divide em palavras e junta com hífen
    - transforma em minúsculo
    Ex.: "Márcio de Guerra" → "marcio-de-guerra"
    """
    clean = re.sub(r"[^\w\s-]", "", full_name, flags=re.UNICODE)
    parts = re.split(r"[\s]+", clean.strip())
    return "-".join(parts).lower()

def get_fighters():
    """
    Coleta da página A–Z os hrefs originais (?p=####) de cada lutador,
    garantindo que a URL exista e evitando 404 por slug incorreto.
    """
    url = "https://www.bjjheroes.com/a-z-bjj-fighters-list"
    resp = session.get(url, timeout=10)
    if resp.status_code != 200:
        print("Erro ao acessar a lista de lutadores.")
        return []
    soup = BeautifulSoup(resp.content, 'html.parser')
    fighter_ids = []
    for a in soup.select("td.column-1 a"):
        href = a.get("href")
        if href:
            fighter_ids.append(href)  # ex: "?p=8141"
    return fighter_ids

def scrape_fighter(fighter_id):
    """
    Usa o ID  para acessar o perfil:
    1) extrai o nome real do <h1>
    2) gera um slug amigável via slugify_name()
    3) coleta o histórico de lutas sob esse slug
    Retorna (slug, erro).
    """
    url = f"https://www.bjjheroes.com/bjj-fighters/{fighter_id}"
    try:
        resp = session.get(url, timeout=5)
        if resp.status_code != 200:
            return fighter_id, f"HTTP {resp.status_code}"

        soup = BeautifulSoup(resp.content, 'html.parser')

        # 1) pega nome completo do <h1>
        h1 = soup.find("h1")
        real_name = h1.get_text(strip=True) if h1 else fighter_id
        slug = slugify_name(real_name)

        # 2) localiza o bloco de lutas
        content = soup.find("div", class_="text-content")
        if not content:
            return slug, "sem text-content"
        plug = content.find("div", class_="fighter_info_plug")
        if not plug:
            return slug, "sem fighter_info_plug"
        wrapper = plug.find("div", class_="table-responsive")
        if not wrapper:
            return slug, "sem table-responsive"
        table = wrapper.find("table")
        if not table:
            return slug, "sem <table>"
        tbody = table.find("tbody")
        if not tbody:
            return slug, "sem <tbody>"

        # 3) itera cada linha de luta
        for row in tbody.find_all("tr"):
            cols = row.find_all("td")
            if len(cols) < 8:
                continue
            lutas_por_lutador[slug].append({
                "fighter":     slug,
                "fight_id":    cols[0].get_text(strip=True),
                "opponent":    cols[1].get_text(strip=True),
                "result":      cols[2].get_text(strip=True),
                "method":      cols[3].get_text(strip=True),
                "competition": cols[4].get_text(strip=True),
                "weight":      cols[5].get_text(strip=True),
                "stage":       cols[6].get_text(strip=True),
                "year":        cols[7].get_text(strip=True),
            })

        return slug, None

    except requests.exceptions.RequestException:
        return fighter_id, "erro de rede"

def process_fighters(fighter_ids, max_workers=10):
    """
    Processa em paralelo todos os IDs, exibe progresso e coleta eventuais erros.
    """
    errors = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(scrape_fighter, fid): fid for fid in fighter_ids}
        with tqdm(total=len(futures), desc="Lutadores processados", unit="lutador") as pbar:
            for future in as_completed(futures):
                slug, err = future.result()
                count = len(lutas_por_lutador.get(slug, []))
                pbar.set_postfix_str(f"{slug}: {count} lutas")
                pbar.update(1)
                if err:
                    errors.append(f"{slug} → {err}")

    if errors:
        print("\nErros encontrados:")
        for e in errors:
            print(" •", e)

def salvar_csv(path='historico_lutas.csv'):
    """
    Concatena todas as lutas coletadas em um DataFrame e salva em CSV.
    """
    total = sum(len(v) for v in lutas_por_lutador.values())
    if total == 0:
        print("Nenhuma luta coletada. Verifique os seletores.")
        return
    df = pd.DataFrame([item for sub in lutas_por_lutador.values() for item in sub])
    df.to_csv(path, index=False, encoding='utf-8-sig')
    print(f"✅ {len(df)} lutas salvas em '{path}'.")

if __name__ == "__main__":
    print("📥 Coletando lista de lutadores (IDs)...")
    fighters = get_fighters()
    print(f"🔍 {len(fighters)} perfis encontrados:")
    print(fighters[:20])  # inspecione os primeiros 20 IDs
    process_fighters(fighters, max_workers=10)
    salvar_csv()
# Out:
# 📥 Coletando lista de lutadores (IDs)...
# 🔍 1428 perfis encontrados:
# ['/?p=8141', '/?p=9246', '/?p=8494', '/?p=390', '/?p=3083', '/?p=14157', '/?p=8814', '/?p=8131', '/?p=1133', '/?p=7478', '/?p=13245', '/?p=6339', '/?p=8968', '/?p=9541', '/?p=13498', '/?p=699', '/?p=1116', '/?p=909', '/?p=4328', '/?p=2189']
# Lutadores processados:  79%|███████▊  | 1124/1428 [04:16<01:06,  4.55lutador/s, thaís-ramos: 0 lutas]WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Lutadores processados: 100%|██████████| 1428/1428 [05:23<00:00,  4.41lutador/s, vinicius-garcia: 58 lutas]
# Erros encontrados:
#  • aarae-alexander → sem fighter_info_plug
#  • adam-shahir-kayoom → sem fighter_info_plug
#  • abmar-barbosa → sem fighter_info_plug
#  • admilson-juquinha-brites → sem fighter_info_plug
#  • adriana-martins → sem fighter_info_plug
#  • adriano-martins → sem fighter_info_plug
#  • adriano-silva → sem fighter_info_plug
#  • alan-moraes → sem fighter_info_plug
#  • beto-carmona → sem fighter_info_plug
#  • alberto-crane → sem fighter_info_plug
#  • alex-martins → sem fighter_info_plug
#  • leka-vieira → sem fighter_info_plug
#  • alessandro-capodeferro → sem fighter_info_plug
#  • alexandre-baraúna → sem fighter_info_plug
#  • alexandre-de-souza → sem fighter_info_plug
#  • alexandro-ceconi → sem fighter_info_plug
#  • alexandre-paiva-gigi → sem fighter_info_plug
#  • alexandre-pulga-pimentel → sem fighter_info_plug
#  • alexandre-puga → sem fighter_info_plug
#  • alexandre-baiano-santos → sem fighter_info_plug
#  • alexsandro-leke-machado → sem fighter_info_plug
#  • allan-góes → sem fighter_info_plug
#  • alvaro-barreto → sem fighter_info_plug
#  • alvaro-cabeção-bobadilla → sem fighter_info_plug
#  • amanda-tubby-alequin → sem fighter_info_plug
#  • amal-amjahid → sem fighter_info_plug
#  • amanda-monteiro-canuto → sem fighter_info_plug
#  • amin-touati-camelinho → sem fighter_info_plug
#  • ana-carolina-vieira → sem fighter_info_plug
#  • ana-carolina-schmitt → sem fighter_info_plug
#  • ana-maria-india-checkmat → sem fighter_info_plug
#  • ana-laura-cordeiro → sem fighter_info_plug
#  • anderson-pereira-deton → sem fighter_info_plug
#  • andrea-baggio → sem fighter_info_plug
#  • andré-dedeco-almeida → sem fighter_info_plug
#  • andré-almeida → sem fighter_info_plug
#  • andre-maracaba → sem fighter_info_plug
#  • andre-tim-monteiro → sem fighter_info_plug
#  • andre-pederneiras → sem fighter_info_plug
#  • andre-quiles → sem fighter_info_plug
#  • andre-negão-terêncio → sem fighter_info_plug
#  • andressa-cintra → sem fighter_info_plug
#  • angelica-galvão → sem fighter_info_plug
#  • tony-pacenski → sem fighter_info_plug
#  • aj-scales → sem fighter_info_plug
#  • anthony-perosh → sem fighter_info_plug
#  • antonio-de-melo-brazil-021 → sem fighter_info_plug
#  • antônio-rodrigo-nogueira-minotauro → sem fighter_info_plug
#  • antonio-peinado → sem fighter_info_plug
#  • juninho-crivelari → sem fighter_info_plug
#  • arlisson-kiki-melo → sem fighter_info_plug
#  • armando-wridt → sem fighter_info_plug
#  • augusto-ferrari → sem fighter_info_plug
#  • guto-monteiro → sem fighter_info_plug
#  • beatriz-mesquita → sem fighter_info_plug
#  • ben-baxter → sem fighter_info_plug
#  • bernardo-pitel → sem fighter_info_plug
#  • bianca-andrade → sem fighter_info_plug
#  • brenda-heller → sem fighter_info_plug
#  • brian-beauchamp → sem fighter_info_plug
#  • brian-beaury → sem fighter_info_plug
#  • bruno-alves → sem fighter_info_plug
#  • bruno-amorim → sem fighter_info_plug
#  • bruno-barbosa → sem fighter_info_plug
#  • bruno-de-paula → sem fighter_info_plug
#  • bruno-bastos → sem fighter_info_plug
#  • bruno-ferreira → sem fighter_info_plug
#  • bruno-matias → sem fighter_info_plug
#  • bruno-mendes → sem fighter_info_plug
#  • caio-almeida → sem fighter_info_plug
#  • caio-terra → sem fighter_info_plug
#  • carina-santi → sem fighter_info_plug
#  • carley-gracie → sem fighter_info_plug
#  • carlos-henrique-elias-caique → sem fighter_info_plug
#  • carlos-gracie-sr → sem fighter_info_plug
#  • carlos-gracie-junior-carlinhos → sem fighter_info_plug
#  • carlos-henrique → sem fighter_info_plug
#  • carlos-lemos-escorrega → sem fighter_info_plug
#  • carlos-portugues-vieira → sem fighter_info_plug
#  • carlos-machado → sem fighter_info_plug
#  • carlos-melo → sem fighter_info_plug
#  • carlson-gracie → sem fighter_info_plug
#  • caroline-de-lazzer → sem fighter_info_plug
#  • cassio-werneck → sem fighter_info_plug
#  • catherine-perret → sem fighter_info_plug
#  • cleber-luciano → sem fighter_info_plug
#  • cesar-gracie → sem fighter_info_plug
#  • cezar-guimarães-casquinha → sem fighter_info_plug
#  • charlotte-von-baumgarten → sem fighter_info_plug
#  • charles-do-bronx-oliveira → sem fighter_info_plug
#  • christian-graugart → sem fighter_info_plug
#  • christian-xaropinho-uflacker → sem fighter_info_plug
#  • cícero-costha → sem fighter_info_plug
#  • chris-moriarty → sem fighter_info_plug
#  • claudia-do-val → sem fighter_info_plug
#  • claudio-franca → sem fighter_info_plug
#  • claudio-joanino → sem fighter_info_plug
#  • cosmo-dias → sem fighter_info_plug
#  • craig-kukuk → sem fighter_info_plug
#  • crézio-chavez → sem fighter_info_plug
#  • crezio-de-souza → sem fighter_info_plug
#  • cristiano-carioca → sem fighter_info_plug
#  • cristiano-lazzarini → sem fighter_info_plug
#  • cristiano-marcello → sem fighter_info_plug
#  • daisuke-shiraki → sem fighter_info_plug
#  • cindy-omatsu → sem fighter_info_plug
#  • crolin-gracie → sem fighter_info_plug
#  • daniel-azevedo → sem fighter_info_plug
#  • daniel-beleza → sem fighter_info_plug
#  • daniel-garcia → sem fighter_info_plug
#  • daniel-otero → sem fighter_info_plug
#  • daniel-valverde → sem fighter_info_plug
#  • danielle-alvarez → sem fighter_info_plug
#  • danilo-cherman → sem fighter_info_plug
#  • dave-camarillo → sem fighter_info_plug
#  • david-avellan → sem fighter_info_plug
#  • david-juliano-lemes → sem fighter_info_plug
#  • david-raab → sem fighter_info_plug
#  • david-jacobs → sem fighter_info_plug
#  • david-onuma → sem fighter_info_plug
#  • david-meyer → sem fighter_info_plug
#  • delson-heleno-pé-de-chumbo → sem fighter_info_plug
#  • dennis-asche → sem fighter_info_plug
#  • denilson-pimenta → sem fighter_info_plug
#  • denys-darzi → sem fighter_info_plug
#  • denny-prokopos → sem fighter_info_plug
#  • deoclecio-paulo → sem fighter_info_plug
#  • diego-bispo → sem fighter_info_plug
#  • diego-vivaldo → sem fighter_info_plug
#  • dima-murovanni → sem fighter_info_plug
#  • donald-achnick → sem fighter_info_plug
#  • doug-pelinkovic → sem fighter_info_plug
#  • dustin-clean-denes → sem fighter_info_plug
#  • /?p=199 → HTTP 404
#  • edson-diniz → sem fighter_info_plug
#  • /?p=4874 → HTTP 404
#  • eduardo-galvão → sem fighter_info_plug
#  • eduardo-jamelão-conceição → sem fighter_info_plug
#  • eduardo-gonçalves → sem fighter_info_plug
#  • eduardo-monteiro → sem fighter_info_plug
#  • ed-ramos-jiu-jitsu → sem fighter_info_plug
#  • eduardo-santoro-portuguese → sem fighter_info_plug
#  • eduardo-brigadeiro-venâncio → sem fighter_info_plug
#  • eduardo-rios → sem fighter_info_plug
#  • elina-moestam → sem fighter_info_plug
#  • eloisa-souto → sem fighter_info_plug
#  • eliot-marshall → sem fighter_info_plug
#  • elvira-karppinen → sem fighter_info_plug
#  • emilly-alves-vasconcelos → sem fighter_info_plug
#  • erik-wanderley → sem fighter_info_plug
#  • éricka-almeida → sem fighter_info_plug
#  • erin-herle → sem fighter_info_plug
#  • fabiano-silva-att → sem fighter_info_plug
#  • everton-santana-dentinho → sem fighter_info_plug
#  • fabiana-borges → sem fighter_info_plug
#  • fabbio-passos → sem fighter_info_plug
#  • fabio-coringa → sem fighter_info_plug
#  • fábio-andrade → sem fighter_info_plug
#  • fabio-clemente → sem fighter_info_plug
#  • fabio-gurgel → sem fighter_info_plug
#  • fabio-leopoldo → sem fighter_info_plug
#  • fabio-pateta-prado → sem fighter_info_plug
#  • fabio-santos → sem fighter_info_plug
#  • fabricio-morango → sem fighter_info_plug
#  • fabricio-martins → sem fighter_info_plug
#  • fabricio-medici → sem fighter_info_plug
#  • fabrício-moreira → sem fighter_info_plug
#  • faustino-pina-neto → sem fighter_info_plug
#  • federico-tisi → sem fighter_info_plug
#  • felipe-cavalcante-fredson-alves-jj → sem fighter_info_plug
#  • felipe-costa → sem fighter_info_plug
#  • felipe-zicro-neto → sem fighter_info_plug
#  • felipe-mota → sem fighter_info_plug
#  • felipe-bocão-silva → sem fighter_info_plug
#  • fernando-di-piero-soluço → sem fighter_info_plug
#  • fernando-pinduka → sem fighter_info_plug
#  • fernando-boi → sem fighter_info_plug
#  • fernando-monteiro-brasil-021 → sem fighter_info_plug
#  • fernando-pinduka → sem fighter_info_plug
#  • fernando-paradeda → sem fighter_info_plug
#  • flávio-almeida-cachorrinho → sem fighter_info_plug
#  • firas-zahabi → sem fighter_info_plug
#  • flavio-behring → sem fighter_info_plug
#  • francisco-toco-albuquerque → sem fighter_info_plug
#  • master-francisco-sá → sem fighter_info_plug
#  • chico-mendes → sem fighter_info_plug
#  • francisco-toco-albuquerque → sem fighter_info_plug
#  • fredson-paixao → sem fighter_info_plug
#  • master-francisco-mansor → sem fighter_info_plug
#  • gabriel-kitober → sem fighter_info_plug
#  • gabriel-goulart → sem fighter_info_plug
#  • gabriel-gonzaga → sem fighter_info_plug
#  • gabriel-marinho → sem fighter_info_plug
#  • gabriel-ribeiro-brazil-021 → sem fighter_info_plug
#  • gabriel-rainho → sem fighter_info_plug
#  • gabriel-willlcox → sem fighter_info_plug
#  • gabriel-procópio-fonseca → sem fighter_info_plug
#  • gabrielle-mccomb → sem fighter_info_plug
#  • gabriela-fechter → sem fighter_info_plug
#  • garth-taylor → sem fighter_info_plug
#  • geny-rebelo → sem fighter_info_plug
#  • gastão-gracie → sem fighter_info_plug
#  • george-gracie → sem fighter_info_plug
#  • geraldo-flôres → sem fighter_info_plug
#  • gezary-matuda → sem fighter_info_plug
#  • greg-souders → sem fighter_info_plug
#  • guilherme-cascon → sem fighter_info_plug
#  • gustavo-dantas → sem fighter_info_plug
#  • gustavo-machado → sem fighter_info_plug
#  • gustavo-dias-elias → sem fighter_info_plug
#  • gustavo-pires-siri → sem fighter_info_plug
#  • guybson-sá → sem fighter_info_plug
#  • heather-raftery → sem fighter_info_plug
#  • heath-pedigo → sem fighter_info_plug
#  • hannette-staack → sem fighter_info_plug
#  • helder-medeiros-spongebob → sem fighter_info_plug
#  • helio-soneca-moreira → sem fighter_info_plug
#  • helio-vigio → sem fighter_info_plug
#  • helvecio-penna → sem fighter_info_plug
#  • henrique-machado → sem fighter_info_plug
#  • hillary-williams → sem fighter_info_plug
#  • huanderson-pavão-gfteam → sem fighter_info_plug
#  • humberto-silveira → sem fighter_info_plug
#  • ian-mcpherson → sem fighter_info_plug
#  • ian-behring → sem fighter_info_plug
#  • ida-hansson → sem fighter_info_plug
#  • ighor-horta → sem fighter_info_plug
#  • igor-rodrigues → sem fighter_info_plug
#  • italo-lins → sem fighter_info_plug
#  • ítallo-vilardo → sem fighter_info_plug
#  • ivaniel-oliveira → sem fighter_info_plug
#  • ivan-gomes → sem fighter_info_plug
#  • jaqueline-amorim → sem fighter_info_plug
#  • jair-lourenço → sem fighter_info_plug
#  • jake-mackenzie → sem fighter_info_plug
#  • james-brasco → sem fighter_info_plug
#  • jim-harbison → sem fighter_info_plug
#  • janni-larsson → sem fighter_info_plug
#  • javier-vazquez → sem fighter_info_plug
#  • jean-kleber → sem fighter_info_plug
#  • jeff-joslin → sem fighter_info_plug
#  • jena-bishop → sem fighter_info_plug
#  • jeremy-arel-gerbil → sem fighter_info_plug
#  • jessica-cristina-santos → sem fighter_info_plug
#  • jessica-flowers → sem fighter_info_plug
#  • jessica-swanson → sem fighter_info_plug
#  • joão-johnny-faria → sem fighter_info_plug
#  • joão-roque → sem fighter_info_plug
#  • joão-zeferino → sem fighter_info_plug
#  • joao-alberto-barreto → sem fighter_info_plug
#  • joe-baize → sem fighter_info_plug
#  • joão-jones-oliveira → sem fighter_info_plug
#  • joe-moreira → sem fighter_info_plug
#  • joel-gingery → sem fighter_info_plug
#  • joel-tudor → sem fighter_info_plug
#  • jorge-britto → sem fighter_info_plug
#  • john-danaher → sem fighter_info_plug
#  • john-crouch → sem fighter_info_plug
#  • john-kavanagh → sem fighter_info_plug
#  • john-frankl → sem fighter_info_plug
#  • john-lewis → sem fighter_info_plug
#  • john-will → sem fighter_info_plug
#  • jonatas-tagarela-gurgel → sem fighter_info_plug
#  • jonatas-novaes → sem fighter_info_plug
#  • josé-aldo → sem fighter_info_plug
#  • jose-carlos → sem fighter_info_plug
#  • josé-leão-teixeira-zé-beleza → sem fighter_info_plug
#  • jose-junior → sem fighter_info_plug
#  • zé-mario-esfiha-queiroga → sem fighter_info_plug
#  • zé-marcello → sem fighter_info_plug
#  • zé-radiola → sem fighter_info_plug
#  • josef-manuel-zé-cobra → sem fighter_info_plug
#  • josh-griffiths → sem fighter_info_plug
#  • juan-miguel-iturralde → sem fighter_info_plug
#  • juan-lopes-da-silva → sem fighter_info_plug
#  • julio-cesar-pereira → sem fighter_info_plug
#  • julius-park → sem fighter_info_plug
#  • julio-foca-fernandez → sem fighter_info_plug
#  • julia-boscher → sem fighter_info_plug
#  • juliana-borges → sem fighter_info_plug
#  • jurandir-moura → sem fighter_info_plug
#  • justin-ordinario → sem fighter_info_plug
#  • jw-wright → sem fighter_info_plug
#  • jurandir-moura → sem fighter_info_plug
#  • keith-mckenzie → sem fighter_info_plug
#  • kid-peligro → sem fighter_info_plug
#  • karel-pravec-silver-fox → sem fighter_info_plug
#  • keiser-girão → sem fighter_info_plug
#  • kyra-gracie → sem fighter_info_plug
#  • koji-shibamoto → sem fighter_info_plug
#  • kristen-martin → sem fighter_info_plug
#  • kristin-mikkelson → sem fighter_info_plug
#  • kurt-osiander → sem fighter_info_plug
#  • kleber-buiú → sem fighter_info_plug
#  • larissa-campos → sem fighter_info_plug
#  • larissa-paes → sem fighter_info_plug
#  • laércio-fernandes → sem fighter_info_plug
#  • laura-barker → sem fighter_info_plug
#  • laurence-cousin-fouillat → sem fighter_info_plug
#  • leandro-escobar-tatu → sem fighter_info_plug
#  • leandro-lora → sem fighter_info_plug
#  • leandro-nyza → sem fighter_info_plug
#  • leandro-leu-martins → sem fighter_info_plug
#  • livia-gluchowska → sem fighter_info_plug
#  • laurah-hallock → sem fighter_info_plug
#  • leo-arruda → sem fighter_info_plug
#  • leonardo-castello-branco → sem fighter_info_plug
#  • leo-davila → sem fighter_info_plug
#  • leonardo-peçanha → sem fighter_info_plug
#  • letícia-ribeiro → sem fighter_info_plug
#  • lloyd-irvin → sem fighter_info_plug
#  • luanna-alzuguir → sem fighter_info_plug
#  • louie-cercedez → sem fighter_info_plug
#  • lucas-sachs → sem fighter_info_plug
#  • luciano-nucci-casquinha → sem fighter_info_plug
#  • luis-carlos-manimal → sem fighter_info_plug
#  • luis-heredia → sem fighter_info_plug
#  • luis-gustavo-guga-campos → sem fighter_info_plug
#  • lucio-rodrigues-lagarto → sem fighter_info_plug
#  • luis-roberto-duarte-bebeo → sem fighter_info_plug
#  • luis-marques → sem fighter_info_plug
#  • luis-sergio-roman → sem fighter_info_plug
#  • luiz-dias → sem fighter_info_plug
#  • luiz-frança → sem fighter_info_plug
#  • luiz-guilherme → sem fighter_info_plug
#  • luiz-renato-tom-abdo → sem fighter_info_plug
#  • luiz-ribeiro-manxinha → sem fighter_info_plug
#  • luiza-monteiro → sem fighter_info_plug
#  • luzia-fernandes → sem fighter_info_plug
#  • luke-harris → sem fighter_info_plug
#  • maggie-grindatti → sem fighter_info_plug
#  • marc-laimon → sem fighter_info_plug
#  • marcelino-freitas → sem fighter_info_plug
#  • marcel-louzado → sem fighter_info_plug
#  • marcelo-azevedo-uirapuru → sem fighter_info_plug
#  • marcelo-behring → sem fighter_info_plug
#  • marcelo-cohen → sem fighter_info_plug
#  • marcelo-cohen → sem fighter_info_plug
#  • marcelo-nunes → sem fighter_info_plug
#  • marcelo-machado → sem fighter_info_plug
#  • marcelo-capo-martins → sem fighter_info_plug
#  • marcelo-ribeiro → sem fighter_info_plug
#  • marcelo-pereira → sem fighter_info_plug
#  • marcello-salazar → sem fighter_info_plug
#  • marcelo-saporito → sem fighter_info_plug
#  • marcio-stambowsky → sem fighter_info_plug
#  • marcio-dos-santos → sem fighter_info_plug
#  • marco-barbosa → sem fighter_info_plug
#  • marco-canha → sem fighter_info_plug
#  • marcos-barreto → sem fighter_info_plug
#  • marco-vilella-gigante → sem fighter_info_plug
#  • marcos-de-souza → sem fighter_info_plug
#  • marcos-da-matta-parrumpinha → sem fighter_info_plug
#  • marcos-escobar → sem fighter_info_plug
#  • marcos-cerqueira → sem fighter_info_plug
#  • marcos-galvao-lôro → sem fighter_info_plug
#  • marcos-ratinho → sem fighter_info_plug
#  • marcos-de-oliveira → sem fighter_info_plug
#  • marcos-torregrosa-yemaso → sem fighter_info_plug
#  • marcus-bello → sem fighter_info_plug
#  • marcus-norat → sem fighter_info_plug
#  • maria-malyjasiak → sem fighter_info_plug
#  • marina-ribeiro → sem fighter_info_plug
#  • mario-claudio-tallarico → sem fighter_info_plug
#  • mario-yokoyama-gracie-oceania → sem fighter_info_plug
#  • mark-ramos → sem fighter_info_plug
#  • mariusz-linke-gold-team → sem fighter_info_plug
#  • marlon-sandro → sem fighter_info_plug
#  • matt-thornton → sem fighter_info_plug
#  • mauricio-antunes → sem fighter_info_plug
#  • mauricio-gomes → sem fighter_info_plug
#  • maurício-mariano → sem fighter_info_plug
#  • mauro-chueng → sem fighter_info_plug
#  • mauro-pacífico → sem fighter_info_plug
#  • mayara-custódio → sem fighter_info_plug
#  • mayko-araújo → sem fighter_info_plug
#  • max-carvalho → sem fighter_info_plug
#  • max-trombini → sem fighter_info_plug
#  • maxine-thylin → sem fighter_info_plug
#  • melissa-cueto → sem fighter_info_plug
#  • melqui-galvão → sem fighter_info_plug
#  • michael-zenga → sem fighter_info_plug
#  • michel-langhi → sem fighter_info_plug
#  • michelle-nicolini → sem fighter_info_plug
#  • mike-fowler → sem fighter_info_plug
#  • milton-bastos → sem fighter_info_plug
#  • milton-regis → sem fighter_info_plug
#  • mitsuyoshi-hayakawa → sem fighter_info_plug
#  • moacir-mendes-júnior → sem fighter_info_plug
#  • moisés-muradi → sem fighter_info_plug
#  • monica-vanessa-silva → sem fighter_info_plug
#  • monir-salomão → sem fighter_info_plug
#  • monique-ricardo → sem fighter_info_plug
#  • murilo-bustamante → sem fighter_info_plug
#  • muzio-de-angelis → sem fighter_info_plug
#  • nabil-aziz-master-nabil → sem fighter_info_plug
#  • natasha-quiza → sem fighter_info_plug
#  • nathalie-ribeiro → sem fighter_info_plug
#  • nathan-mendelsohn → sem fighter_info_plug
#  • nathan-carroll → sem fighter_info_plug
#  • nahum-rabay → sem fighter_info_plug
#  • nelson-monteiro → sem fighter_info_plug
#  • nicolas-gregoriades → sem fighter_info_plug
#  • nikki-sullivan → sem fighter_info_plug
#  • nina-moura → sem fighter_info_plug
#  • nuno-martins → sem fighter_info_plug
#  • nyjah-rollins → sem fighter_info_plug
#  • octavio-couto-ratinho → sem fighter_info_plug
#  • bold-erdene-odsuren → sem fighter_info_plug
#  • octavio-de-almeida-senior → sem fighter_info_plug
#  • olavo-abreu → sem fighter_info_plug
#  • oliver-geddes → sem fighter_info_plug
#  • omar-salum → sem fighter_info_plug
#  • osvaldo-alves → sem fighter_info_plug
#  • oswaldo-fadda → sem fighter_info_plug
#  • oswaldo-gracie → sem fighter_info_plug
#  • patricia-lage → sem fighter_info_plug
#  • oswaldo-paqueta → sem fighter_info_plug
#  • patrick-bittan → sem fighter_info_plug
#  • pablo-silva → sem fighter_info_plug
#  • paul-schreiner → sem fighter_info_plug
#  • pámela-bóveda-aguirre → sem fighter_info_plug
#  • paulo-filho → sem fighter_info_plug
#  • paulo-mauricio-strauch → sem fighter_info_plug
#  • paulo-gazze-jr → sem fighter_info_plug
#  • pedro-hemeterio → sem fighter_info_plug
#  • pedro-mello → sem fighter_info_plug
#  • pedro-pacheco-fernandes-tu-kaha-bjj → sem fighter_info_plug
#  • pedro-sauer → sem fighter_info_plug
#  • penny-thomas → sem fighter_info_plug
#  • pete-the-greek-letsos → sem fighter_info_plug
#  • philippe-balmant → sem fighter_info_plug
#  • radek-turek → sem fighter_info_plug
#  • rafael-fofitio-barros → sem fighter_info_plug
#  • rafael-barbosa → sem fighter_info_plug
#  • rafael-correa-gordinho → sem fighter_info_plug
#  • rafael-freitas → sem fighter_info_plug
#  • rafael-heck → sem fighter_info_plug
#  • rafael-rafinha-dallinha → sem fighter_info_plug
#  • rafael-dos-anjos → sem fighter_info_plug
#  • ralph-gracie → sem fighter_info_plug
#  • raquel-paaluhi-canuto → sem fighter_info_plug
#  • ramon-lemos → sem fighter_info_plug
#  • raphael-abi-rihan → sem fighter_info_plug
#  • renato-migliaccio → sem fighter_info_plug
#  • raphael-chaves-catatau → sem fighter_info_plug
#  • raul-gomes → sem fighter_info_plug
#  • raoni-barcelos → sem fighter_info_plug
#  • reginaldo-gurgel-almeida → sem fighter_info_plug
#  • reinaldo-ribeiro → sem fighter_info_plug
#  • relson-gracie → sem fighter_info_plug
#  • renan-barão → sem fighter_info_plug
#  • renato-barreto → sem fighter_info_plug
#  • renata-marinho → sem fighter_info_plug
#  • renato-migliaccio → sem fighter_info_plug
#  • renato-tavares → sem fighter_info_plug
#  • reyson-gracie → sem fighter_info_plug
#  • ricardo-de-la-riva → sem fighter_info_plug
#  • ricardo-rey-diogo → sem fighter_info_plug
#  • ricardo-feliciano → sem fighter_info_plug
#  • ricardo-cavalcanti → sem fighter_info_plug
#  • ricardo-marques → sem fighter_info_plug
#  • ricardo-soranco → sem fighter_info_plug
#  • ricardo-franjinha-miller → sem fighter_info_plug
#  • richard-dickie-martin → sem fighter_info_plug
#  • rikako-yuasa → sem fighter_info_plug
#  • rilion-gracie → sem fighter_info_plug
#  • robert-drysdale → sem fighter_info_plug
#  • roberto-godoi → sem fighter_info_plug
#  • roberto-lage → sem fighter_info_plug
#  • roberto-gordo-correa → sem fighter_info_plug
#  • roberto-atalla → sem fighter_info_plug
#  • roberto-tozi → sem fighter_info_plug
#  • robson-chaves → sem fighter_info_plug
#  • robson-gracie → sem fighter_info_plug
#  • robson-mau-mau → sem fighter_info_plug
#  • rockson-gracie → sem fighter_info_plug
#  • /?p=2048 → HTTP 404
#  • rodney-ellis → sem fighter_info_plug
#  • rodolphe-olivier → sem fighter_info_plug
#  • rodrigo-brucutu-cabral → sem fighter_info_plug
#  • rodrigo-carvalho → sem fighter_info_plug
#  • rodrigo-fajardo-pimpolho → sem fighter_info_plug
#  • rodrigo-medeiros → sem fighter_info_plug
#  • rodrigo-munduruca → sem fighter_info_plug
#  • rodrigo-siqueira → sem fighter_info_plug
#  • rodrigo-ribeiro → sem fighter_info_plug
#  • rodrigo-ranieri-mike → sem fighter_info_plug
#  • roger-coelho → sem fighter_info_plug
#  • rogerio-poggio → sem fighter_info_plug
#  • rogerio-taborda → sem fighter_info_plug
#  • rolker-gracie → sem fighter_info_plug
#  • rolles-gracie → sem fighter_info_plug
#  • romero-jacaré-cavalcanti → sem fighter_info_plug
#  • royce-gracie → sem fighter_info_plug
#  • rufino-gomes-morcego → sem fighter_info_plug
#  • ryan-beauregard → sem fighter_info_plug
#  • ryan-murphy-crosley-gracie-jj → sem fighter_info_plug
#  • ryo-ominami → sem fighter_info_plug
#  • ryron-gracie → sem fighter_info_plug
#  • saeed-dunkaev → sem fighter_info_plug
#  • salvatore-pace → sem fighter_info_plug
#  • samantha-cook → sem fighter_info_plug
#  • samuel-braga → sem fighter_info_plug
#  • samy-al-jamal → sem fighter_info_plug
#  • scott-kaplan → sem fighter_info_plug
#  • serena-gabrielli → sem fighter_info_plug
#  • sergio-benini → sem fighter_info_plug
#  • sergio-calderon → sem fighter_info_plug
#  • sérgio-íris → sem fighter_info_plug
#  • sergio-babu-gasparelli → sem fighter_info_plug
#  • sergio-penha → sem fighter_info_plug
#  • sergio-bolão-souza → sem fighter_info_plug
#  • sergio-rios → sem fighter_info_plug
#  • sergio-zimmermann-canudo → sem fighter_info_plug
#  • shanti-abelha → sem fighter_info_plug
#  • shane-rice → sem fighter_info_plug
#  • shawn-williams → sem fighter_info_plug
#  • silvana-abreu → sem fighter_info_plug
#  • sim-go → sem fighter_info_plug
#  • stéfano-corrêa → sem fighter_info_plug
#  • shinya-aoki → sem fighter_info_plug
#  • sylvio-behring → sem fighter_info_plug
#  • sofia-amarante → sem fighter_info_plug
#  • talia-marie-vaughan → sem fighter_info_plug
#  • talita-nogueira-treta → sem fighter_info_plug
#  • tammi-musumeci → sem fighter_info_plug
#  • tracey-goodell → sem fighter_info_plug
#  • thaís-ramos → sem fighter_info_plug
#  • p13193 → sem text-content
#  • thamires-monteiro → sem fighter_info_plug
#  • theodoro-canal → sem fighter_info_plug
#  • thiago-barreto → sem fighter_info_plug
#  • thiago-monstro-borges → sem fighter_info_plug
#  • thiago-leiras-brazil-021 → sem fighter_info_plug
#  • thiago-fernandes → sem fighter_info_plug
#  • thiago-rogerio-dos-santos-brazil-021 → sem fighter_info_plug
#  • thibaut-olivier → sem fighter_info_plug
#  • tiago-alves → sem fighter_info_plug
#  • tiago-rocha → sem fighter_info_plug
#  • todd-margolis → sem fighter_info_plug
#  • totila-jordan → sem fighter_info_plug
#  • travis-lutter → sem fighter_info_plug
#  • ulpiano-malachias → sem fighter_info_plug
#  • valmyr-neto → sem fighter_info_plug
#  • vanessa-english → sem fighter_info_plug
#  • vanessa-oliveira → sem fighter_info_plug
#  • vedha-toscano → sem fighter_info_plug
#  • vicente-junior → sem fighter_info_plug
#  • victor-costa → sem fighter_info_plug
#  • vinicius-aieta → sem fighter_info_plug
#  • vincent-nguyen → sem fighter_info_plug
#  • vinícius-coelho → sem fighter_info_plug
#  • vinicius-corrales → sem fighter_info_plug
#  • vinicius-draculino-magalhães → sem fighter_info_plug
#  • vinicius-marinho → sem fighter_info_plug
#  • vinícius-pedrosa → sem fighter_info_plug
#  • vitor-toledo → sem fighter_info_plug
#  • wagner-galeto-campos → sem fighter_info_plug
#  • wagnney-fabiano → sem fighter_info_plug
#  • waldemar-santana → sem fighter_info_plug
#  • waldomiro-perez-jr → sem fighter_info_plug
#  • washington-luis → sem fighter_info_plug
#  • walter-mattos → sem fighter_info_plug
#  • wellington-megaton-dias → sem fighter_info_plug
#  • wendell-alexander → sem fighter_info_plug
#  • master-wilson-mattos → sem fighter_info_plug
#  • william-abreu → sem fighter_info_plug
#  • wilson-bueno → sem fighter_info_plug
#  • xiong-yuxing-emma → sem fighter_info_plug
#  • wilson-moreira → sem fighter_info_plug
#  • yacinta-nguyen → sem fighter_info_plug
#  • yuki-nakai → sem fighter_info_plug
#  • yukinori-sasa → sem fighter_info_plug
#  • yusuke-honma → sem fighter_info_plug
#  • yvone-duarte → sem fighter_info_plug
#  • zach-maslany → sem fighter_info_plug
#  • zak-maxwell → sem fighter_info_plug
#  • shimon-mochizuki → sem fighter_info_plug
#  • andre-marola → sem fighter_info_plug
#  • budo-jake → sem fighter_info_plug
#  • alain-pozo → sem fighter_info_plug
#  • josé-higino → sem fighter_info_plug
#  • riccardo-ammendolia → sem fighter_info_plug
#  • mauro-ayres → sem fighter_info_plug
#  • paulo-coelho-brandão → sem fighter_info_plug
#  • henry-akins → sem fighter_info_plug
#  • fabio-binho-monteiro → sem fighter_info_plug
#  • fernando-gurgel → sem fighter_info_plug
#  • bruno-fernandes → sem fighter_info_plug
#  • fernando-yamasaki → sem fighter_info_plug
#  • henry-akins → sem fighter_info_plug
#  • luca-atalla → sem fighter_info_plug
#  • marcelo-alonso → sem fighter_info_plug
#  • marcelo-mello → sem fighter_info_plug
#  • renato-miragaia → sem fighter_info_plug
#  • kim-terra → sem fighter_info_plug
#  • sergio-malibu-jardim → sem fighter_info_plug
#  • monique-elias → sem fighter_info_plug
#  • roy-harris → sem fighter_info_plug
#  • fernando-gurgel → sem fighter_info_plug
#  • bruno-fernandes → sem fighter_info_plug
#  • rodrigo-pagani → sem fighter_info_plug
#  • givanildo-santana → sem fighter_info_plug
#  • fabiano-pega-leve-scherner → sem fighter_info_plug
#  • enson-inoue → sem fighter_info_plug
#  • vinícius-cruz → sem fighter_info_plug
#  • carlos-rosado → sem fighter_info_plug
#  • rosângela-zanza-conceição → sem fighter_info_plug
#  • andré-motta → sem fighter_info_plug
#  • carlos-rollyson → sem fighter_info_plug
#  • tony-passos → sem fighter_info_plug
#  • tom-deblass → sem fighter_info_plug
#  • dean-liebenberg → sem fighter_info_plug
#  • beneil-dariush → sem fighter_info_plug
#  • venla-luukkonen → sem fighter_info_plug
#  • i̇brahim-i̇nal → sem fighter_info_plug
#  • herbert-burns → sem fighter_info_plug
#  • sebastian-lalli → sem fighter_info_plug
#  • jamie-cruz → sem fighter_info_plug
#  • márcio-rodrigues → sem fighter_info_plug
#  • alan-gumby-marques → sem fighter_info_plug
#  • emily-kwok → sem fighter_info_plug
#  • louis-vintaloro → sem fighter_info_plug
#  • steve-maxwell → sem fighter_info_plug
#  • joaquina-bonfim → sem fighter_info_plug
#  • rodrigo-freitas → sem fighter_info_plug
#  • bruno-paulista → sem fighter_info_plug
#  • josé-tiago-barros → sem fighter_info_plug
#  • paulo-guillobel → sem fighter_info_plug
#  • andré-glodzinski → sem fighter_info_plug
#  • everdan-mestre-dan-olegário → sem fighter_info_plug
#  • dc-maxwell → sem fighter_info_plug
#  • chris-haueter → sem fighter_info_plug
#  • jorge-pereira → sem fighter_info_plug
#  • fábio-negão-nascimento → sem fighter_info_plug
#  • felicia-oh → sem fighter_info_plug
#  • daniel-wanderley → sem fighter_info_plug
#  • paulo-rezende → sem fighter_info_plug
#  • carlson-gracie-junior → sem fighter_info_plug
#  • vinicius-amaral → sem fighter_info_plug
#  • wilson-reis → sem fighter_info_plug
#  • adriano-moraes → sem fighter_info_plug
#  • nic-ruben → sem fighter_info_plug
#  • reylson-gracie → sem fighter_info_plug
#  • gazzy-parman → sem fighter_info_plug
#  • suga-pop → sem fighter_info_plug
#  • ataíde-junior → sem fighter_info_plug
#  • wander-braga → sem fighter_info_plug
#  • karen-antunes → sem fighter_info_plug
#  • suyan-queiroz → sem fighter_info_plug
#  • luigi-mondelli → sem fighter_info_plug
#  • elan-santiago → sem fighter_info_plug
#  • aldo-januário → sem fighter_info_plug
#  • carlos-barreto → sem fighter_info_plug
#  • alison-tremblay → sem fighter_info_plug
#  • sophia-mcdermott-drysdale → sem fighter_info_plug
#  • ailson-brites → sem fighter_info_plug
#  • paulo-sergio → sem fighter_info_plug
#  • alex-paz → sem fighter_info_plug
#  • pirillo-roriz → sem fighter_info_plug
#  • emyr-shark-bussade → sem fighter_info_plug
#  • jason-gagnon → sem fighter_info_plug
#  • leo-dalla → sem fighter_info_plug
#  • marcel-gonçalves → sem fighter_info_plug
#  • henrique-gama-filho → sem fighter_info_plug
#  • pedro-duarte → sem fighter_info_plug
#  • patricia-fontes → sem fighter_info_plug
#  • pedro-gama-filho → sem fighter_info_plug
#  • amal-easton → sem fighter_info_plug
#  • neiman-gracie → sem fighter_info_plug
#  • régis-lebre → sem fighter_info_plug
#  • egan-inoue → sem fighter_info_plug
#  • kristina-barlaan → sem fighter_info_plug
#  • bruno-alminha-moreno → sem fighter_info_plug
#  • james-boran → sem fighter_info_plug
#  • francisco-sázinho → sem fighter_info_plug
#  • kiko-velloso → sem fighter_info_plug
#  • luciana-luka-dias → sem fighter_info_plug
#  • deborah-gracie-stambowsky → sem fighter_info_plug
#  • ryan-gracie → sem fighter_info_plug
#  • juarez-soares → sem fighter_info_plug
#  • carlos-terrinha → sem fighter_info_plug
#  • rodrigo-feijão → sem fighter_info_plug
#  • tayane-porfirio → sem fighter_info_plug
#  • fernanda-mazzelli → sem fighter_info_plug
#  • adilson-bitta-lima → sem fighter_info_plug
#  • jared-weiner → sem fighter_info_plug
#  • danny-alvarez → sem fighter_info_plug
#  • vinicius-magoo-canevari → sem fighter_info_plug
#  • nathiely-de-jesus → sem fighter_info_plug
#  • stephen-roberto → sem fighter_info_plug
#  • jack-mcvicker → sem fighter_info_plug
#  • ariadne-oliveira → sem fighter_info_plug
#  • talita-alencar → sem fighter_info_plug
#  • wagner-mota → sem fighter_info_plug
#  • carlos-farias → sem fighter_info_plug
#  • marcus-antelante → sem fighter_info_plug
#  • luiz-tosta → sem fighter_info_plug
#  • tiago-pereira → sem fighter_info_plug
#  • rodrigo-pinheiro → sem fighter_info_plug
#  • fabricio-bicudo → sem fighter_info_plug
#  • manuel-manny-diaz → sem fighter_info_plug
#  • diogo-almeida → sem fighter_info_plug
#  • outi-järvilehto → sem fighter_info_plug
#  • andré-ushirobira → sem fighter_info_plug
#  • mauricio-russo → sem fighter_info_plug
#  • paulo-caruso → sem fighter_info_plug
#  • roli-delgado → sem fighter_info_plug
#  • manoel-neto → sem fighter_info_plug
#  • valdir-tio-chico-canuto → sem fighter_info_plug
#  • thamires-aquino → sem fighter_info_plug
#  • nakapan-phungephorn → sem fighter_info_plug
#  • eliot-kelly → sem fighter_info_plug
#  • maurição-da-hunter → sem fighter_info_plug
# ✅ 55188 lutas salvas em 'historico_lutas.csv'.

# %%
  df_fights = pd.read_csv('historico_lutas.csv', encoding='utf-8')
  df_fights
# Out:
#                fighter  fight_id                    opponent result  \
# 0         adam-ferrara     14004        Joao MiyaoJoao Miyao      L
# 1         adam-ferrara     14630    Silvio DuranSilvio Duran      L
# 2         adam-ferrara     15144  Thiago MacedoThiago Macedo      L
# 3         adam-ferrara     15583                  Rene Lopez      L
# 4         adam-ferrara     16392  Thiago MacedoThiago Macedo      L
# ...                ...       ...                         ...    ...
# 55183  vinicius-garcia     22014                 Cody Heller      W
# 55184  vinicius-garcia     23363              Daniel Olivier      W
# 55185  vinicius-garcia     23371              Joshua Murdock      W
# 55186  vinicius-garcia     24039               Kyle Raemisch      W
# 55187  vinicius-garcia     24236                Kevin Vieira      W
#
#                 method       competition weight stage  year
# 0                  RNC     No Gi Pan Am.   61KG    SF  2017
# 1             Pts: 4x2   Cincinnati Open   70KG    SF  2017
# 2      Choke from back      Houston Open   70KG     F  2018
# 3                  Adv  Chicago Sp. Open   64KG    SF  2018
# 4        Pts: 2x2, Adv         Miami SPO   70KG    SF  2018
# ...                ...               ...    ...   ...   ...
# 55183              NaN   Atlanta SM Open    ABS    4F  2019
# 55184      Canto choke  New Orleans Open   88KG    SF  2020
# 55185           Points  New Orleans Open    ABS    SF  2020
# 55186  Mounted X choke           F2W 153   85KG   SPF  2020
# 55187  Hashimoto choke      Pan American   82KG    8F  2020
#
# [55188 rows x 9 columns]

# %%
print(df_fights.isnull().sum())
# Out:
# fighter           0
# fight_id          0
# opponent        148
# result            0
# method         1371
# competition      20
# weight          657
# stage           332
# year              0
# dtype: int64

# %%
# prompt: Veja todos o nome dos lutadores que estao na coluna fighter, após isso,  faça a busca apenas pelos nomes que nao estao nessa coluna em opponent, e me mostre os 20 que mais aparecem

from collections import Counter

if df_fights is not None:
  fighters = df_fights['fighter'].unique()
  opponents = df_fights['opponent'].unique()

  # Find opponents not present as fighters
  missing_fighters = set(opponents) - set(fighters)

  # Count the occurrences of the missing fighters in the 'opponent' column
  opponent_counts = df_fights['opponent'].value_counts()
  missing_fighters_counts = opponent_counts[opponent_counts.index.isin(missing_fighters)]

  # Display the top 20 missing fighters
  print("Top 20 Opponents not present in the 'fighter' column:")
  print(missing_fighters_counts.head(100))
else:
  print("DataFrame not loaded correctly, please check the previous code.")
# Out:
# Top 20 Opponents not present in the 'fighter' column:
# opponent
# Unknown                           399
# Leandro LoLeandro Lo              208
# Fellipe AndrewFellipe Andrew      206
# Gianni GrippoGianni Grippo        182
# Adam WardzinskiAdam Wardzinski    168
#                                  ...
# JT TorresJT Torres                 71
# Mica GalvaoMica Galvao             71
# Roosevelt SousaRoosevelt Sousa     71
# Cleber SousaCleber Sousa           71
# Lucas PinheiroLucas Pinheiro       71
# Name: count, Length: 100, dtype: int64

# %%
df_fights = (
    df_fights
    .drop(columns=['method', 'stage'])
    .dropna(subset=['opponent'])
)
df_fights = df_fights[df_fights['opponent'] != 'Unknown']

df_fights
# Out:
#                fighter  fight_id                    opponent result  \
# 0         adam-ferrara     14004        Joao MiyaoJoao Miyao      L
# 1         adam-ferrara     14630    Silvio DuranSilvio Duran      L
# 2         adam-ferrara     15144  Thiago MacedoThiago Macedo      L
# 3         adam-ferrara     15583                  Rene Lopez      L
# 4         adam-ferrara     16392  Thiago MacedoThiago Macedo      L
# ...                ...       ...                         ...    ...
# 55183  vinicius-garcia     22014                 Cody Heller      W
# 55184  vinicius-garcia     23363              Daniel Olivier      W
# 55185  vinicius-garcia     23371              Joshua Murdock      W
# 55186  vinicius-garcia     24039               Kyle Raemisch      W
# 55187  vinicius-garcia     24236                Kevin Vieira      W
#
#             competition weight  year
# 0         No Gi Pan Am.   61KG  2017
# 1       Cincinnati Open   70KG  2017
# 2          Houston Open   70KG  2018
# 3      Chicago Sp. Open   64KG  2018
# 4             Miami SPO   70KG  2018
# ...                 ...    ...   ...
# 55183   Atlanta SM Open    ABS  2019
# 55184  New Orleans Open   88KG  2020
# 55185  New Orleans Open    ABS  2020
# 55186           F2W 153   85KG  2020
# 55187      Pan American   82KG  2020
#
# [54641 rows x 7 columns]

# %%
print(df_fights.isnull().sum())
# Out:
# fighter          0
# fight_id         0
# opponent         0
# result           0
# competition     20
# weight         650
# year             0
# dtype: int64

# %%
# Preenche NaN em competition e weight com "Unknown"
df_fights['competition'].fillna('Unknown', inplace=True)
df_fights['weight'].fillna('Unknown', inplace=True)

# Verifique
print(df_fights.isnull().sum())
# Out:
# fighter        0
# fight_id       0
# opponent       0
# result         0
# competition    0
# weight         0
# year           0
# dtype: int64
# <ipython-input-41-e27ae486d526>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fights['competition'].fillna('Unknown', inplace=True)
# <ipython-input-41-e27ae486d526>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fights['weight'].fillna('Unknown', inplace=True)

# %%
import unicodedata

def normalize_text(s):
    if pd.isna(s):
        return s
    # Remove acentos
    s = unicodedata.normalize('NFKD', s)
    s = s.encode('ascii', 'ignore').decode('utf-8')
    # Converte para minúsculas
    return s.lower().strip()

# Aplica a normalização em df_unico
df_fights['fighter']  = df_fights['fighter'].apply(normalize_text)
df_fights['opponent'] = df_fights['opponent'].apply(normalize_text)

df_fights['fighter'] = (
    df_fights['fighter']
    .str.replace(r'\s+', '-', regex=True)
    .str.strip('-')
)

df_fights['opponent'] = (
    df_fights['opponent']
    .str.replace(r'\s+', '-', regex=True)
    .str.strip('-')
)
# Opcional: converte para categoria para otimizar memória
df_fights['fighter']  = df_fights['fighter'].astype('category')
df_fights['opponent'] = df_fights['opponent'].astype('category')


def corrigir_nome(nome):
    meio = len(nome) // 2
    if nome[:meio] == nome[meio:]:
        return nome[:meio]
    return nome

df_fights['opponent'] = df_fights['opponent'].apply(corrigir_nome)


df_fights
# Out:
#                fighter  fight_id        opponent result       competition  \
# 0         adam-ferrara     14004      joao-miyao      L     No Gi Pan Am.
# 1         adam-ferrara     14630    silvio-duran      L   Cincinnati Open
# 2         adam-ferrara     15144   thiago-macedo      L      Houston Open
# 3         adam-ferrara     15583      rene-lopez      L  Chicago Sp. Open
# 4         adam-ferrara     16392   thiago-macedo      L         Miami SPO
# ...                ...       ...             ...    ...               ...
# 55183  vinicius-garcia     22014     cody-heller      W   Atlanta SM Open
# 55184  vinicius-garcia     23363  daniel-olivier      W  New Orleans Open
# 55185  vinicius-garcia     23371  joshua-murdock      W  New Orleans Open
# 55186  vinicius-garcia     24039   kyle-raemisch      W           F2W 153
# 55187  vinicius-garcia     24236    kevin-vieira      W      Pan American
#
#       weight  year
# 0       61KG  2017
# 1       70KG  2017
# 2       70KG  2018
# 3       64KG  2018
# 4       70KG  2018
# ...      ...   ...
# 55183    ABS  2019
# 55184   88KG  2020
# 55185    ABS  2020
# 55186   85KG  2020
# 55187   82KG  2020
#
# [54641 rows x 7 columns]

# %%
# prompt: Veja todos o nome dos lutadores que estao na coluna fighter, após isso,  faça a busca apenas pelos nomes que nao estao nessa coluna em opponent, e me mostre os 20 que mais aparecem

from collections import Counter

if df_fights is not None:
  fighters = df_fights['fighter'].unique()
  opponents = df_fights['opponent'].unique()

  # Find opponents not present as fighters
  missing_fighters = set(opponents) - set(fighters)

  # Count the occurrences of the missing fighters in the 'opponent' column
  opponent_counts = df_fights['opponent'].value_counts()
  missing_fighters_counts = opponent_counts[opponent_counts.index.isin(missing_fighters)]

  # Display the top 20 missing fighters
  print("Top 20 Opponents not present in the 'fighter' column:")
  print(missing_fighters_counts.head(100))
else:
  print("DataFrame not loaded correctly, please check the previous code.")
# Out:
# Top 20 Opponents not present in the 'fighter' column:
# opponent
# lucas-barbosa       163
# roberto-abreu       130
# felipe-pena         126
# r.-evangelista      115
# osvaldo-moizinho    110
#                    ...
# carlos-farias        33
# orlando-castillo     32
# matheus-onda         32
# athos-miranda        32
# leandro-lima         32
# Name: count, Length: 100, dtype: int64

# %%
import pandas as pd


# 1) Dicionário manual mapeando opponent → fighter correto
manual_map = {
    'lucas-barbosa':    'lucas-hulk-barbosa',
    'roberto-abreu':    'roberto-cyborg-abreu',
    'felipe-pena':      'felipe-pena-preguica',
    'r.-evangelista':   'ricardo-evangelista',
    'osvaldo-moizinho': 'osvaldo-queixinho-moizinho',
    'rafael-lovato':    'rafael-lovato-jr',
    'helton-jose':      'helton-jose-junior',
    'marcus-almeida':   'marcus-buchecha-almeida',
    'diego-oliveira':   'diego-pato-oliveira',
    'joao-rocha':       'joao-gabriel-rocha',
    'michael-liera':    'michael-liera-jr',
    'c.-negromonte':    'charles-negromonte',
    'leo-saggioro':     'leonardo-saggioro',
    'vitor-oliveira':   'vitor-henrique-oliveira',
    'augusto-mendes':   'augusto-mendes-tanquinho',
    'mica-galvao':      'micael-galvao',
    'rubens-charles':   'rubens-charles-cobrinha',
    'alexandre-jesus':  'alexandre-de-jesus',
    'wellington-luis':  'wellington-alemao-luis',
    'thiago-sa':        'thiago-sa-fortes',
    'henrique-cardoso': 'henrique-cardoso-ceconi',
    'pedro-alex':       'pedro-alex-bombom',
    'israel-sousa':     'israel-sousa-almeida',
    'lucas-valle':      'lucas-valente',
    'diogo-sampaio':    'diogo-sampaio-moreno',
    'celso-vinicius':   'celso-celsinho-venicius',
    'bruno-matias':     'jose-bruno-matias',
    'gilbert-burns':    'gilbert-burns-durinho',
    'levi-jones':       'levi-jones-leary',
    'yan-lucas':               'yan-pica-pau-lucas',
    'leo-nogueira':            'leonardo-nogueira',
    'marcos-martins':          'marcos-petcho-martins',
    'gabriel-costa':           'gabriel-costa-maranhao',
    'gabriel-henrique':        'gabriel-henrique-oliveira',
    'braga-neto':              'antonio-braga-neto',
    'rodrigo-tatu':            'rodrigo-lopes-tatu',
    'ademir-barreto':          'ademir-barreto-araujo',
    'rafael-anjos':            'rafael-dos-anjos-torres',
    'mikey-musumeci':          'michael-musumeci',
    'valdir-araujo':           'valdir-araujo-bb-monstro',
    'leo-silva':               'leonardo-silva',
    'rodrigo-fajardo':         'rodrigo-francioni',
    'ruan-oliveira':           'ruan-de-oliveira',
    'mauricio-oliveira':       'mauricio-oliveira-neto',
    'yago-souza':              'yago-de-souza',
    'alan-finfou':             'alan-nascimento-finfou',
    'eldar-rafigaev':          'eldar-yakuza-rafigaev',
    'orlando-castillo':        'orlando-sanchez',
    'leandro-lima':            'leandro-rounaud-lima',
    'catriel-oliveira':        'catriel-oliveira-rodrigues',
    'gabriel-oliveira':        'gabriel-de-oliveira',
    'g.-lambertucci':          'guilherme-lambertucci',
    'claudio-mattos':          'claudio-mattos-caloquinha',
    'inacio-santos':           'inacio-dos-santos',
    'bill-cooper':             'bill-the-grill-cooper',
    'luis-oliveira':           'luis-oliveira-cantareira',
    'faisal-alkitbe':          'faisal-al-kitbe',
    'marcio-cruz':             'marcio-cruz-pe-de-pano',
    'marcos-costa':            'marcos-paulo-costa'
}

# 2) Verificação anterior ao replace: quantas ocorrências cada chave tinha
counts_before = df_fights['opponent'].value_counts()
print("Ocorrências antes da substituição:")
print(counts_before.reindex(manual_map.keys(), fill_value=0))

# 3) Aplica apenas essas substituições em opponent
df_fights['opponent'] = df_fights['opponent'].replace(manual_map)

# 4) Converte para categoria (recomendado)
df_fights['opponent'] = df_fights['opponent'].astype('category')

# 5) Verificação após o replace
print("\nTotal de fighters únicos em 'opponent' após mapeamento:", df_fights['opponent'].nunique())

# (Opcional) Confira que as chaves foram realmente substituídas, mostrando zeros
counts_after = df_fights['opponent'].value_counts()
print("\nOcorrências após a substituição (esperado zeros nas chaves):")
print(counts_after.reindex(manual_map.keys(), fill_value=0))

# 6) Se tudo estiver certo, df_limpado agora contém as correções
df_fights
# Out:
# Ocorrências antes da substituição:
# opponent
# lucas-barbosa        163
# roberto-abreu        130
# felipe-pena          126
# r.-evangelista       115
# osvaldo-moizinho     110
# rafael-lovato        106
# helton-jose          102
# marcus-almeida       102
# diego-oliveira       100
# joao-rocha            99
# michael-liera         88
# c.-negromonte         86
# leo-saggioro          80
# vitor-oliveira        78
# augusto-mendes        73
# mica-galvao           71
# rubens-charles        68
# alexandre-jesus       67
# wellington-luis       67
# thiago-sa             66
# henrique-cardoso      66
# pedro-alex            65
# israel-sousa          64
# lucas-valle           60
# diogo-sampaio         53
# celso-vinicius        52
# bruno-matias          47
# gilbert-burns         47
# levi-jones            47
# yan-lucas             99
# leo-nogueira          50
# marcos-martins        49
# gabriel-costa         48
# gabriel-henrique      44
# braga-neto            43
# rodrigo-tatu          41
# ademir-barreto        38
# rafael-anjos          37
# mikey-musumeci        37
# valdir-araujo         37
# leo-silva             37
# rodrigo-fajardo       36
# ruan-oliveira         36
# mauricio-oliveira     36
# yago-souza            33
# alan-finfou           33
# eldar-rafigaev        32
# orlando-castillo      32
# leandro-lima          32
# catriel-oliveira      31
# gabriel-oliveira      31
# g.-lambertucci        31
# claudio-mattos        31
# inacio-santos         30
# bill-cooper           30
# luis-oliveira         30
# faisal-alkitbe        30
# marcio-cruz           29
# marcos-costa          28
# Name: count, dtype: int64
#
# Total de fighters únicos em 'opponent' após mapeamento: 11747
#
# Ocorrências após a substituição (esperado zeros nas chaves):
# opponent
# lucas-barbosa        0
# roberto-abreu        0
# felipe-pena          0
# r.-evangelista       0
# osvaldo-moizinho     0
# rafael-lovato        0
# helton-jose          0
# marcus-almeida       0
# diego-oliveira       0
# joao-rocha           0
# michael-liera        0
# c.-negromonte        0
# leo-saggioro         0
# vitor-oliveira       0
# augusto-mendes       0
# mica-galvao          0
# rubens-charles       0
# alexandre-jesus      0
# wellington-luis      0
# thiago-sa            0
# henrique-cardoso     0
# pedro-alex           0
# israel-sousa         0
# lucas-valle          0
# diogo-sampaio        0
# celso-vinicius       0
# bruno-matias         0
# gilbert-burns        0
# levi-jones           0
# yan-lucas            0
# leo-nogueira         0
# marcos-martins       0
# gabriel-costa        0
# gabriel-henrique     0
# braga-neto           0
# rodrigo-tatu         0
# ademir-barreto       0
# rafael-anjos         0
# mikey-musumeci       0
# valdir-araujo        0
# leo-silva            0
# rodrigo-fajardo      0
# ruan-oliveira        0
# mauricio-oliveira    0
# yago-souza           0
# alan-finfou          0
# eldar-rafigaev       0
# orlando-castillo     0
# leandro-lima         0
# catriel-oliveira     0
# gabriel-oliveira     0
# g.-lambertucci       0
# claudio-mattos       0
# inacio-santos        0
# bill-cooper          0
# luis-oliveira        0
# faisal-alkitbe       0
# marcio-cruz          0
# marcos-costa         0
# Name: count, dtype: int64
#                fighter  fight_id        opponent result       competition  \
# 0         adam-ferrara     14004      joao-miyao      L     No Gi Pan Am.
# 1         adam-ferrara     14630    silvio-duran      L   Cincinnati Open
# 2         adam-ferrara     15144   thiago-macedo      L      Houston Open
# 3         adam-ferrara     15583      rene-lopez      L  Chicago Sp. Open
# 4         adam-ferrara     16392   thiago-macedo      L         Miami SPO
# ...                ...       ...             ...    ...               ...
# 55183  vinicius-garcia     22014     cody-heller      W   Atlanta SM Open
# 55184  vinicius-garcia     23363  daniel-olivier      W  New Orleans Open
# 55185  vinicius-garcia     23371  joshua-murdock      W  New Orleans Open
# 55186  vinicius-garcia     24039   kyle-raemisch      W           F2W 153
# 55187  vinicius-garcia     24236    kevin-vieira      W      Pan American
#
#       weight  year
# 0       61KG  2017
# 1       70KG  2017
# 2       70KG  2018
# 3       64KG  2018
# 4       70KG  2018
# ...      ...   ...
# 55183    ABS  2019
# 55184   88KG  2020
# 55185    ABS  2020
# 55186   85KG  2020
# 55187   82KG  2020
#
# [54641 rows x 7 columns]

# %%
df_fights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54641 entries, 0 to 55187
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fighter      54641 non-null  category
#  1   fight_id     54641 non-null  int64
#  2   opponent     54641 non-null  category
#  3   result       54641 non-null  object
#  4   competition  54641 non-null  object
#  5   weight       54641 non-null  object
#  6   year         54641 non-null  int64
# dtypes: category(2), int64(2), object(3)
# memory usage: 3.1+ MB

# %%
from rapidfuzz import process, fuzz
import pandas as pd

# 1. Garante que as colunas sejam do tipo string (resolve o erro)
df_fights['opponent'] = df_fights['opponent'].astype(str)
df_fights['fighter'] = df_fights['fighter'].astype(str)

# 2. Nomes únicos da coluna opponent (removendo nulos)
opponent_names = df_fights['opponent'].dropna().unique().tolist()
threshold = 85
matches = {}

# 3. Mapa com nomes corretos (quando opponent == fighter)
opponent_fighter_map = (
    df_fights[df_fights['opponent'] == df_fights['fighter']]
    [['opponent', 'fighter']]
    .drop_duplicates()
    .set_index('opponent')['fighter']
    .to_dict()
)

# 4. Encontra variações ortográficas
for name in opponent_names:
    initial = name.split('-', 1)[0][0]  # primeira letra do primeiro nome
    raw_matches = process.extract(name, opponent_names, scorer=fuzz.token_sort_ratio, limit=10)

    similares = [
        (match, score)
        for match, score, _ in raw_matches
        if score >= threshold
        and match != name
        and match.split('-', 1)[0][0] == initial
    ]

    if similares:
        matches[name] = similares

# 5. Gera sugestões baseadas na coluna 'fighter'
correcoes_sugeridas = {}

for nome_errado, similares in matches.items():
    candidatos_validos = [s for s, _ in similares if s in opponent_fighter_map]

    if candidatos_validos:
        nome_correto = opponent_fighter_map[candidatos_validos[0]]
        correcoes_sugeridas[nome_errado] = nome_correto
    else:
        correcoes_sugeridas[nome_errado] = similares[0][0]

# 6. Exibe as sugestões
print("Sugestões de correção (sem aplicar):")
for errado, certo in correcoes_sugeridas.items():
    print(f"'{errado}' ➜ '{certo}'")
# Out:
# Sugestões de correção (sem aplicar):
# 'silvio-duran' ➜ 'sivio-duran'
# 'thiago-macedo' ➜ 'tiago-macedo'
# 'rene-lopez' ➜ 'renan-lopez'
# 'rodrigo-francioni' ➜ 'rodrigo-francione'
# 'rodrigo-oliveira' ➜ 'rodrigo-limera'
# 'martin-davilla' ➜ 'martin-davila'
# 'felipe-pena-preguica' ➜ 'felipe-preguica'
# 'yuri-simoes' ➜ 'yuri-simes'
# 'igor-silva' ➜ 'igor-da-silva'
# 'jackson-sousa' ➜ 'jackson-souza'
# 'abdulbary-guseinov' ➜ 'abdulbari-guseinov'
# 'basel-fanous' ➜ 'basel-fanos'
# 'kamil-umiski' ➜ 'kamil-uminski'
# 'nicolas-penzer' ➜ 'nicholas-penzer'
# 'pouya-rahman' ➜ 'pouya-rahmani'
# 'quentin-rosensweig' ➜ 'quentin-rosenzweig'
# 'neiman-gracie' ➜ 'nieman-gracie'
# 'joao-soares' ➜ 'jason-soares'
# 'jonathan-satava' ➜ 'johnathan-satava'
# 'mahamed-aly' ➜ 'mahamad-aly'
# 'james-puopolo' ➜ 'james-poupolo'
# 'victor-hugo' ➜ 'vitor-hugo'
# 'vitor-schlosser' ➜ 'victor-schlosser'
# 'ricardo-bastos' ➜ 'rico-bastos'
# 'joseph-cashin' ➜ 'joe-cashin'
# 'wellington-peroto' ➜ 'wellington-perotto'
# 'leo-davila' ➜ 'leo-davilla'
# 'samir-abdolkader' ➜ 'samir-abdolakder'
# 'eliot-marshall' ➜ 'eliot-marshal'
# 'christian-simmerling' ➜ 'chris-simmerling'
# 'josh-bowlin' ➜ 'josh-bowling'
# 'kaliffa-oliviera' ➜ 'kaliffa-oliveira'
# 'leo-davilla' ➜ 'leo-davila'
# 'matt-kirchwhem' ➜ 'matt-kirchwehm'
# 'kenneth-brown' ➜ 'keneth-brown'
# 'rodrigo-freitas' ➜ 'rodrigo-farias'
# 'nicholas-penzer' ➜ 'nicolas-penzer'
# 'tom-deblass' ➜ 'tom-debass'
# 'kevin-gallager' ➜ 'kevin-gallagher'
# 'ricardo-abreu' ➜ 'ricard-abreu'
# 'lucasz-gustaw' ➜ 'lucas-gustaw'
# 'briean-beaury' ➜ 'brian-beaury'
# 'todd-mueckenheim' ➜ 'todd-muckenheim'
# 'guybson-sa' ➜ 'gybson-sa'
# 'quentin-rosenzweig' ➜ 'quentin-rosensweig'
# 'john-hansen' ➜ 'jon-hansen'
# 't.-ruotolo' ➜ 'tye-ruotolo'
# 'gabriel-sousa' ➜ 'gabriel-souza'
# 'francisco-cuneo' ➜ 'francisco-cueno'
# 'thiago-barbosa' ➜ 'thiago-rosa'
# 'fred-alves' ➜ 'fredson-alves'
# 'joshua-presley' ➜ 'joshua-prestley'
# 'charles-murdock' ➜ 'charles-murdoch'
# 'spencer-nogawa' ➜ 'spenser-nogawa'
# 'brandon-walensky' ➜ 'brandon-walenski'
# 'tomoshige-sera' ➜ 'tomoshigue-sera'
# 'orlando-andaviza' ➜ 'orlando-andavi'
# 'luan-da-silva' ➜ 'luanna-silva'
# 'giovani-marcelo' ➜ 'giovanni-marcelo'
# 'victor-paschoal' ➜ 'vitor-paschoal'
# 'edward-hohl' ➜ 'eduard-hohl'
# 'bradley-hill' ➜ 'bredley-hill'
# 'felipe-makoto' ➜ 'felipe-matos'
# 'huthayfah-penney' ➜ 'huthayfa-penney'
# 'dany-vega' ➜ 'danny-vega'
# 'damion-oranday' ➜ 'damion-orlanday'
# 'jon-calestine' ➜ 'j.-calestine'
# 'cameron-mellott' ➜ 'cameron-melott'
# 'jay-rodriguez' ➜ 'jay-rodrigues'
# 'q.-rosenzweig' ➜ 'q.-roszenweig'
# 'jb-bechtloff' ➜ 'jb-bechloff'
# 'alexandre-ribeiro' ➜ 'andre-ribeiro'
# 'dimitrius-souza' ➜ 'dimitrus-souza'
# 'marcos-souza' ➜ 'marco-souza'
# 'raphael-souza' ➜ 'rafael-souza'
# 'fernando-reis' ➜ 'fernando-ribas'
# 'jonnatas-gracie' ➜ 'jonatas-gracie'
# 'josh-hinger' ➜ 'joshua-hinger'
# 'luan-azevedo' ➜ 'luciano-azevedo'
# 'roosevelt-sousa' ➜ 'roosevel-sousa'
# 'francisco-lo' ➜ 'francisco-leon'
# 'bruno-lima' ➜ 'breno-lima'
# 'marian-klosowski' ➜ 'marcin-klonowski'
# 'pawel-nedzi' ➜ 'pawe-nedzi'
# 'tomasz-skorkowski' ➜ 'tomasz-skorowski'
# 'tomasz-skorowski' ➜ 'tomasz-skorkowski'
# 'arturo-salas' ➜ 'arturi-salas'
# 'rodolfo-bonfim' ➜ 'rodolpho-bonfim'
# 'matheus-rodrigues' ➜ 'mateus-rodrigues'
# 'lucio-rodrigues' ➜ 'luciano-rodrigues'
# 'rodrigo-reis' ➜ 'rodrigo-freitas'
# 'diego-herzog' ➜ 'diego-hertzog'
# 'luan-arouca' ➜ 'luan-rocha'
# 'wellinton-modena' ➜ 'wellington-modena'
# 'joachim-sveinson' ➜ 'joachim-svenson'
# 'marek-zbrog' ➜ 'marerk-zbrog'
# 'gustavo-saraiva' ➜ 'gustavo-silva'
# 'maciej-kozak' ➜ 'maciek-kozak'
# 'patryk-wysoki' ➜ 'patryk-wysocki'
# 'wesley-arquete' ➜ 'wesley-archete'
# 'tyrone-gonsalves' ➜ 'tyrone-goncalves'
# 'mathias-ribeiro' ➜ 'matias-ribeiro'
# 'andre-reis' ➜ 'andre-freitas'
# 'basel-famous' ➜ 'basel-fanous'
# 'manuel-oliveira' ➜ 'manoel-oliveira'
# 'm.-maciejwski' ➜ 'm.-maciejewski'
# 'steeve-combourg' ➜ 'steev-combourg'
# 'stan-varshavskiy' ➜ 'stan.-varshavskiyi'
# 'lukasz-michalec' ➜ 'luckasz-michalec'
# 'sergio-rios' ➜ 'sergio-iris'
# 'tony-ferraz' ➜ 'toni-ferraz'
# 'anton-minenko' ➜ 'anton-mikenko'
# 'silviu-natasha' ➜ 'silviu-nastasa'
# 'abdulbari-guseinov' ➜ 'abdulbary-guseinov'
# 'karol-dzieniszewski' ➜ 'karol-dzienisze'
# 'marcus-ruiz' ➜ 'marcos-ruiz'
# 'almog-britsch' ➜ 'almog-britch'
# 'thiago-dalcol' ➜ 'thiag-dalcol'
# 'marcus-junior' ➜ 'marcos-junior'
# 'pedro-elias' ➜ 'pedro-dias'
# 'pawe-kwiatkowski' ➜ 'p.-kwiatkowski'
# 'todd-muckenheim' ➜ 'todd-mueckenheim'
# 'elliot-kelly' ➜ 'eliot-kelly'
# 'guthierry-barbosa' ➜ 'guthiery-barbosa'
# 'marlon-ferreira' ➜ 'marcelo-ferreira'
# 'alex-alexandrov' ➜ 'a.-alexandrov'
# 'eric-bergmann' ➜ 'erick-bergmann'
# 'gyula-szabo' ➜ 'gyla-szabo'
# 'vegard-vanderberg' ➜ 'vegard-randeberg'
# 'shane-fishman' ➜ 'sean-fishman'
# 'lucasz-michalec' ➜ 'luckasz-michalec'
# 'filipe-pinheiro' ➜ 'felipe-pinheiro'
# 'igor-sousa' ➜ 'igor-souza'
# 'roberto-jimenez' ➜ 'robert-jimenez'
# 'felipe-pimentel' ➜ 'filipe-pimentel'
# 'marcos-junior' ➜ 'marco-junior'
# 'mateus-rodrigues' ➜ 'matheus-rodrigues'
# 'mckenzie-morales' ➜ 'mackenzie-morales'
# 'vegard-randeberg' ➜ 'vegard-vanderberg'
# 'marcos-carrozzino' ➜ 'macos-carrozzino'
# 'mourece-ramirez' ➜ 'mourice-ramirez'
# 'gialysson-freitas' ➜ 'gialyson-freitas'
# 'rafael-fernando' ➜ 'rafael-fernandes'
# 'charles-adorian' ➜ 'charlie-adorian'
# 'aj-agazarm' ➜ 'a.-agazarm'
# 'daniel-garcia' ➜ 'daniel-marciano'
# 'tiago-reinaldo' ➜ 'thiago-reinaldo'
# 'keneth-brown' ➜ 'kenneth-brown'
# 'raphael-goulart' ➜ 'rafael-goulart'
# 'gabriel-toribio' ➜ 'gabriel-timbo'
# 'daniel-tsatsos' ➜ 'daniel-statsos'
# 'gustavo-dias' ➜ 'gustavo-elias'
# 'victor-nithael' ➜ 'victor-nathiel'
# 'alex-sodre' ➜ 'alex-soares'
# 'natan-chueng' ➜ 'nathan-chueng'
# 'leandro-rounaud' ➜ 'leandro-rounaud-lima'
# 'joao-mendes' ➜ 'joao-menezes'
# 'patrick-possamai' ➜ 'parick-possami'
# 'diogo-reis' ➜ 'diogo-freitas'
# 'adrian-sozisz' ➜ 'adrian-kozisz'
# 'jonatham-silva' ➜ 'jonatas-silva'
# 'kevin-mahecha' ➜ 'kevin-machecha'
# 'pablo-lavaselli' ➜ 'pablo-lavaseli'
# 'gustavo-oliveira' ➜ 'gustavo-vieira'
# 'mario-silva' ➜ 'marcio-silva'
# 'krysztof-flak' ➜ 'krzysztof-flak'
# 'tyrone-elliott' ➜ 'tyrone-elliot'
# 'luiz-santos' ➜ 'luis-santos'
# 'vinicius-pereira' ➜ 'vinicius-ferreira'
# 'murilo-silva' ➜ 'mario-silva'
# 'marlus-salgado' ➜ 'marlos-salgado'
# 'jp-rocha' ➜ 'j.-rocha'
# 'isaias-higino' ➜ 'isaias-higinio'
# 'rehan-muttalib' ➜ 'rehan-mutalib'
# 'tiago-macedo' ➜ 'thiago-macedo'
# 'sebastian-serpa' ➜ 'sebastiano-serpa'
# 'gabriel-olinto' ➜ 'gabriell-olinto'
# 'guilherme-rocha' ➜ 'guilherme-bacha'
# 'william-shannon' ➜ 'william-shanon'
# 'kaisar-saulebayev' ➜ 'kaiser-saulebayev'
# 'jared-dopp' ➜ 'jarred-dopp'
# 'andre-rudolfo' ➜ 'andre-rodolfo'
# 'henrique-russi' ➜ 'henrique-rossi'
# 'antonio-assef' ➜ 'antonio-asseff'
# 'ailson-ferraz' ➜ 'alisson-ferraz'
# 'ramon-marques' ➜ 'ruan-marques'
# 'raul-gomes' ➜ 'raul-gomez'
# 'lucas-pinheiro' ➜ 'luan-pinheiro'
# 'lincoln-silva' ➜ 'lincon-silva'
# 'thalison-soares' ➜ 'talison-soares'
# 'mateus-porto' ➜ 'matheus-porto'
# 'andrew-soares' ➜ 'andre-soares'
# 'franciedson-costa' ➜ 'francielo-costa'
# 'marcelo-oliveira' ➜ 'marcos-oliveira'
# 'luiz-costa' ➜ 'luiz-tosta'
# 'nobuhiro-sawada' ➜ 'nobohiro-sawada'
# 'marcio-nascimento' ➜ 'maria-nascimento'
# 'jailson-santos' ➜ 'jadson-santos'
# 'andreza-costa' ➜ 'andre-costa'
# 'fiona-mortel' ➜ 'fiona-mortell'
# 'anna-rodrigues' ➜ 'alan-rodrigues'
# 'sophia-cassella' ➜ 'sophia-cassaella'
# 'faisal-kitbe' ➜ 'faisal-elkitbe'
# 'rodolfo-vieira' ➜ 'rofolfo-vieira'
# 'alexandre-souza' ➜ 'alexandre-sousa'
# 'leonardo-vieira' ➜ 'leonardo-oliveira'
# 'lucas-leite' ➜ 'lucas-laet'
# 'jonatas-novaes' ➜ 'jonnatas-novaes'
# 'roberto-satoshi' ➜ 'robert-santos'
# 'otavio-sousa' ➜ 'otavio-souza'
# 'rafael-pereira' ➜ 'rafael-ferreira'
# 'marcio-andre' ➜ 'mario-andre'
# 'stephen-martinez' ➜ 'stephan-martinez'
# 'jake-mackenzie' ➜ 'jake-mckenzie'
# 'jose-carlos' ➜ 'jose-cardoso'
# 'marcelo-fausto' ➜ 'marcelo-augusto'
# 'thiago-cintra' ➜ 'tiago-cintra'
# 'andrew-alexander' ➜ 'andrew-alexandre'
# 'joshua-mckinney' ➜ 'josh-mckinney'
# 'davis-asare' ➜ 'dave-asare'
# 'oliver-geddes' ➜ 'oliver-geddess'
# 'antonio-antnioli' ➜ 'antonio-antonioli'
# 'denny-prokopos' ➜ 'dennis-prokopos'
# 'diogo-freitas' ➜ 'diogo-reis'
# 'steven-barnett' ➜ 'steven-barrett'
# 'peter-runez' ➜ 'peter-cruz'
# 'enrico-cocco' ➜ 'erico-cocco'
# 'uknown' ➜ 'unknown'
# 'briklin-welch' ➜ 'bricklin-welch'
# 'paulo-henrique' ➜ 'pablo-henrique'
# 'ralf-carneburn' ➜ 'ralf-carneborn'
# 'mauricio-henrique' ➜ 'mario-henrique'
# 'washington-lima' ➜ 'washington-luis'
# 'antonio-antonioli' ➜ 'antonio-antoniolli'
# 'marcel-goncalves' ➜ 'marcelo-goncalves'
# 'jorge-elias' ➜ 'jorge-luis'
# 'nik-nikolaisen' ➜ 'nic-nikolaisen'
# 'luiz-rosa' ➜ 'luis-rosa'
# 'luan-carvalho' ➜ 'lucas-carvalho'
# 'daniel-strauss' ➜ 'dan-strauss'
# 'felipe-cesar' ➜ 'filipe-cesar'
# 'pedro-henrique' ➜ 'pedro-henriques'
# 'itua-sales' ➜ 'itua-salles'
# 'nicollas-welker' ➜ 'nichollas-welker'
# 'piter-frank' ➜ 'peter-frank'
# 'bret-russel' ➜ 'bret-russell'
# 'ronald-henderson' ➜ 'ron-henderson'
# 'stanley-rosa' ➜ 'staley-rosa'
# 'issa-able' ➜ 'isa-able'
# 'samuel-dias' ➜ 'samuel-davis'
# 'nicky-ryan' ➜ 'nick-ryan'
# 'lachlan-giles' ➜ 'lachlan-gile'
# 'marcos-galvao' ➜ 'marco-galvao'
# 'daniel-seth' ➜ 'daniel-leith'
# 'zachary-legates' ➜ 'zachary-lecates'
# 'cody-orrison' ➜ 'cody-orrisson'
# 'gustavo-campos' ➜ 'guto-campos'
# 'tarsis-humphreys' ➜ 'tarsys-humphreys'
# 'eduardo-rios' ➜ 'eduardo-ramos'
# 'renato-morais' ➜ 'renato-moraes'
# 'max-carvalho' ➜ 'm.-carvalho'
# 'julien-cazier' ➜ 'julien-crazier'
# 'alan-oliveira' ➜ 'alvaro-oliveira'
# 'filipe-brobrick' ➜ 'filipe-bobrick'
# 'benji-silva' ➜ 'benjamin-silva'
# 'rodrigo-gortari' ➜ 'rodrigo-gortati'
# 'vincent-pezzuto' ➜ 'vince-pezzuto'
# 'jz-cavalcante' ➜ 'jz-cavalcanti'
# 'donald-stoner' ➜ 'don-stoner'
# 'rhehan-silva' ➜ 'rehan-silva'
# 'saul-viayra' ➜ 'saul-viarya'
# 'j-piersma' ➜ 'jon-piersma'
# 'danny-stolfy' ➜ 'danny-stolfi'
# 'dylan-garofalo' ➜ 'dylan-garafalo'
# 'isa-able' ➜ 'issa-able'
# 'harrison-woods' ➜ 'harrison-wood'
# 'ricardo-pena' ➜ 'ricardo-rea'
# 'matheus-luna' ➜ 'matheus-cunha'
# 'chris-wocjik' ➜ 'chris-wojick'
# 'bruno-tosto' ➜ 'bruno-tostes'
# 'tarik-hopstock' ➜ 'tarik-hopstok'
# 'endres-barbosa' ➜ 'esdras-barbosa'
# 'lucas-brito' ➜ 'luis-brito'
# 'harryson-pereira' ➜ 'harrysson-pereira'
# 'alehander-mariano' ➜ 'alejander-mariano'
# 'andre-costa' ➜ 'andreza-costa'
# 'gustav-apee' ➜ 'gustavo-epee'
# 'diego-pato' ➜ 'diego-sato'
# 'thiago-gaia' ➜ 'tiago-gaia'
# 'tommi-pulkkanen' ➜ 'tommi-pulkkannen'
# 'tyson-antillon' ➜ 'tyson-atillon'
# 'juan-kleber' ➜ 'juan-cleber'
# 'clay-mayfield' ➜ 'clayton-mayfield'
# 'fabricio-barbarotti' ➜ 'fabricio-barbaroti'
# 'chris-gores' ➜ 'chris-graves'
# 'carlos-andre' ➜ 'carlos-andrade'
# 'rafael-silveira' ➜ 'rafael-silva'
# 'ricardo-briceno' ➜ 'ricardo-brito'
# 'renan-muttalib' ➜ 'rehan-muttalib'
# 'joao-marcio' ➜ 'joao-marco'
# 'thiago-andrade' ➜ 'tiago-andrade'
# 'sophia-casella' ➜ 'sophia-cassella'
# 'andressa-morais' ➜ 'andreza-morais'
# 'alexa-trevino' ➜ 'alexandra-trevino'
# 'cindy-ung' ➜ 'cindy-hung'
# 'andrea-amaro' ➜ 'andrea-mario'
# 'vitor-cheloni' ➜ 'vitor-chelloni'
# 'jose-neto' ➜ 'jose-bisneto'
# 'vinicius-lessa' ➜ 'vinicius-jesus'
# 'rafael-oliveira' ➜ 'rafael-silveira'
# 'bruno-veloso' ➜ 'brenno-veloso'
# 'diogo-almeida' ➜ 'diego-almeida'
# 'rafael-souza' ➜ 'rafael-sousa'
# 'vinicius-reis' ➜ 'vinicius-soares'
# 'alexandre-rocha' ➜ 'alexandre-soca'
# 'ramon-rosa' ➜ 'raimon-rosa'
# 'hugo-gambino' ➜ 'hugo-gabino'
# 'matheus-felipe' ➜ 'matheus-felix'
# 'thiago-pessoa' ➜ 'tiago-pessoa'
# 'karol-kania' ➜ 'karol-kaina'
# 'erick-diovano' ➜ 'erick-diovanni'
# 'vinicius-martins' ➜ 'vinicius-marinho'
# 'leonardo-souza' ➜ 'leonardo-moura'
# 'joao-rodrigues' ➜ 'jay-rodrigues'
# 'leon-brito' ➜ 'leo-brito'
# 'everton-freitas' ➜ 'evertom-freitas'
# 'tiago-andrade' ➜ 'thiago-andrade'
# 'marcello-lemelle' ➜ 'marcelo-lemelle'
# 'manoel-porto' ➜ 'manuel-porto'
# 'b.-georgy' ➜ 'b.-george'
# 'roberto-roberto' ➜ 'roberto-ribeiro'
# 'thomas-johanssen' ➜ 'thomas-johanessen'
# 'rafael-goulart' ➜ 'raphael-goulart'
# 'leo-d'avila' ➜ 'leo-davila'
# 'william-lima' ➜ 'william-de-lima'
# 'morrys-ayala' ➜ 'morris-ayala'
# 'diego-borges' ➜ 'diogo-borges'
# 'carlos-farias' ➜ 'carlinhos-faria'
# 'otavio-nalati' ➜ 'otavio-nalatti'
# 'sam-wells' ➜ 'samuel-wells'
# 'martin-gonzalez' ➜ 'mario-gonzalez'
# 'jhonathan-marques' ➜ 'jonathan-ares'
# 'joshua-guerra' ➜ 'josh-guerra'
# 'wallisson-oliveira' ➜ 'wallison-oliveira'
# 'heitor-senra' ➜ 'heltor-senra'
# 'mateus-moraes' ➜ 'matheus-moraes'
# 'vinicius-marinho' ➜ 'vinicius-marilho'
# 'chaise-olimpio' ➜ 'chairo-olimpio'
# 'marcos-aurelio' ➜ 'marco-aurelio'
# 'david-raab' ➜ 'davi-raab'
# 'ygor-rodrigues' ➜ 'yago-rodrigues'
# 'wellington-marques' ➜ 'welington-marques'
# 'alexandre-pereira' ➜ 'alexsandro-pereira'
# 'o.-kasimov' ➜ 'o.-kassimov'
# 'pedro-farias' ➜ 'pedro-farkas'
# 'christian-dellevag' ➜ 'cristian-dellavag'
# 'chairo-olimpio' ➜ 'chaise-olimpio'
# 'jose-dias' ➜ 'jose-diaz'
# 'fabricio-barbosa' ➜ 'fabricio-barros'
# 'luis-domingos' ➜ 'lucas-domingos'
# 'alexandre-vaz' ➜ 'alexandre-paiva'
# 'vitor-matos' ➜ 'victor-matos'
# 'joao-melo' ➜ 'joao-marcelo'
# 'luan-silva' ➜ 'luanna-silva'
# 'fabricio-barbaroti' ➜ 'fabricio-barbarotti'
# 'eric-souza' ➜ 'erick-souza'
# 'fernando-mano' ➜ 'fernando-matos'
# 'royler-gracie' ➜ 'roger-gracie'
# 'marco-barbosa' ➜ 'mario-barbosa'
# 'marcelo-mendes' ➜ 'marco-mendes'
# 'wellington-dias' ➜ 'wellington-lima'
# 'robin-gracie' ➜ 'robson-gracie'
# 'octavio-couto' ➜ 'otavio-coutinho'
# 'sasha-palvski' ➜ 'sasha-plavski'
# 'fernando-lopes' ➜ 'fernando-gomes'
# 'sasha-plavski' ➜ 'sasha-palvski'
# 'joe-gilbert' ➜ 'joey-gilbert'
# 'hugo-marques' ➜ 'higor-marques'
# 'filipe-cesar' ➜ 'felipe-cesar'
# 'lucas-rocha' ➜ 'luan-rocha'
# 'andre-gois' ➜ 'andre-goes'
# 'lucas-moutinho' ➜ 'lucas-foguinho'
# 'daniel-maira' ➜ 'daniel-baia'
# 'johnathan-satava' ➜ 'jonathan-satava'
# 'sean-fisher' ➜ 'sean-fischer'
# 'carlos-neto' ➜ 'carlos-newton'
# 'levi-jones-leary' ➜ 'levi-j-leary'
# 'michael-neary' ➜ 'micheal-neary'
# 'jakub-najdek' ➜ 'jakub-bajdek'
# 'eliot-kelly' ➜ 'elliot-kelly'
# 'fabricio-pitittio' ➜ 'fabio-pititto'
# 'lucas-foguinho' ➜ 'lucas-moutinho'
# 'gabriel-avila' ➜ 'ganriel-avila'
# 'rodrigo-praia' ➜ 'rodrigo-paixao'
# 'marcelo-lemelle' ➜ 'marcello-lemelle'
# 'jeferson-ramos' ➜ 'jefferson-ramos'
# 'leonardo-oliveira' ➜ 'leonardo-vieira'
# 'weslei-possamai' ➜ 'wesley-possamai'
# 'andre-lipienski' ➜ 'andre-lipenski'
# 'italo-oliveira' ➜ 'icaro-oliveira'
# 'wesley-possamai' ➜ 'weslei-possamai'
# 'javier-barter' ➜ 'javi-barter'
# 'jose-bisneto' ➜ 'jose-neto'
# 'wallisson-souza' ➜ 'wallison-souza'
# 'gabriell-olinto' ➜ 'gabriel-olinto'
# 'matheus-pereira' ➜ 'mateus-pereira'
# 'sean-goolsby' ➜ 'sean-golbsy'
# 'joian-silva' ➜ 'jocsan-silva'
# 'leandro-rounaud-lima' ➜ 'leandro-rounaud'
# 'luis-eduhardo' ➜ 'luis-eduardo'
# 'rafael-barbosa' ➜ 'rafael-babosa'
# 'diego-silva' ➜ 'diogo-silva'
# 'm.-abdulkadirov' ➜ 'm.-abdulkaridov'
# 'gabriel-ferreira' ➜ 'gabriela-pereira'
# 'lautaro-sanguimene' ➜ 'lautaro-sanguime'
# 'bricklin-welsh' ➜ 'bricklin-welch'
# 'jeffrey-cummings' ➜ 'jeff-cummings'
# 'bricklin-welch' ➜ 'briklin-welch'
# 'breno-bittencourt' ➜ 'breno-bitencourt'
# 'james-guyton' ➜ 'james-guion'
# 'gustavo-epee' ➜ 'gustav-espee'
# 'danilo-silva' ➜ 'daniel-silva'
# 'khristofer-santos' ➜ 'khristopher-santos'
# 'kristopher-santos' ➜ 'khristopher-santos'
# 'cesar-casamajo' ➜ 'cesar-caramajo'
# 'nicolas-renier' ➜ 'nicholas-renier'
# 'felipe-desouza' ➜ 'filipe-desouza'
# 'joshua-bacallao' ➜ 'josh-bacallao'
# 'murat-besnet' ➜ 'murat-besnek'
# 'john-lennon' ➜ 'john-lenno'
# 'ayub-mugamedov' ➜ 'ayub-mogamadov'
# 'kenji-sette' ➜ 'keji-sette'
# 'cesar-miyahira' ➜ 'cesar-miahira'
# 'adria-perez' ➜ 'adam-perez'
# 'joseph-breslin' ➜ 'joe-breslin'
# 'tyson-antillom' ➜ 'tyson-antillon'
# 'jonothan-maflin' ➜ 'jonathan-maflin'
# 'fernando-cabrera' ➜ 'ferando-cabrera'
# 'kevin-melendez' ➜ 'kevin-melendrez'
# 'brandon-wilkinson' ➜ 'brandon-wilson'
# 'fernando-soares' ➜ 'fernando-reis'
# 'edmund-kim' ➜ 'edmond-kim'
# 'matheus-galvao' ➜ 'matheus-galacio'
# 'desond-mcdonald' ➜ 'desmond-mcdonald'
# 'gustavo-estebam' ➜ 'gustavo-esteban'
# 'chris-passerrello' ➜ 'chris-passarrello'
# 'guilherme-higinio' ➜ 'guilherme-higino'
# 'guilherme-higuchi' ➜ 'guilherme-higuino'
# 'a.-cacareco' ➜ 'alex.-cacareco'
# 'roger-gracie' ➜ 'roger-graci.'
# 'marcelo-garcia' ➜ 'marcelinho-garcia'
# 'marcio-corleta' ➜ 'marcio-corletta'
# 'dennis-gomes' ➜ 'denis-gomes'
# 'erik-wanderlei' ➜ 'eric-wanderlei'
# 'elliott-marshall' ➜ 'eliot-marshall'
# 'john-einimo' ➜ 'jon-einemo'
# 'antoine-joude' ➜ 'antoine-jaoude'
# 'ricardo-morais' ➜ 'ricardo-moraes'
# 'yukissyu-ozawa' ➜ 'yukiyasu-ozawa'
# 'cristiano-lazzarini' ➜ 'cristiano-lazzarinni'
# 'luiz-theodoro' ➜ 'luis-theodoro'
# 'gabriel-vella' ➜ 'gabriel-vilella'
# 'dan-simmler' ➜ 'daniel-simmler'
# 'chris-moriarity' ➜ 'chris-moriarty'
# 'ryan-beaugeard' ➜ 'ryan-beauregard'
# 'eduardo-silva' ➜ 'eduardo-silveira'
# 'alexandre-ceconi' ➜ 'alexadre-ceconi'
# 'yukiyasu-ozawa' ➜ 'yukissyu-ozawa'
# 'karim-khalifa' ➜ 'karim-kalifah'
# 'marcus-santos' ➜ 'marcos-santos'
# 'basel-fanos' ➜ 'basel-fanous'
# 'jose-henrique' ➜ 'jonas-henrique'
# 'emiliano-simone' ➜ 'emiliani-simeone'
# 'giovanne-della' ➜ 'giovanni-della'
# 'emiliani-simeone' ➜ 'emiliano-simone'
# 'rodrigo-limera' ➜ 'rodrigo-lima'
# 'john-salter' ➜ 'john-slater'
# 'rustam-chsiev' ➜ 'ruslam-chsiev'
# 'andre-santos' ➜ 'alexandre-santos'
# 'marcos-ruiz' ➜ 'marcus-ruiz'
# 'fernando-carsadale' ➜ 'fernando-carsalade'
# 'vitor-moraes' ➜ 'victor-moraes'
# 'rodrigo-dias' ➜ 'rodrigo-modrias'
# 'victor-moraes' ➜ 'vitor-moraes'
# 'victor-dias' ➜ 'victor-doria'
# 'bruno-celio' ➜ 'breno-celio'
# 'pedro-neto' ➜ 'pedro-bisneto'
# 'tuomas-tamilehto' ➜ 'tuomas-tammilehto'
# 'raphael-cadena' ➜ 'raphael-cadema'
# 'igor-terreco' ➜ 'igor-terraceo'
# 'esdras-junior' ➜ 'estras-junior'
# 'yago-rodrigues' ➜ 'ygor-rodrigues'
# 'davi-oliveira' ➜ 'david-oliveira'
# 'geoffrey-villarreal' ➜ 'geoffrey-villareal'
# 'fatima-kline' ➜ 'fatima-kleine'
# 'joanie-chamberlain' ➜ 'joanie-chamberland'
# 'haley-zahnow' ➜ 'haley-zhanow'
# 'nicole-matthew' ➜ 'nicole-mathew'
# 'briget-mceliece' ➜ 'bridget-mceliece'
# 'bernardita-campos' ➜ 'bernardo-campos'
# 'eddie-cummings' ➜ 'ed-cummings'
# 'nick-ryan' ➜ 'nicky-ryan'
# 'pablo-silva' ➜ 'paulo-silva'
# 'pedro-dias' ➜ 'pedro-elias'
# 'wellington-lima' ➜ 'wellington-dias'
# 'r.-oliveira' ➜ 'r.-olivier'
# 'juan-lopes' ➜ 'juan-lopez'
# 'juan-lopez' ➜ 'juan-lopes'
# 'audrey-adam' ➜ 'andrey-adam'
# 'paulo-melo' ➜ 'paulo-mello'
# 'perez-figueroa' ➜ 'perez-figueiroa'
# 'mohd-ali-hayat' ➜ 'mo-ali-hayat'
# 'pedro-valenca' ➜ 'pedro-valencia'
# 'ulysses-faguntes' ➜ 'ulysses-fagundes'
# 'alexandre-vieira' ➜ 'alexandre-oliveira'
# 'marcos-santos' ➜ 'marcus-santos'
# 'andrey-adam' ➜ 'audrey-adam'
# 'william-campos' ➜ 'williams-campos'
# 'gui-augusto' ➜ 'g.-augusto'
# 'andre-brito' ➜ 'andre-rico'
# 'l.-lima' ➜ 'l.-lira'
# 'garrett-beck' ➜ 'garett-beck'
# 'sam-mcnally' ➜ 'sam-mc-nally'
# 'eduardo-jesus' ➜ 'eduardo-de-jesus'
# 'higor-lima' ➜ 'hiago-lima'
# 'rodnei-barbosa' ➜ 'rodney-barbosa'
# 'tiago-cintra' ➜ 'thiago-cintra'
# 'gustavo-esteban' ➜ 'gustavo-estebam'
# 'matheus-lima' ➜ 'mateus-lima'
# 'guilherme-dalpra' ➜ 'guilherme-dal-pra'
# 'guilherme-neres' ➜ 'guilherme-neves'
# 'guilherme-silva' ➜ 'guilherme-milan'
# 'edward-lucero' ➜ 'eduard-lucero'
# 'guilherme-fernandes' ➜ 'guilherme-mendes'
# 'marcos-cruz' ➜ 'marcos-ruiz'
# 'anderson-lima' ➜ 'anderson-lira'
# 'tim-hinrichs' ➜ 'tim-hinrich'
# 'jefferson-goteu' ➜ 'jefferson-gomes'
# 'm.-muratazaliev' ➜ 'm.-murtazaliev'
# 'nino-ambrosini' ➜ 'nino-ambrosio'
# 'flavio-serafin' ➜ 'flavio-serafim'
# 'flavio-serafim' ➜ 'flavio-serafin'
# 'dan-schon' ➜ 'don-schon'
# 'sebastien-lecocq' ➜ 'sebastien-lecoq'
# 'jan-basso' ➜ 'jan-baso'
# 'fernando-santos' ➜ 'fernando-matos'
# 'b.-benmahammed' ➜ 'b.-menmahammed'
# 'bilal-benmahammed' ➜ 'bilal-benmahammmed'
# 'joao-bezerra' ➜ 'j-bezerra'
# 'pavel-kalesnik' ➜ 'pavel-kavesnik'
# 'thabet-altaher' ➜ 'thabet-al-taher'
# 'grant-bogdanove' ➜ 'grant-bogdanov'
# 'moolele-cuellar' ➜ 'mooelehe-cuellar'
# 'melisa-cueto' ➜ 'melissa-cueto'
# 'bridget-mceliece' ➜ 'briget-mceliece'
# 'elizabeth-mitrovic' ➜ 'elizabeth-mitrov'
# 'chayse-diekma' ➜ 'chayse-diekema'
# 'maria-ruffatto' ➜ 'maria-ruffato'
# 'melissa-cueto' ➜ 'melisa-cueto'
# 'stephanie-delphine' ➜ 'stephanie-delphin'
# 'leticia-cardozo' ➜ 'leticia-cartozo'
# 'julia-maele' ➜ 'julia-maee'
# 'brittney-elkin' ➜ 'britney-elkin'
# 'fernanda-mazzelli' ➜ 'fernanda-mazzeli'
# 'maria-malyjasiak' ➜ 'maria-malyjasik'
# 'maisa-gurgel' ➜ 'maissa-gurgel'
# 'izadora-cristina' ➜ 'isadora-cristina'
# 'isadora-cristina' ➜ 'izadora-cristina'
# 'graciele-fava' ➜ 'graciele-del-fava'
# 'marcia-karina' ➜ 'maria-karolina'
# 'andreia-cavalcante' ➜ 'andre-cavalcante'
# 'alexia-arantes' ➜ 'alex-arantes'
# 'maria-luiza' ➜ 'maria-luisa'
# 'suelen-desterro' ➜ 'suellen-desterro'
# 'alexandre-paiva' ➜ 'alexandre-silva'
# 'ryan-gracie' ➜ 'ryron-gracie'
# 'akira-shouji' ➜ 'akira-shoji'
# 'thamara-ferreira' ➜ 'thaynara-ferreira'
# 'amy-cadwell' ➜ 'amy-dadwell'
# 'erin-johnson' ➜ 'edin-johnson'
# 'vannessa-griffin' ➜ 'vanessa-griffin'
# 'bethany-wright' ➜ 'brethany-wright'
# 'polyanna-araujo' ➜ 'polyana-araujo'
# 'maria-vicentini' ➜ 'maria-vincentini'
# 'nia-blackman' ➜ 'n.-blackman'
# 'wallace-costa' ➜ 'walllace-costa'
# 'marcelo-monteiro' ➜ 'marcelo-montoro'
# 'maique-azevedo' ➜ 'maique-azavedo'
# 'harrysson-pereira' ➜ 'harryson-pereira'
# 'lucas-silva' ➜ 'luan-silva'
# 'elionai-braz' ➜ 'elioenai-braz'
# 'nicollas-santos' ➜ 'nicolas-santos'
# 'gabriel-martins' ➜ 'gabriel-marinho'
# 'cleyton-flores' ➜ 'cleiton-flores'
# 'julian-stonjek' ➜ 'julian-stonkek'
# 'joao-viera' ➜ 'joao-vieira'
# 'leonardo-rocha' ➜ 'leonardo-brocca'
# 'caio-goncalves' ➜ 'carlos-goncalves'
# 'matheus-oliveira' ➜ 'matheus-d-oliveira'
# 'pedro-maia' ➜ 'pedro-matias'
# 'lucas-santos' ➜ 'lucas-canto'
# 'julian-synan' ➜ 'julian-syan'
# 'thiago-alves' ➜ 'tiago-alves'
# 'thiago-graca' ➜ 'thiago-gaia'
# 'anthony-elbert' ➜ 'anthony-erbert'
# 'clayton-mayfield' ➜ 'clay-mayfield'
# 'gyalisson-freitas' ➜ 'gialysson-freitas'
# 'eduardo-santoro' ➜ 'eduardo-santos'
# 'fernando-piero' ➜ 'fernando-di-piero'
# 'm.-carvalho' ➜ 'max-carvalho'
# 'marcelo-louzado' ➜ 'marcel-louzado'
# 'marco-junior' ➜ 'marcos-junior'
# 'chris-weidman' ➜ 'chris-wideman'
# 'tom-bass' ➜ 'tom-debass'
# 'diego-gamonal' ➜ 'diogo-gamonal'
# 'nol.-dutcher' ➜ 'nolan-dutcher'
# 'rust.-chsiev' ➜ 'rustam-chsiev'
# 'ryron-gracie' ➜ 'rayron-gracie'
# 'james-harbison' ➜ 'james-sargison'
# 'nic-ruben' ➜ 'nik-ruben'
# 'gabriel-rosberg' ➜ 'gabriel-roseberg'
# 'thomas-johannesson' ➜ 'thomas-johannessen'
# 'alexandro-ceconi' ➜ 'alexandre-ceconi'
# 'tiago-pessoa' ➜ 'thiago-pessoa'
# 'felipe-mota' ➜ 'filipe-mota'
# 'thiago-abud' ➜ 'thiago-abreu'
# 'luccas-lira' ➜ 'lucas-lira'
# 'ryan-aitken' ➜ 'ryan-aiken'
# 'jordan-moore' ➜ 'jordan-more'
# 'stuart-maddox' ➜ 'stuart-maddoc'
# 'mackenzie-morales' ➜ 'mckenzie-morales'
# 'nathan-mendelsohn' ➜ 'nathan-mendesohn'
# 'lucas-laet' ➜ 'lucas-leite'
# 'joao-pedrosa' ➜ 'joao-pedro'
# 'andre-cavalcante' ➜ 'andreia-cavalcante'
# 'thiago-santos' ➜ 'tiago-santos'
# 'delson-heleno' ➜ 'delso-heleno'
# 'bryan-peterson' ➜ 'breno-peterson'
# 'stephen-hargett' ➜ 'stephen-hergett'
# 'filipe-pimentel' ➜ 'felipe-pimentel'
# 'dan-martinez' ➜ 'd.-martinez'
# 'sergio-villas' ➜ 'sergio-vilas'
# 'mario-gonzales' ➜ 'mario-gonzalez'
# 'enrique-galarza' ➜ 'enrique-falarza'
# 'daniel-mcguire' ➜ 'daniel-maguire'
# 'b.-george' ➜ 'b.-georgy'
# 'a.-la-montagne' ➜ 'a.-la-montague'
# 'david-stoyle' ➜ 'david-stoil'
# 'chris-wojick' ➜ 'chris-wocjik'
# 'erico-said' ➜ 'enrico-said'
# 'brandon-mandarim' ➜ 'brandon-manarin'
# 'tiago-carvalho' ➜ 'thiago-carvalho'
# 'leonardo-mario' ➜ 'leonardo-martins'
# 'khaled-alshehi' ➜ 'khalel-alshehhi'
# 'xavi-bas' ➜ 'xavier-bas'
# 'klaus-maine' ➜ 'klaus-meine'
# 'matheus-fonseca' ➜ 'mateus-fonseca'
# 'fabio-fernandes' ➜ 'flavio-fernandes'
# 'jefferson-fagundes' ➜ 'jeferson-fagundes'
# 'felipe-lima' ➜ 'felipe-simao'
# 'tadiyah-danforth' ➜ 'tadiyah-danfort'
# 'marko-oikarainen' ➜ 'marko-oikaraine'
# 'omar-alsuwaidi' ➜ 'omar-alswaidi'
# 'matheus-onda' ➜ 'matheus-honda'
# 'isiah-wright' ➜ 'isaiah-right'
# 'victor-silva' ➜ 'vitor-silva'
# 'rafael-domingos' ➜ 'rafael-domngos'
# 'gabriel-santos' ➜ 'gabriela-matos'
# 'daniel-manasoiu' ➜ 'daniel-manasoiou'
# 'damien-anderson' ➜ 'damion-anderson'
# 'fabian-ramirez' ➜ 'fabio-ramirez'
# 'rene-sousa' ➜ 'rene-souza'
# 'rob-winther' ➜ 'robert-winther'
# 'troy-russell' ➜ 'troy-russel'
# 'joshua-squires' ➜ 'josh-squires'
# 'leonardo-domingos' ➜ 'leonardo-domingo'
# 'matheus-ferreira' ➜ 'matheus-pereira'
# 'joao-albuquerque' ➜ 'j.-albuquerque'
# 'anthony-erbert' ➜ 'anthony-elbert'
# 'wallison-oliveira' ➜ 'wallisson-oliveira'
# 'gabriela-pereira' ➜ 'gabriel-ferreira'
# 'dyna-sena' ➜ 'dina-sena'
# 'mika-damaceno' ➜ 'mikaele-damaceno'
# 'ann-kneib' ➜ 'ann-kneibb'
# 'rayanne-santos' ➜ 'raiane-santos'
# 'dina-sena' ➜ 'dyna-sena'
# 'rita-lynne' ➜ 'rita-lynn'
# 'luciane-araujo' ➜ 'luciano-araujo'
# 'ariadne-oliveira' ➜ 'ariadne-de-oliveira'
# 'zofia-szawenowska' ➜ 'zofia-szawernowska'
# 'alicja-stypulkow' ➜ 'alicja-stypukowska'
# 'diego-ferreira' ➜ 'diego-pereira'
# 'brian-beaury' ➜ 'briean-beaury'
# 'johanan-vielma' ➜ 'jhoannan-vielma'
# 'christian-cevallos' ➜ 'christhian-cevallos'
# 'pedro-bisneto' ➜ 'pedro-neto'
# 'dylan-freedman' ➜ 'drylan-freedman'
# 'ryan-beuregard' ➜ 'ryan-beauregard'
# 'saulo-ribeiro' ➜ 'salomao-ribeiro'
# 'egan-inoue' ➜ 'egan-inoe'
# 'rodrigo-teixeira' ➜ 'rodrigo-texieira'
# 'eduardo-macedo' ➜ 'eduardo-machado'
# 'artur-silva' ➜ 'arthur-silva'
# 'lucas-luciano' ➜ 'lucas-luciani'
# 'luan-fernandes' ➜ 'luzia-fernandes'
# 'lucas-queiroz' ➜ 'luciano-queiroz'
# 'luiz-finocchio' ➜ 'luis-finnochio'
# 'yuri-rodrigues' ➜ 'ygor-rodrigues'
# 'lasse-rhakolin' ➜ 'lasse-rahkolin'
# 'victor-futrik' ➜ 'victor-futurik'
# 'adriano-comolese' ➜ 'adriano-camolesi'
# 'matt-jubera' ➜ 'mat-jubera'
# 'stephen-hall' ➜ 'stephen-hal'
# 'marcio-corletta' ➜ 'marcio-corleta'
# 'mick-wilson' ➜ 'mike-wilson'
# 'igor-praporschchikov' ➜ 'i.-praporshchikov'
# 'jose-filho' ➜ 'josete-filho'
# 'marcus-oliveira' ➜ 'marcos-oliveira'
# 'rafhael-borges' ➜ 'rafael-borges'
# 'felipe-costa' ➜ 'felipe-mota'
# 'thiano-alves' ➜ 'thiago-alves'
# 'maicon-silva' ➜ 'mario-silva'
# 'edson-oliveira' ➜ 'edson-de-oliveira'
# 'max-danrlei' ➜ 'max-danrley'
# 'cameron-chafee' ➜ 'cameron-chaffee'
# 'alexandre-santos' ➜ 'alexandre-dantas'
# 'markus-vinicius' ➜ 'marcus-vinicius'
# 'dai-yoshioka' ➜ 'dai-yoshida'
# 'kouhel-ebashi' ➜ 'kouhei-ebashi'
# 'severi-nenonen' ➜ 'severi-nendnen'
# 'jonathan-buren' ➜ 'jonathan-van-buren'
# 'orlando-silva-jr' ➜ 'olando-silva'
# 'kaio-cesar' ➜ 'kayo-cesar'
# 'eduardo-yezeguie' ➜ 'eduardoyezeguie'
# 'isaac-dul' ➜ 'isaac-dull'
# 'patryk-wysocki' ➜ 'patryk-wysoki'
# 'robson-gracie' ➜ 'robin-gracie'
# 'chris-bowe' ➜ 'chris-bowles'
# 'm.-maciejewski' ➜ 'm.-maciejwski'
# 'thomas-johanessen' ➜ 'thomas-johannessen'
# 'marek-zborg' ➜ 'marek-zbrog'
# 'yuji-harai' ➜ 'yuji-arai'
# 'ruben-fonseca' ➜ 'rubens-fonseca'
# 'dinu-bucalet' ➜ 'dino-bucalet'
# 'omar-frederick' ➜ 'omar-frederik'
# 'wesley-caixeta' ➜ 'wesley-caixet'
# 'mile-ivankovic' ➜ 'miles-ivankovic'
# 'alef-silva' ➜ 'allef-silva'
# 'jun-yong-cho' ➜ 'junyong-cho'
# 'michael-marco' ➜ 'michael-demarco'
# 'jose-rios' ➜ 'josh-rios'
# 'vinicius-soares' ➜ 'vinicius-torres'
# 'myke-jesus' ➜ 'mike-jesus'
# 'joao-marco' ➜ 'joao-marcio'
# 'jonathan-thomas' ➜ 'jonathan-tomasian'
# 'dino-bucalet' ➜ 'dinu-bucalet'
# 'gairbeg-ibragimov' ➜ 'gairbek-ibragimov'
# 'eduardo-de-jesus' ➜ 'eduardo-jesus'
# 'riku-hapulahti' ➜ 'riku-hapulathi'
# 'tuomas-tammilehto' ➜ 'tuomas-tamilehto'
# 'jay-butler' ➜ 'jay-buttler'
# 'sergio-hernandez' ➜ 'sergio-hernandes'
# 'jay-buttler' ➜ 'jay-butler'
# 'rafael-freitas' ➜ 'rafael-reis'
# 'kevin-corkhill' ➜ 'kev-corkhill'
# 'lee-renault' ➜ 'lee-renaut'
# 'sean-white' ➜ 'sean-whyte'
# 'lucas-andrade' ➜ 'lukas-andrade'
# 'boris-tonev' ➜ 'bornis-tonev'
# 'chris-sterling' ➜ 'chris-simmerling'
# 'maria-goncalves' ➜ 'mario-goncalves'
# 'eduarda-goncalves' ➜ 'eduardo-goncalves'
# 'mikaela-lima' ➜ 'mika-lima'
# 'roberta-ribeiro' ➜ 'roberto-ribeiro'
# 'anabel-lopez' ➜ 'angel-lopez'
# 'rafael-mendes' ➜ 'rafa-mendes'
# 'guilherme-mendes' ➜ 'guilherme-fernandes'
# 'eduardo-ramos' ➜ 'eduardo-campos'
# 'rodrigo-farias' ➜ 'rodrigo-freitas'
# 'steve-rosenburg' ➜ 'steven-rosenberg'
# 'marcel-gonclaves' ➜ 'marcel-goncalves'
# 'spenser-guilliam' ➜ 'spenser-gilliam'
# 'michel-maia' ➜ 'michael-maia'
# 'nicholas-renier' ➜ 'nicolas-renier'
# 'vitor-paschoal' ➜ 'victor-paschoal'
# 'gabriel-de-oliveira' ➜ 'gabriel-d.-oliveira'
# 'marcos-lopes' ➜ 'marcos-paes'
# 'justin-fabac' ➜ 'justin-labac'
# 'victor-barreto' ➜ 'vitor-barreto'
# 'kevin-berbrich' ➜ 'kevin-berberich'
# 'marcus-guedes' ➜ 'marcus-geddes'
# 'lucas-pollard' ➜ 'lukas-pollard'
# 'ty-freeman' ➜ 't.-freeman'
# 'marcos-oliveira' ➜ 'marcus-oliveira'
# 'sean-golbsy' ➜ 'sean-goolsby'
# 'amir-ghoneim' ➜ 'amr-ghoneim'
# 'rany-yahya' ➜ 'rani-yahya'
# 'mike-davila' ➜ 'mike-davilla'
# 'gustavo-dantas' ➜ 'gustavo-santos'
# 'alexandre-soca' ➜ 'alexandre-souza'
# 'tetsu-suzuko' ➜ 'tetsu-suzuki'
# 'takizawa-keusuke' ➜ 'takezawa-keisuke'
# 'takezawa-keisuke' ➜ 'takizawa-keusuke'
# 'kohei-yasumi' ➜ 'kouhei-yasumi'
# 'juan-bernardo' ➜ 'jakson-bernardo'
# 'alex-eklin' ➜ 'alex-ecklin'
# 'ron-henderson' ➜ 'ronald-henderson'
# 'paulo-cezar' ➜ 'paulo-cesar'
# 'gabriel-sa' ➜ 'gabriel-sousa'
# 'troy-russel' ➜ 'troy-russell'
# 'dan-manasoiu' ➜ 'daniel-manasoiu'
# 'jonathan-tomasian' ➜ 'jonathan-thomas'
# 'charles-parsons' ➜ 'charles-pearson'
# 'leo-souza' ➜ 'leomar-souza'
# 'vinicius-barbosa' ➜ 'vinicius-barros'
# 'kauan-barboza' ➜ 'kaua-barbosa'
# 'saul-viarya' ➜ 'saul-viayra'
# 'felipe-teixeira' ➜ 'felipe-vieira'
# 'hayden-buckner' ➜ 'hayden-bucner'
# 'luan-gomez' ➜ 'luan-gomes'
# 'stephen-martin' ➜ 'stephen-martinez'
# 'bernardo-delibero' ➜ 'berbardo-delibero'
# 'bryce-lamb' ➜ 'bryce-layme'
# 'leonardo-davila' ➜ 'leonardo-vilela'
# 'thiago-souza' ➜ 'thiago-sousa'
# 'luciando-queiroz' ➜ 'luciano-queiroz'
# 'diogo-silva' ➜ 'diego-silva'
# 'christopher-bowe' ➜ 'christopher-powell'
# 'marcos-de-souza' ➜ 'marcos-souza'
# 'lucas-sachs' ➜ 'lucas-sashs'
# 'roger-ambrosi' ➜ 'roger-ambrosio'
# 'gustavo-silva' ➜ 'gustavo-saraiva'
# 'ezra-lenon' ➜ 'erza-lennon'
# 'fernando-vieira' ➜ 'fernando-silveira'
# 'urijah-faber' ➜ 'urija-faber'
# 'marcelo-santos' ➜ 'marcos-santos'
# 'andre-soares' ➜ 'andrew-soares'
# 'dai-yoshida' ➜ 'dai-yoshioka'
# 'carlos-ferreira' ➜ 'carlos-pereira'
# 'marcus-antelante' ➜ 'marcus-antelanti'
# 'dustin-akbari' ➜ 'dustn-akbari'
# 'luiz-gustavo' ➜ 'luis-gustavo'
# 'jason-bukach' ➜ 'jason-bukich'
# 'daniel-tavarez' ➜ 'daniel-tavares'
# 'marcel-louzado' ➜ 'marcelo-louzado'
# 'nolan-dutcher' ➜ 'nol.-dutcher'
# 'felipe-oliveira' ➜ 'felipe-vieira'
# 'jordan-tabor' ➜ 'jordon-tabor'
# 'i.-sanders' ➜ 'ian-sanders'
# 'jake-scovel' ➜ 'joe-scovel'
# 'joe-scovel' ➜ 'joel-scovel'
# 'marvin-castelle' ➜ 'marvin-castell'
# 'felipe-simplicio' ➜ 'filipe-simplicio'
# 'bruno-valdivino' ➜ 'bruno-valdivimo'
# 'takahito-yoshioka' ➜ 'takahiko-yashioka'
# 'eliana-carauni' ➜ 'eli-carauni'
# 'ni-ni-hoang' ➜ 'nini-hoang'
# 'polyana-araujo' ➜ 'polyanna-araujo'
# 'dina-souza' ➜ 'dinei-souza'
# 'serena-gabrielli' ➜ 'serena-gabrieli'
# 'luciane-silva' ➜ 'luan-silva'
# 'lavinia-barbosa' ➜ 'lavinia-barbososa'
# 'rawanna-dasilva' ➜ 'rawanna-silva'
# 'flavia-santos' ➜ 'flavio-santos'
# 'ana-da-silva' ➜ 'ana-silva'
# 'raquel-ferreira' ➜ 'rafael-ferreira'
# 'gabi-mendes' ➜ 'gabriel-mendes'
# 'fredson-alves' ➜ 'fred-alves'
# 'claudia-doval' ➜ 'claudia-do-val'
# 'bianca-mesquita' ➜ 'bia-mesquita'
# 'emilie-thylin' ➜ 'emily-thylin'
# 'e.-karppinen' ➜ 'e.-karpinen'
# 'anidete-ferreira' ➜ 'andre-ferreira'
# 'emilia-tuukanen' ➜ 'emilia-tuukkanen'
# 'larissa-paes' ➜ 'larissa-alves'
# 'ruthe-cathen' ➜ 'ruthe-caten'
# 'christine-mcdonagh' ➜ 'chris-mcdonagh'
# 'elvira-karpinnen' ➜ 'elvira-karppinen'
# 'michelle-nicolini' ➜ 'michele-nicolini'
# 'ruthe-caten' ➜ 'ruthe-cathen'
# 'mikaele-damaceno' ➜ 'mika-damaceno'
# 'thaunay-correa' ➜ 'thauany-correa'
# 'milena-sakumoto' ➜ 'milena-sakumo'
# 'isabel-seki' ➜ 'izabel-seki'
# 'zofia-szawarnowska' ➜ 'zofia-szawernowska'
# 'rafael-mota' ➜ 'rafael-costa'
# 'tomas-szczerek' ➜ 'tomasz-szczerek'
# 'roger-monsalve' ➜ 'rogel-monsalve'
# 'yuji-arai' ➜ 'yuji-harai'
# 'rodrigo-pinheiro' ➜ 'rodrigo-pnheiro'
# 'don-schon' ➜ 'dan-schon'
# 'kamil-uminski' ➜ 'kamil-huminski'
# 'leonardo-domingo' ➜ 'leonardo-domingos'
# 'fayaz-akbari' ➜ 'fayyaz-akbari'
# 'bre-stikkelman' ➜ 'breanna-stikkelman'
# 'joanie-chamberland' ➜ 'joanie-chamberlain'
# 'elvira-karppinen' ➜ 'elvira-karpinnen'
# 'thaynara-bandeira' ➜ 'thayana-bandeira'
# 'ludmila-fiori' ➜ 'ludimira-fiori'
# 'fiona-mortell' ➜ 'fiona-mortel'
# 'priscila-assuncao' ➜ 'priscilla-assuncao'
# 'maria-vincentini' ➜ 'maria-vicentini'
# 'tye-ruotolo' ➜ 't.-ruotolo'
# 'rafa-mendes' ➜ 'rafael-mendes'
# 'samuel-hertzog' ➜ 'samuel-hertz'
# 'niccolas-araujo' ➜ 'nicholas-araujo'
# 'rodrigo-lima' ➜ 'rodrigo-limera'
# 'franciscso-matos' ➜ 'francisco-mateus'
# 'nicholas-welker' ➜ 'nichollas-welker'
# 'joshua-murdock' ➜ 'joshua-murdok'
# 'lucas-araujo' ➜ 'luis-araujo'
# 'matheus-vectoraci' ➜ 'matheus-vetoraci'
# 'matheus-vetoraci' ➜ 'matheus-vectoraci'
# 'angel-cicero' ➜ 'angelo-cicero'
# 'd.-lapchenkov' ➜ 'dimi-lapchenkov'
# 'thomas-edmund' ➜ 'thomas-edmond'
# 'marco-pereira' ➜ 'marcelo-pereira'
# 'walter-santos' ➜ 'walter-dos-santos'
# 'eletherios-pagkalos' ➜ 'eleftherios-pagkalos'
# 'macos-carrozzino' ➜ 'marcos-carrozzino'
# 'charlie-adorian' ➜ 'charles-adorian'
# 'david-cartwright' ➜ 'david-wright'
# 'narciso-vilaca' ➜ 'narciso-vila'
# 'andrea-verdimari' ➜ 'andrea-verdemare'
# 'marcelo-pereira' ➜ 'marco-pereira'
# 'takahiko-yashioka' ➜ 'takahito-yoshioka'
# 'javier-gomez' ➜ 'javier-gomes'
# 'robert-ezzell' ➜ 'robert-ezel'
# 'rennick-kama' ➜ 'rennik-kama'
# 'marcos-goulart' ➜ 'marcus-goulart'
# 'caleb-mcallister' ➜ 'caleb-mccallister'
# 'sebastian-calle' ➜ 'sebastian-calloud'
# 'vinicius-barros' ➜ 'vinicius-barbosa'
# 'dylan-whyte' ➜ 'dylan-white'
# 'alexis-tangen' ➜ 'alexis-stangen'
# 'gabriel-neves' ➜ 'gabriel-mees'
# 'wesley-leite' ➜ 'weslley-leite'
# 'lucas-bezerra' ➜ 'lucas-bezerril'
# 'tiago-alves' ➜ 'thiago-alves'
# 'jackson-silva' ➜ 'jacson-silva'
# 'alexander-lane' ➜ 'alexander-le'
# 'rehan-mutalib' ➜ 'rehan-muttalib'
# 'christopher-ryan' ➜ 'christopher-tran'
# 'brandon-bergenon' ➜ 'brandon-bergeron'
# 'rafael-silva' ➜ 'rafal-silva'
# 'youngseung-cho' ➜ 'yongseung-cho'
# 'matheus-dantas' ➜ 'matheus-santos'
# 'andy-reyes' ➜ 'andy-reese'
# 'eduardo-machado' ➜ 'eduardo-macedo'
# 'filipe-bobrick' ➜ 'filipe-brobrick'
# 'faisal-al-kitbe' ➜ 'faisal-elkitbe'
# 'nejc-hodnik' ➜ 'njec-hodnik'
# 'matheus-aguiar' ➜ 'matheus-dauria'
# 'lucas-lira' ➜ 'luccas-lira'
# 'melksedec-fran' ➜ 'melksedec-franc'
# 'leonardo-carlos' ➜ 'leonardo-barros'
# 'luiz-oliveira' ➜ 'luiz-g.-oliveira'
# 'marat-kurbanov' ➜ 'murat-karbanov'
# 'nimrod-ryeder' ➜ 'nimrod-ryder'
# 'sviatoslav-ognev' ➜ 'svyatoslav-ognev'
# 'luiz-tosta' ➜ 'luiz-costa'
# 'cindy-hung' ➜ 'cindy-ung'
# 'sara-galvao' ➜ 'sarah-galvao'
# 'carlos-elias' ➜ 'carlos-reis'
# 'joao-gabriel' ➜ 'j-gabriel'
# 'justin-labac' ➜ 'justin-fabac'
# 'joshua-richards' ➜ 'josh-richards'
# 'chris-passarello' ➜ 'chris-passarrello'
# 'kasper-larsen' ➜ 'kaser-larsen'
# 'adam-perez' ➜ 'adria-perez'
# 'paulo-lanzillotti' ➜ 'paulo-lanzilotti'
# 'chris-wojcik' ➜ 'chris-wocjik'
# 'sergio-vilas' ➜ 'sergio-villas'
# 'jhonatha-angelim' ➜ 'jhonathan-angelim'
# 'robson-feitosa' ➜ 'robson-feitoza'
# 'gabriel-lima' ➜ 'gabriel-litman'
# 'ulysses-fagundes' ➜ 'ulysses-faguntes'
# 'felippe-mello' ➜ 'felippe-melo'
# 'wesley-santos' ➜ 'weslley-santos'
# 'felipe-ono' ➜ 'felipe-nilo'
# 'marcos-suel' ➜ 'marcus-suel'
# 'matheus-monteiro' ➜ 'matheus-soeiro'
# 'felipe-machado' ➜ 'felipe-cancado'
# 'wellison-sousa' ➜ 'wallison-souza'
# 'matheus-azancot' ➜ 'mateus-azancot'
# 'marcos-vinicius' ➜ 'marcus-vinicius'
# 'artur-oliveira' ➜ 'artur-oliveita'
# 'brendo-babilonia' ➜ 'breno-babilonia'
# 'vinicius-oliveira' ➜ 'vinicius-vieira'
# 'guilherme-lopes' ➜ 'guilherme-gomes'
# 'leonardo-barros' ➜ 'leonardo-carlos'
# 'aleksander-jablonski' ➜ 'aleks-jablonski'
# 'j.-gracie' ➜ 'j.-grace'
# 'rafael-rosendo' ➜ 'raphael-rosendo'
# 'r.-olivier' ➜ 'r.-oliveira'
# 'tiago-rocha' ➜ 'thiago-rocha'
# 'geovani-bernardo' ➜ 'giovani-bernardo'
# 'edwin-ocasio' ➜ 'edwin-acasio'
# 'kyle-thomison' ➜ 'kyle-thomson'
# 'greg-walker' ➜ 'gred-walker'
# 'melor-strura' ➜ 'melor-sturua'
# 'raiane-santos' ➜ 'rayanne-santos'
# 'tyler-freeman' ➜ 'ty-freeman'
# 'sebastian-lecoq' ➜ 'sebastien-lecoq'
# 'vinicius-de-castro' ➜ 'vinicius-castro'
# 'ludy-goulart' ➜ 'ludi-goulart'
# 'rafael-carvalho' ➜ 'rafael-cabral'
# 'stefan-croitoru' ➜ 'stefan-croituro'
# 'ayub-magomadov' ➜ 'ayub-mogomadov'
# 'dimitri-vostrivov' ➜ 'dimitri-vostrikov'
# 'bredley-hill' ➜ 'bradley-hill'
# 'rafael-bernardes' ➜ 'rafael-fernandes'
# 'leonardo-goncalves' ➜ 'leonardo-gocalves'
# 'andresa-cintra' ➜ 'andressa-cintra'
# 'andressa-cintra' ➜ 'andresa-cintra'
# 'lucas-castro' ➜ 'lucas-castelo'
# 'jhonatas-ramos' ➜ 'jhonathas-ramos'
# 'antonio-villiatora' ➜ 'antonio-villatora'
# 'danielle-alvarez' ➜ 'dannielle-alvarez'
# 'tracey-goodell' ➜ 'tracey-goodel'
# 'levi-oliveira' ➜ 'levy-oliveira'
# 'nic-gregoriades' ➜ 'nicolas-gregoriades'
# 'kron-gracie' ➜ 'kayron-gracie'
# 'vinicius-corrales' ➜ 'vinicius-torres'
# 'tetsuya-kondo' ➜ 'tatsuya-kondo'
# 'thiago-abreu' ➜ 'thiago-abud'
# 'luis-gustavo' ➜ 'luiz-gustavo'
# 'rafael-nicholas' ➜ 'raphael-nicolas'
# 'mauro-santiago' ➜ 'maria-santiago'
# 'rodrigo-martins' ➜ 'rodrigo-mariani'
# 'danilo-borovic' ➜ 'dan-borovic'
# 'leandro-kussano' ➜ 'leandro-kusano'
# 'diego-vivaldo' ➜ 'diego-vivalde'
# 'roberto-frias' ➜ 'robert-frias'
# 'thiago-de-sousa' ➜ 'thiago-sousa'
# 'daniel-speirn' ➜ 'daniel-sperm'
# 'rafael-castro' ➜ 'raphael-castro'
# 'oliver-geddess' ➜ 'oliver-geddes'
# 'lucas-ramos' ➜ 'lucas-campos'
# 'wellington-paes' ➜ 'wellington-pesce'
# 'joao-silva' ➜ 'joao-da-silva'
# 'dimitrus-souza' ➜ 'dimitrius-souza'
# 'marcel-goulart' ➜ 'marcos-goulart'
# 'felipe-brobrick' ➜ 'felipe-bobrick'
# 'victor-bomfim' ➜ 'vitor-bomfim'
# 'william-martins' ➜ 'wiliam-martins'
# 'lucas-gomes' ➜ 'luan-gomes'
# 'jonatas-gracie' ➜ 'jonnatas-gracie'
# 'caio-gregori' ➜ 'caio-gregorio'
# 'marcel-golcalves' ➜ 'marcel-goncalves'
# 'alex-taveira' ➜ 'alex-vieira'
# 'william-mello' ➜ 'william-melo'
# 'leonardo-vilela' ➜ 'leonardo-vieira'
# 'shiniya-aoki' ➜ 'shinya-aoki'
# 'aleksandr-ustimenko' ➜ 'aleks-ustimenko'
# 'marco-mendes' ➜ 'marcelo-mendes'
# 'victor-matos' ➜ 'vitor-matos'
# 'spenser-nogawa' ➜ 'spencer-nogawa'
# 'wellington-modena' ➜ 'wellinton-modena'
# 'michael-main' ➜ 'michael-maia'
# 'josh-murdock' ➜ 'josh-murdoc'
# 'gerson-atiogue' ➜ 'gerson-atoigue'
# 'shane-torres' ➜ 'stephanie-torres'
# 'tomer-alroy' ➜ 'tomer-aldroy'
# 'micah-brakefield' ➜ 'micah-bakefield'
# 'adam-sachnoff' ➜ 'adam-sanchoff'
# 'antoine-jaoude' ➜ 'antoine-joude'
# 'denis-hallman' ➜ 'dennis-hallman'
# 'kevin-casey' ➜ 'kevin-cassey'
# 'eldar-savidov' ➜ 'eldar-sayidov'
# 'phil-rowe' ➜ 'philip-rowe'
# 'marvin-castell' ➜ 'marvin-castelle'
# 'winson-ramos' ➜ 'windson-ramos'
# 'russell-white' ➜ 'russel-white'
# 'manuel-aguilar' ➜ 'marcel-aguilar'
# 'alexander-le' ➜ 'alexander-lane'
# 'augusto-rebelo' ➜ 'augusto-rabelo'
# 'rodrigo-goncales' ➜ 'rodrigo-goncalves'
# 'robson-silva' ➜ 'robson-sa'
# 'wilhiam-mateus' ➜ 'wilhiam-matheus'
# 'walkler-barroso' ➜ 'walker-barroso'
# 'david-sigler' ➜ 'david-siegler'
# 'cameron-chaffee' ➜ 'cameron-chafee'
# 'jonathan-roberts' ➜ 'john-roberts'
# 'chris-passarrello' ➜ 'chris-passarello'
# 'alika-villiatora' ➜ 'alika-villatora'
# 'tehau-sandord' ➜ 'tehau-stanford'
# 'alef-soares' ➜ 'alex-soares'
# 'thiago-ferreira' ➜ 'thiago-pereira'
# 'jeff-childs' ➜ 'jeffrey-childs'
# 'michael-hay' ➜ 'michael-lady'
# 'marlos-salgado' ➜ 'marlus-salgado'
# 'christian-muckay' ➜ 'christian-mueckay'
# 'anthony-wong' ➜ 'anthony-yong'
# 'dennis-pressey' ➜ 'dennis-presley'
# 'johnathan-frank' ➜ 'johnatha-franca'
# 'alfonso-estrada' ➜ 'alfonso-astrada'
# 'wilker-marques' ➜ 'wilkler-marques'
# 'michael-sainz' ➜ 'michael-saenz'
# 'kevin-machecha' ➜ 'kevin-mahecha'
# 'joao-henrique' ➜ 'jonas-henrique'
# 'alexandre-dantas' ➜ 'alexandre-santos'
# 'wagney-fabiano' ➜ 'wagnney-fabiano'
# 'shawn-williams' ➜ 'sean-williams'
# 'wander-braga' ➜ 'wender-braga'
# 'marcelo-queiroz' ➜ 'marco-queiroz'
# 'diego-asenjo' ➜ 'diego-anjos'
# 'chris-moriaty' ➜ 'chris-moriarty'
# 'nik-ruben' ➜ 'nic-ruben'
# 'matt-aroyo' ➜ 'matt-arroyo'
# 'reby-donofrio' ➜ 'rob-donofrio'
# 'bruno-tostes' ➜ 'bruno-tosto'
# 'leonardo-ramos' ➜ 'leonardo-lemos'
# 'khalif-fadallah' ➜ 'khalil-fadallah'
# 'erick-raposo' ➜ 'erik-raposo'
# 'antoine-gibson' ➜ 'antione-gibson'
# 'r.-jennerjohn' ➜ 'ryan-jennerjohn'
# 'alika-villatora' ➜ 'alika-villiatora'
# 'michael-aaron' ➜ 'michael-harmon'
# 'jose-silva' ➜ 'josue-silva'
# 'marcos-campos' ➜ 'marcos-campo'
# 'scott-thometz' ➜ 'scott-thomez'
# 'jeff-cummings' ➜ 'jef.-cummings'
# 'josh-bacallao' ➜ 'joshua-bacallao'
# 'brian-bergeron' ➜ 'brandon-bergeron'
# 'kyle-thomson' ➜ 'kyle-thomison'
# 'enrique-falarza' ➜ 'enrique-galarza'
# 'q.-roszenweig' ➜ 'q.-rosenzweig'
# 'charles-murdoch' ➜ 'charles-murdock'
# 'allika-villatora' ➜ 'alika-villatora'
# 'diogo-silveira' ➜ 'diogo-silva'
# 'otavio-serafim' ➜ 'otavio-seravim'
# 'victor-braz' ➜ 'victor-borja'
# 'jae-mcintosh' ➜ 'jaret-macintosh'
# 'mathew-torres' ➜ 'matthew-torres'
# 'gustavo-elias' ➜ 'gustavo-dias'
# 'brandon-bergeron' ➜ 'brandon-bergenon'
# 'kayron-gracie' ➜ 'kron-gracie'
# 'pedro-mello' ➜ 'pedro-melo'
# 'rodrigo-akilis' ➜ 'rodrigo-acioli'
# 'nic-nikolaisen' ➜ 'nik-nikolaisen'
# 'rafael-ferreira' ➜ 'rafael-pereira'
# 'robson-tanno' ➜ 'robson-tano'
# 'ruben-rivera' ➜ 'ruan-rivera'
# 'almog-britch' ➜ 'almog-britsch'
# 'aaron-tiegs' ➜ 'aaron-tieggs'
# 'amr-ghoneim' ➜ 'amir-ghoneim'
# 'talison-soares' ➜ 'thalison-soares'
# 'tom-kozlowski' ➜ 'thomas-kozlowski'
# 'aizbeck-mustekov' ➜ 'aiazbek-mustakov'
# 'kazuyuki-miyata' ➜ 'kazuyuki-miyazi'
# 'perez-figueiroa' ➜ 'perez-figueroa'
# 'khristopher-gonzalez' ➜ 'khristopher-gonzales'
# 'desmond-mcdonald' ➜ 'desond-mcdonald'
# 'nick-fiore' ➜ 'nick-forrer'
# 'james-guion' ➜ 'james-guyton'
# 'aaron-haris' ➜ 'aaron-harris'
# 'diogo-borges' ➜ 'diego-borges'
# 'brandon-wilson' ➜ 'brandon-wilkinson'
# 'saar-shimesh' ➜ 'saar-shemesh'
# 'mathew-martinez' ➜ 'matthew-martinez'
# 'vinicius-jesus' ➜ 'vinicius-de-jesus'
# 'daniel-leith' ➜ 'daniel-seth'
# 'matthew-cox' ➜ 'mathew-cox'
# 'brandon-manarin' ➜ 'brandon-mandarim'
# 'andre-fernando' ➜ 'andre-fernandes'
# 'cameron-earle' ➜ 'cameron-earl'
# 'akira-shoji' ➜ 'akira-shouji'
# 'jake-mckenzie' ➜ 'jake-mackenzie'
# 'oliver-lovell' ➜ 'oliver-novell'
# 'chris-regan' ➜ 'chris-tran'
# 'maciek-kozak' ➜ 'maciej-kozak'
# 'diego-calvacanti' ➜ 'diego-cavalcante'
# 'javier-vazquez' ➜ 'javier-vasquez'
# 'sean-fischer' ➜ 'sean-fisher'
# 'luciano-rodrigues' ➜ 'lucio-rodrigues'
# 'davi-raab' ➜ 'david-raab'
# 'jaakko-hulkkonen' ➜ 'jaakko-hukkonen'
# 'arbi-muradov' ➜ 'abi-muradov'
# 'jose-llanas' ➜ 'jose-lianas'
# 'marco-queiroz' ➜ 'marcelo-queiroz'
# 'antti-mannila' ➜ 'antii-mannila'
# 'chris-dellevag' ➜ 'christian-dellevag'
# 'amadu-jorge' ➜ 'amadeu-jorge'
# 'isaac-dull' ➜ 'isaac-dul'
# 'ferando-cabrera' ➜ 'fernando-cabrera'
# 'jonathan-maflin' ➜ 'jonothan-maflin'
# 'a.-magomadov' ➜ 'a.-mogomadov'
# 'roger-graci.' ➜ 'roger-gracie'
# 'rodrigo-pnheiro' ➜ 'rodrigo-pinheiro'
# 'antonio-borges' ➜ 'antonio-torres'
# 'josh-barnet' ➜ 'josh-barnett'
# 'muhammad-kerimov' ➜ 'muhammed-kerimov'
# 'nate-marquardt' ➜ 'nathan-marquardt'
# 'mario-gonzalez' ➜ 'mario-gonzales'
# 'pawe-jaworski' ➜ 'pawel-jaworski'
# 'orlando-andavi' ➜ 'orlando-andaviza'
# 'frederik-vosgrone' ➜ 'frederic-vosgrone'
# 'q.-rozensweig' ➜ 'q.-roszenweig'
# 'matthew-secor' ➜ 'mathew-secor'
# 'benjamin-bennett' ➜ 'benjamin-bennet'
# 'gottrell-king' ➜ 'gotterell-king'
# 'mohamed-alsuwaidi' ➜ 'mohammed-alsuwaidi'
# 'b.-menmahammed' ➜ 'b.-benmahammed'
# 'luiz-barroso' ➜ 'luis-barroso'
# 'mateus-santos' ➜ 'matheus-santos'
# 'tiago-santos' ➜ 'thiago-santos'
# 'ana-silva' ➜ 'ana-da-silva'
# 'naiomi-mathews' ➜ 'naiomi-matthews'
# 'kamilly-souza' ➜ 'kamilla-souza'
# 'mladen-jokmanovic' ➜ 'malden-jokmanovic'
# 'matheus-souza' ➜ 'matheus-sousa'
# 'marcos-alves' ➜ 'marcos-alves-jr'
# 'anderson-lira' ➜ 'anderson-lima'
# 'ludi-goulart' ➜ 'ludy-goulart'
# 'italo-goncalves' ➜ 'italo-golcalves'
# 'vinny-morais' ➜ 'vinny-moraes'
# 'esdras-barbosa' ➜ 'endres-barbosa'
# 'jarod-lawton' ➜ 'jared-lawton'
# 'eliott-kelly' ➜ 'eliot-kelly'
# 'gianni-crivello' ➜ 'gianni-criello'
# 'thomas-metz' ➜ 'thomas-mietz'
# 'thomas-oyarzun' ➜ 'tomas-oyarzun'
# 'victor-rodrigues' ➜ 'victor-rodriguez'
# 'henrique-moreira' ➜ 'henrique-pereira'
# 'pedro-melo' ➜ 'pedro-mello'
# 'josue-silva' ➜ 'jose-silva'
# 'kalil-nascimento' ➜ 'kalel-nascimento'
# 'giovanni-marcelo' ➜ 'giovani-marcelo'
# 'walton-presto' ➜ 'waltan-presto'
# 'jordan-more' ➜ 'jordan-moore'
# 'daniel-rivera' ➜ 'daniel-rivas'
# 'rafael-rodrigues' ➜ 'rafael-rodriguez'
# 'alejandro-carreras' ➜ 'alejandro-carrera'
# 'lucas-goncalves' ➜ 'luciano-goncalves'
# 'mo-ali-hayat' ➜ 'mohd-ali-hayat'
# 'kyvann-jimenez' ➜ 'kyvan-jimenez'
# 'demian-anderson' ➜ 'damien-anderson'
# 'kyvan-jimenez' ➜ 'kyvann-jimenez'
# 'alika-villatore' ➜ 'alika-villatora'
# 'jesse-sosa' ➜ 'jese-sosa'
# 'chad-meyers' ➜ 'chad-myers'
# 'mohammed-alswaidi' ➜ 'mohammed-alsuwaidi'
# 'j.-echevarria' ➜ 'j.-echeverria'
# 'dan-borovic' ➜ 'danilo-borovic'
# 'joao-moncalvo' ➜ 'joao-moncaio'
# 'alberto-ramos' ➜ 'albert-ros'
# 'yan-cathalat' ➜ 'yann-cathalat'
# 'gialyson-freitas' ➜ 'gialysson-freitas'
# 'm.-almenhali' ➜ 'mo-almenhali'
# 'mo-almenhali' ➜ 'm.-almenhali'
# 'valcemir-junior' ➜ 'valmecir-junior'
# 'mani-tavanaei' ➜ 'mani-tavanae'
# 'mohamed-h.' ➜ 'mohammad-h.'
# 'dinei-souza' ➜ 'dina-souza'
# 'paulo-oliveira' ➜ 'pablo-oliveira'
# 'carlos-geovani' ➜ 'carlos-geovanni'
# 'kaique-affonso' ➜ 'kaike-affonso'
# 'luis-barroso' ➜ 'luiz-barroso'
# 'amanda-loewen' ➜ 'amanda-lowen'
# 'tammy-griego' ➜ 'tammi-griego'
# 'tammi-griego' ➜ 'tammy-griego'
# 'venla-luukkonen' ➜ 'venla-lukkonnen'
# 'bia-mesquita' ➜ 'bianca-mesquita'
# 'jaqueline-moraes' ➜ 'juliane-moraes'
# 'diego-hertzog' ➜ 'diego-herzog'
# 'felipe-matos' ➜ 'felipe-makoto'
# 'corey-brown' ➜ 'corey-brokaw'
# 'phillip-lietz' ➜ 'phil-lietz'
# 'yann-cathalat' ➜ 'yan-cathalat'
# 'alvaro-oliveiro' ➜ 'alvaro-oliveira'
# 'tanner-wesgram' ➜ 'tanner-weisgram'
# 'saar-shemesh' ➜ 'saar-shimesh'
# 'ancelmo-santos' ➜ 'anselmo-santos'
# 'ioannis-pronos' ➜ 'ioannis-proios'
# 'eduard-hohl' ➜ 'edward-hohl'
# 's.-mcnally' ➜ 'sam-mcnally'
# 'alejandro-lopez' ➜ 'alejandro-perez'
# 'zach-green' ➜ 'zach-greene'
# 'jacob-semsem' ➜ 'jacob-semsen'
# 'pete-shoemaker' ➜ 'peter-shoemaker'
# 'j.-cisneros' ➜ 'j.-cinceros'
# 'jacob-semsen' ➜ 'jacob-semsem'
# 'jonathan-lopez' ➜ 'jonathan-lopes'
# 'robert-santos' ➜ 'roberto-satoshi'
# 'john-garcia' ➜ 'josh-garcia'
# 'reece-lafever' ➜ 'reese-lafever'
# 'anthony-valdes' ➜ 'anthony-valdez'
# 'augusto-rabelo' ➜ 'augusto-rebelo'
# 'andre-greco' ➜ 'andre-rico'
# 'lucas-canto' ➜ 'lucas-santos'
# 'ricardo-rea' ➜ 'ricardo-pena'
# 'josh-richards' ➜ 'joshua-richards'
# 'vinicius-torres' ➜ 'vinicius-corrales'
# 'matheus-vieira' ➜ 'mateus-vieira'
# 'parick-goncalves' ➜ 'patrick-goncalves'
# 'rob.-anderson' ➜ 'r.-anderson'
# 'eric-ingram' ➜ 'erick-ingram'
# 'ross-daniel' ➜ 'ross-daniels'
# 'luis-henrique' ➜ 'luiz-henrique'
# 'antione-gibson' ➜ 'antoine-gibson'
# 'pablo-henrique' ➜ 'paulo-henrique'
# 'henrique-felix' ➜ 'henrique-feijo'
# 'antonio-asseff' ➜ 'antonio-assef'
# 'luiz-felipe' ➜ 'luis-felipe'
# 'jose-pereira' ➜ 'jonas-pereira'
# 'mateus-carmo' ➜ 'matheus-carmona'
# 'robson-sa' ➜ 'robson-silva'
# 'wellington-pesce' ➜ 'wellington-paes'
# 'pedro-alcantra' ➜ 'pedro-alcantara'
# 'leonardo-brocca' ➜ 'leonardo-rocha'
# 'tiago-gaia' ➜ 'thiago-gaia'
# 'j.-friedrich' ➜ 'j.-fredrich'
# 'joao-moncaio' ➜ 'joao-moncalvo'
# 'omar-sabha' ➜ 'omar-saba'
# 'rafael-fraga' ➜ 'rafael-braga'
# 'matt-secor' ➜ 'matthew-secor'
# 'dennis-prokopos' ➜ 'denny-prokopos'
# 'daud-adaev' ➜ 'dauad-adaev'
# 'hamzeh-rashid' ➜ 'hamzeh-rasheed'
# 'dainis-nguyen' ➜ 'daninis-nguyen'
# 'chris-tran' ➜ 'chris-regan'
# 'daniel-groot' ➜ 'daniel-de-groot'
# 'n.-blackman' ➜ 'nia-blackman'
# 'anton-mikenko' ➜ 'anton-minenko'
# 'eduardo-silveira' ➜ 'eduardo-silva'
# 'melksedec-franco' ➜ 'melksedeck-franco'
# 'jarosaw-gajek' ➜ 'jaroslaw-gajek'
# 'edward-ingamells' ➜ 'ed-ingamells'
# 'rogel-monsalve' ➜ 'roger-monsalve'
# 'p.-kwiatkowski' ➜ 'pawe-kwiatkowski'
# 'walter-dos-santos' ➜ 'walter-santos'
# 'tiago-silva' ➜ 'thiago-silva'
# 'dmitrii-vostrikov' ➜ 'dimitri-vostrikov'
# 'krzysztof-flak' ➜ 'krysztof-flak'
# 'samuel-khan' ➜ 'samuel-kahn'
# 'marcin-klonowski' ➜ 'marian-klosowski'
# 'thaynara-dias' ➜ 'thayara-dias'
# 'lilian-tran' ➜ 'lillian-tran'
# 'serena-gabrieli' ➜ 'serena-gabrielli'
# 'sean-whyte' ➜ 'sean-white'
# 'bobby-winther' ➜ 'bobby-whither'
# 'diogo-oliveira' ➜ 'diogo-silveira'
# 'mateusz-lim' ➜ 'mateus-lima'
# 'michael-lady' ➜ 'michael-hay'
# 'maxim-cote' ➜ 'maxime-cote'
# 'joe-kropschot' ➜ 'joseph-kropschot'
# 'eliyah-sala' ➜ 'elijah-sala'
# 'kevin-berberich' ➜ 'kevin-berbrich'
# 'tara-white' ➜ 'tara-while'
# 'britney-elkin' ➜ 'brittney-elkin'
# 'fernanda-figueira' ➜ 'fernanda-figueiredo'
# 'fernanda-figueiredo' ➜ 'fernanda-figueira'
# 'vanessa-griffin' ➜ 'vannessa-griffin'
# 'lunna-silva' ➜ 'luanna-silva'
# 'mayara-ribeiro' ➜ 'marina-ribeiro'
# 'amanda-lowen' ➜ 'amanda-loewen'
# 'maria-malijasiak' ➜ 'maria-malyjasiak'
# 'rita-lynn' ➜ 'rita-lynne'
# 'maryanna-cardoso' ➜ 'mayanna-cardoso'
# 'breanna-stikkelman' ➜ 'bre-stikkelman'
# 'tracey-goodel' ➜ 'tracey-goodell'
# 'haley-zhanow' ➜ 'haley-zahnow'
# 'michelle-welti' ➜ 'michele-welti'
# 'sarah-block' ➜ 'sarah-black'
# 'juan-cleber' ➜ 'juan-kleber'
# 'joao-pedro' ➜ 'joao-pedrosa'
# 'luan-gomes' ➜ 'luan-gomez'
# 'ermilio-limea' ➜ 'ermilio-lima'
# 'russel-white' ➜ 'russell-white'
# 'vinicius-gimenes' ➜ 'vinicius-gimenis'
# 'joao-pereira' ➜ 'joao-ferreira'
# 'j.-cinceros' ➜ 'j.-cisneros'
# 'thiag-dalcol' ➜ 'thiago-dalcol'
# 'eduardo-farfan' ➜ 'eduardo-franca'
# 'jese-sosa' ➜ 'jesse-sosa'
# ...
# 'nathan-mendlesohn' ➜ 'nathan-mendesohn'
# 'ann-kneibb' ➜ 'ann-kneib'
# 'chingwen-huang' ➜ 'ching-huang'
# 'delfina-francisco' ➜ 'delfina-fransisco'
# 'melksedec-franc' ➜ 'melksedec-franco'
# 'rodolfo-nygarrd' ➜ 'rodolfo-nygaard'
# 'mateusz-gamrot' ➜ 'mateusz-garmot'
# 'j.-grace' ➜ 'j.-gracie'
# 'nick-forrer' ➜ 'nick-fiore'
# 'khalid-alshamsi' ➜ 'khaled-shamsi'
# 'a.-alexandrov' ➜ 'alex-alexandrov'
# 'juan-bitterncourt' ➜ 'juan-bittencourt'
# 'victor-doria' ➜ 'viktor-doria'
# 'yuri-simes' ➜ 'yuri-simoes'
# 'vince-pezzuto' ➜ 'vincent-pezzuto'
# 'eldar-saydiov' ➜ 'eldar-sayidov'
# 'luis-amigo' ➜ 'luis-gamino'
# 'charles-pearson' ➜ 'charles-parsons'
# 'ocimar-santos' ➜ 'oscar-santos'
# 'karel-pravec' ➜ 'karl-pravec'
# 'karl-pravec' ➜ 'karel-pravec'
# 'jonathan-torres' ➜ 'jonathan-correa'
# 'itaro-andrade' ➜ 'iago-andrade'
# 'edson-de-oliveira' ➜ 'edson-oliveira'
# 'eduardo-da-silva' ➜ 'eduardo-silva'
# 'cristian-dellavag' ➜ 'christian-dellevag'
# 'ayub-mogomadov' ➜ 'ayub-magomadov'
# 'bruno-emanel' ➜ 'bruno-emanoel'
# 'anton-minekento' ➜ 'anton-minenko'
# 'vitor-bomfim' ➜ 'victor-bomfim'
# 'matheus-felix' ➜ 'matheus-felipe'
# 'roosevelt-souza' ➜ 'roosevelt-sousa'
# 'octavio-gaytan' ➜ 'otavio-gaytan'
# 'otavio-gaytan' ➜ 'octavio-gaytan'
# 'enrico-said' ➜ 'erico-said'
# 'kemoy-anderson' ➜ 'kemoy-henderson'
# 'alex-lima' ➜ 'alex-lira'
# 'samuel-kahn' ➜ 'samuel-khan'
# 'mitchel-silva' ➜ 'michael-silva'
# 'mohammod-alim' ➜ 'mohammed-ali'
# 'sam-gibbs' ➜ 'samuel-gibbs'
# 'daniel-de-groot' ➜ 'daniel-groot'
# 'rodrigo-marello' ➜ 'rodrigo-melo'
# 'samuel-gibbs' ➜ 'sam-gibbs'
# 'albert-huges' ➜ 'albert-hughes'
# 'omar-sabah' ➜ 'omar-saba'
# 'michael-harmon' ➜ 'michael-aaron'
# 'yukito-isoda' ➜ 'yukito-iosada'
# 'joel-scovel' ➜ 'joe-scovel'
# 'maiko-araujo' ➜ 'mayko-araujo'
# 'gerson-atoigue' ➜ 'gerson-atiogue'
# 'andre-rico' ➜ 'andre-brito'
# 'jason-lawrence' ➜ 'john-lawrence'
# 'joe-isataka' ➜ 'joe-histaka'
# 'ruan-rivera' ➜ 'ruben-rivera'
# 'michael-thorne' ➜ 'michael-lorne'
# 'keyto-oyanagi' ➜ 'keito-oyanagi'
# 'sho-inaoka' ➜ 'sho-inoaka'
# 'luis-gamino' ➜ 'luis-amigo'
# 'gareth-neal' ➜ 'gareth-neale'
# 'julien-crazier' ➜ 'julien-cazier'
# 'felipe-cancado' ➜ 'felipe-machado'
# 'raphael-silva' ➜ 'rafael-silva'
# 'auyb-magomedov' ➜ 'ayub-magomadov'
# 'pedro-farkas' ➜ 'pedro-farias'
# 'thomas-julien' ➜ 'thomas-jules'
# 'fernando-mera' ➜ 'fernando-vieira'
# 'rafael-rodriguez' ➜ 'rafael-rodrigues'
# 'antti-simola' ➜ 'antii-simola'
# 'ben-bennet' ➜ 'ben-bennett'
# 'adilson-lima' ➜ 'adson-lima'
# 'r.-anderson' ➜ 'rob.-anderson'
# 'jason-miller' ➜ 'joao-miller'
# 'jason-bukich' ➜ 'jason-bukach'
# 'lukqasz-gustaw' ➜ 'lucasz-gustaw'
# 'pavel-kavesnik' ➜ 'pavel-kalesnik'
# 'vitor-silva' ➜ 'victor-silva'
# 'alejandro-perez' ➜ 'alejandro-lopez'
# 'thiago-reinaldo' ➜ 'tiago-reinaldo'
# 'alexander-kalawe' ➜ 'alexander-lane'
# 'gotrell-king' ➜ 'gottrell-king'
# 'a.-almudhri' ➜ 'a.-almurdhi'
# 'huthayfa-penney' ➜ 'huthayfah-penney'
# 'henrique-ferreira' ➜ 'henrique-pereira'
# 'evyatar-pareini' ➜ 'evyatar-paperni'
# 'jason-patino' ➜ 'jayson-patino'
# 'josh-garcia' ➜ 'john-garcia'
# 'oscar-santos' ➜ 'ocimar-santos'
# 'matthew-ferraiolo' ➜ 'matt-ferraiolo'
# 'j.-lopez' ➜ 'j.-lopes'
# 'marcelo-henrique' ➜ 'marcelo-enrique'
# 'johnderson-santos' ➜ 'jhonderson-santos'
# 'evertom-freitas' ➜ 'everton-freitas'
# 'leonardo-onoatto' ➜ 'leonardo-gnoatto'
# 'grant-bodganove' ➜ 'grant-bogdanove'
# 'carlos-e.-alves' ➜ 'carlos-alves'
# 'marcelo-augusto' ➜ 'marcelo-fausto'
# 'maria-kelly' ➜ 'mara-kelly'
# 'kayo-cesar' ➜ 'kaio-cesar'
# 'rodrigo-rotardi' ➜ 'rodrigo-gortari'
# 'emilio-ferreira' ➜ 'emilio-pereira'
# 'estras-junior' ➜ 'esdras-junior'
# 'danny-vega' ➜ 'dany-vega'
# 'renan-lopez' ➜ 'rene-lopez'
# 'emilio-lima' ➜ 'ermilio-lima'
# 'murilo-souza' ➜ 'murilo-sa'
# 'joao-menezes' ➜ 'joao-mendes'
# 'bilal-benmahamed' ➜ 'bilal-benmahammed'
# 'andrea-mario' ➜ 'andrea-amaro'
# 'jakub-najdec' ➜ 'jakub-najdek'
# 'rofolfo-vieira' ➜ 'rodolfo-vieira'
# 'jorge-santiago' ➜ 'joel-santiago'
# 'paul-halm' ➜ 'paul-halme'
# 'i.-praporshchikov' ➜ 'igor-praporschchikov'
# 'eduardo-vieyra' ➜ 'eduardo-vieira'
# 'karen-correa' ➜ 'karen-correia'
# 'kamila-souza' ➜ 'kamilla-souza'
# 'maria-souza' ➜ 'maria-sousa'
# 'martina-gramenius' ➜ 'martina-gremanius'
# 'alex-arantes' ➜ 'alexia-arantes'
# 'rodrigo-oiye' ➜ 'rodrigo-oyie'
# 'mateus-azancot' ➜ 'matheus-azancot'
# 'augustin-jimenez' ➜ 'augustin-gimenez'
# 'claudia-do-val' ➜ 'claudia-doval'
# 'dannielle-alvarez' ➜ 'danielle-alvarez'
# 'kylie-lasater' ➜ 'kyle-lasater'
# 'maria-clara' ➜ 'maria-cabral'
# 'larissa-alves' ➜ 'larissa-paes'
# 'ana-santos' ➜ 'anny-santos'
# 'sam-mc-nally' ➜ 'sam-mcnally'
# 'jonathan-rodrigues' ➜ 'john-rodrigues'
# 'pablo-lavaseli' ➜ 'pablo-lavaselli'
# 'sivio-duran' ➜ 'silvio-duran'
# 'yan-cathalan' ➜ 'yan-cathalat'
# 'josh-rios' ➜ 'jose-rios'
# 'angel-lopez' ➜ 'anabel-lopez'
# 'lautaro-sanguime' ➜ 'lautaro-sanguimene'
# 'diego-sato' ➜ 'diego-pato'
# 'felipe-vieira' ➜ 'felipe-teixeira'
# 'jose-oliveira' ➜ 'jorge-oliveira'
# 'adam-malasch' ➜ 'adam-maslach'
# 'lukasz-leplanka' ➜ 'lukasz-lepianka'
# 'toni-ferraz' ➜ 'tony-ferraz'
# 'francisco-bonetto' ➜ 'francisco-neto'
# 'krzysztof-suchor' ➜ 'krysztof-suchora'
# 'edvaldo-ferreira' ➜ 'edivaldo-ferreira'
# 'andre-bernardo' ➜ 'andre-fernando'
# 't.-hopstock' ➜ 't,-hopstock'
# 'joachim-svenson' ➜ 'joachim-sveinson'
# 'kristian-mae' ➜ 'kristjan-mae'
# 'adrian-kozciz' ➜ 'adrian-kozicz'
# 'm.-abdulkaridov' ➜ 'm.-abdulkadirov'
# 'tarik-hopstok' ➜ 'tarik-hopstock'
# 'diego-heinrich' ➜ 'diego-heirich'
# 'manuel-porto' ➜ 'manoel-porto'
# 'a.-agazarm' ➜ 'aj-agazarm'
# 'ed-cummings' ➜ 'e.-cummings'
# 'nicolas-reiner' ➜ 'nicholas-reiner'
# 'uros-cilic' ➜ 'uros-culic'
# 'marcia-figueiredo' ➜ 'marcelo-figueiredo'
# 'luanna-silva' ➜ 'lunna-silva'
# 'roger-roberto' ➜ 'roberto-roberto'
# 'mat-jubera' ➜ 'matt-jubera'
# 'dimitri-vostrikov' ➜ 'dimitri-vostrivov'
# 'cameron-floczak' ➜ 'cameron-florczak'
# 'anderson-pereira' ➜ 'anderson-ferreira'
# 'marcos-campo' ➜ 'marcos-campos'
# 'jonathan-lopes' ➜ 'jonathan-lopez'
# 'ricardo-soranco' ➜ 'ricardo-franco'
# 'lucas-castelo' ➜ 'lucas-castro'
# 'walker-barroso' ➜ 'walkler-barroso'
# 's.-vilas' ➜ 's.-villas'
# 's.-villas' ➜ 's.-vilas'
# 'chris-simmerling' ➜ 'christian-simmerling'
# 'walllace-costa' ➜ 'wallace-costa'
# 'carlos-geovanni' ➜ 'carlos-geovani'
# 'lucas-campos' ➜ 'lucas-campelo'
# 'brenno-novais' ➜ 'breno-novais'
# 'viktor-doria' ➜ 'victor-doria'
# 'lucas-lopes' ➜ 'luis-lopes'
# 'nolas-stuart' ➜ 'nolan-stuart'
# 'chris-wideman' ➜ 'chris-weidman'
# 'ronny-markes' ➜ 'ronny-marques'
# 'ronny-marques' ➜ 'ronny-markes'
# 'luis-athayde' ➜ 'luiz-athayde'
# 'wilhiam-matheus' ➜ 'wilhiam-mateus'
# 'pedro-santos' ➜ 'pedro-anjos'
# 'vinicius-cecconi' ➜ 'vinicius-ceconi'
# 'victor-bastista' ➜ 'victor-batista'
# 'leandro-nascimento' ➜ 'leo-nascimento'
# 'elfraklin-souza' ➜ 'elfrankli-souza'
# 'nathan-mendhelson' ➜ 'nathan-mendelson'
# 'dainys-huu' ➜ 'dainis-huu'
# 'flavio-fernandes' ➜ 'fabio-fernandes'
# 'carlos-rodriguez' ➜ 'carlos-rodrigues'
# 'fletcher-linton' ➜ 'fletcher-linton-jr'
# 'ekiezer-skaf' ➜ 'eliezer-skaf'
# 'gregory-walker' ➜ 'greg-walker'
# 'rayla-melo' ➜ 'rayan-melo'
# 'thaynara-ferreira' ➜ 'thamara-ferreira'
# 'suellen-desterro' ➜ 'suelen-desterro'
# 'stephanie-delphin' ➜ 'stephanie-delphine'
# 'ludimira-fiori' ➜ 'ludmila-fiori'
# 'otavio-nalatti' ➜ 'otavio-nalati'
# 'henrique-marcos' ➜ 'henrique-rios'
# 'adson-lima' ➜ 'adilson-lima'
# 'breno-babilonia' ➜ 'brendo-babilonia'
# 'joao-victor' ➜ 'joao-vitor'
# 'royce-gracie' ➜ 'royler-gracie'
# 'jhonathan-angelim' ➜ 'jhonatha-angelim'
# 'david-souza' ➜ 'davi-souza'
# 'anderson-oliveira' ➜ 'anderson-lira'
# 'tim-hinrich' ➜ 'tim-hinrichs'
# 'leandro-kusano' ➜ 'leandro-kussano'
# 'luciano-araujo' ➜ 'luciane-araujo'
# 'adam-dashed' ➜ 'adam-adshead'
# 'harry-gretch' ➜ 'harry-grech'
# 'tom-cellamare' ➜ 't.-cellamare'
# 'nimrod-ryder' ➜ 'nimrod-ryeder'
# 'chris-graves' ➜ 'chris-gores'
# 'rehan-mutallib' ➜ 'rehan-mutalib'
# 'jaakko-hukkonen' ➜ 'jaakko-hulkkonen'
# 'victor-martins' ➜ 'victoria-martins'
# 'khaled-shamsi' ➜ 'khalid-alshamsi'
# 'thayara-dias' ➜ 'thaynara-dias'
# 'elizabeth-mitrov' ➜ 'elizabeth-mitrovic'
# 'mica-lima' ➜ 'mika-lima'
# 'kauani-queiroz' ➜ 'kauany-queiroz'
# 'gabriela-matos' ➜ 'gabriel-santos'
# 'aquila-paula' ➜ 'aquila-de-paula'
# 'michael-maia' ➜ 'michel-maia'
# 'michael-thome' ➜ 'michael-tohme'
# 'kouhei-ebashi' ➜ 'kouhel-ebashi'
# 'william-melo' ➜ 'william-mello'
# 'josias-ferreira' ➜ 'jocsan-ferreira'
# 'matheus-carlos' ➜ 'matheus-cardoso'
# 'felipe-reis' ➜ 'felipe-ribas'
# 'rodrigo-francione' ➜ 'rodrigo-francioni'
# 'joshua-lorton' ➜ 'josh-lorton'
# 'joshua-murdok' ➜ 'joshua-murdock'
# 'many-dias' ➜ 'many-diaz'
# 'elliot-marshal' ➜ 'eliot-marshal'
# 'bruno-azevedo' ➜ 'breno-azevedo'
# 'omar-alswaidi' ➜ 'omar-alsuwaidi'
# 'kaike-affonso' ➜ 'kaique-affonso'
# 'raul-marcello' ➜ 'raul-marcelo'
# 'leandro-sousa' ➜ 'leandro-souza'
# 'mateus-pereira' ➜ 'matheus-pereira'
# 't.-alnuaimi' ➜ 't.-alnuami'
# 'igor-pereira' ➜ 'igor-ferreira'
# 't.-alnuami' ➜ 't.-alnuaimi'
# 'rafael-gomez' ➜ 'rafael-gomes'
# 'said-almazrouie' ➜ 'said-almazrouei'
# 'xavier-bas' ➜ 'xavi-bas'
# 'said-almazrouei' ➜ 'said-almazrouie'
# 'breno-azevedo' ➜ 'bruno-azevedo'
# 's.-magomed' ➜ 's.-magomedov'
# 'chris-devallag' ➜ 'chris-dellevag'
# 'j.-pietkainen' ➜ 'j.-pietlainen'
# 'grafon-skraags' ➜ 'grafton-skraggs'
# 'thomas-jules' ➜ 'thomas-julien'
# 'dimirius-souza' ➜ 'dimitrius-souza'
# 'carlos-reis' ➜ 'carlos-elias'
# 'karol-dzienisze' ➜ 'karol-dzieniszewski'
# 'igor-santos' ➜ 'iago-santos'
# 'tarsys-humphreys' ➜ 'tarsis-humphreys'
# 'julian-stonkek' ➜ 'julian-stonjek'
# 'vinicius-de-jesus' ➜ 'vinicius-jesus'
# 'eltrankin-araruna' ➜ 'elfrankli-araruna'
# 'flavio-oliveira' ➜ 'fabio-oliveira'
# 'bruno-franca' ➜ 'bruno-de-franca'
# 'carlos-lima' ➜ 'carlos-elias'
# 'joshua-hinger' ➜ 'josh-hinger'
# 'waltan-presto' ➜ 'walton-presto'
# 'k.-schorabski' ➜ 'k.-suchorabski'
# 'mateo-tenzara' ➜ 'mateo-tenzera'
# 'miles-ivankovic' ➜ 'mile-ivankovic'
# 'tano-odilio' ➜ 'tanno-odilio'
# 'peter-frank' ➜ 'piter-frank'
# 'nicholas-green' ➜ 'nicholas-greene'
# 'phil-lietz' ➜ 'phillip-lietz'
# 'sidney-tavolaro' ➜ 'sid-tavolaro'
# 'claudivan-martins' ➜ 'claudevan-martins'
# 'daniel-statsos' ➜ 'daniel-tsatsos'
# 'rafael-ribeiro' ➜ 'raphael-ribeiro'
# 'antonio-jr' ➜ 'antonio-jr.'
# 'emanoel-felix' ➜ 'emanuel-felix'
# 'alex.-cacareco' ➜ 'a.-cacareco'
# 'marcelinho-garcia' ➜ 'marcelo-garcia'
# 'chico-melo' ➜ 'chico-lo'
# 'denis-gomes' ➜ 'dennis-gomes'
# 'marcio-silva' ➜ 'mario-silva'
# 'andre-silva' ➜ 'andre-da-silva'
# 'gildasio-santana' ➜ 'gildassio-santana'
# 'javier-cardenez' ➜ 'javier-cardenas'
# 'daniel-santos' ➜ 'daniel-tsatsos'
# 'matheus-cunha' ➜ 'matheus-luna'
# 'jose-camilo' ➜ 'jose-calvo'
# 'marcos-alves-jr' ➜ 'marcos-alves'
# 'jackson-souza' ➜ 'jackson-sousa'
# 'vinicius-marilho' ➜ 'vinicius-marinho'
# 'higor-marques' ➜ 'hugo-marques'
# 'matheus-soeiro' ➜ 'matheus-monteiro'
# 'j.-echeverria' ➜ 'j.-echevarria'
# 'steven-rosenberg' ➜ 'steve-rosenburg'
# 'fletcher-linton-jr' ➜ 'fletcher-linton'
# 'antonio-antoniolli' ➜ 'antonio-antonioli'
# 'sergio-hernandes' ➜ 'sergio-hernandez'
# 'ricardo-p.' ➜ 'ricardo-a.'
# 'josh-rodriguez' ➜ 'joshua-rodriguez'
# 'evan-ramdsen' ➜ 'evan-ramsden'
# 'joao-marinho' ➜ 'joao-marcio'
# 'geoff-villarreal' ➜ 'geoff-villareal'
# 'kev-corkhill' ➜ 'kevin-corkhill'
# 'j-gabriel' ➜ 'joao-gabriel'
# 'thiago-aragao' ➜ 'thiago-braga'
# 'otavio-seravim' ➜ 'otavio-serafim'
# 'l.-chocolate' ➜ 'leo-chocolate'
# 'roger-ambrosio' ➜ 'roger-ambrosi'
# 'cleiton-flores' ➜ 'cleyton-flores'
# 'vinicius-caio' ➜ 'vinicius-castro'
# 'j.-lopes' ➜ 'j.-lopez'
# 'john-rickell' ➜ 'john-rickel'
# 'rubens-fonseca' ➜ 'ruben-fonseca'
# 'julyan-synan' ➜ 'julian-synan'
# 'andrea-vaughan' ➜ 'andre-vaughan'
# 'marcelo-ferreira' ➜ 'marlon-ferreira'
# 'vinicius-saraiva' ➜ 'vinicius-silva'
# 'luciano-azevedo' ➜ 'luan-azevedo'
# 'raphael-cadema' ➜ 'raphael-cadena'
# 'guilherme-milan' ➜ 'guilherme-silva'
# 'pedro-valencia' ➜ 'pedro-valenca'
# 'andre-luis' ➜ 'andre-luiz'
# 'raphael-castro' ➜ 'rafael-castro'
# 'douglas-barcelos' ➜ 'douglas-barcellos'
# 'mario-andre' ➜ 'marcio-andre'
# 'joe-histaka' ➜ 'joe-isataka'
# 'robby-d'onofrio' ➜ 'rob-donofrio'
# 'felipe-dias' ➜ 'felipe-ribas'
# 'grafton-skraggs' ➜ 'grafton-skaggs'
# 'mukhammed-kerimov' ➜ 'muhammed-kerimov'
# 'mayko-arajo' ➜ 'mayko-araujo'
# 'jon-hansen' ➜ 'john-hansen'
# 'yuuto-hirao' ➜ 'yuto-hirao'
# 'kazuyuki-miyazi' ➜ 'kazuyuki-miyata'
# 'nabuhiro-sawada' ➜ 'nobuhiro-sawada'
# 'vitor-ricotti' ➜ 'vitor-riciotti'
# 'magomed-djarbaev' ➜ 'magomed-dzharbaev'
# 'narciso-vila' ➜ 'narciso-vilaca'
# 'luiz-andrade' ➜ 'luiz-andre'
# 'magno-motta' ➜ 'magno-mota'
# 'kelvyn-pontes' ➜ 'kevlyn-pontes'
# 'felippe-melo' ➜ 'felippe-mello'
# 'fellipe-mello' ➜ 'fellipe-melo'
# 'igor-terraceo' ➜ 'igor-terreco'
# 'alex-elkin' ➜ 'alex-eklin'
# 'massaki-todokoro' ➜ 'masaaki-todokoro'
# 'joshua-jerome' ➜ 'josh-jerome'
# 'lucas-michalec' ➜ 'lucasz-michalec'
# 'ricardo-moraes' ➜ 'ricardo-morais'
# 'carlos-barreto' ➜ 'carlos-barroso'
# 'diogo-fernandes' ➜ 'diego-fernandes'
# 'charles-oliveira' ➜ 'carlos-oliveira'
# 'jose-kurowoka' ➜ 'jose-kuruoka'
# 'gabriel-roseberg' ➜ 'gabriel-rosenberg'
# 'samat-aitapanbet' ➜ 'samat-aitpanbet'
# 'lukas-andrade' ➜ 'lucas-andrade'
# 'mohammed-ali' ➜ 'mohammod-alim'
# 'thanet-al-taher' ➜ 'thabet-al-taher'
# 'vitor-barreto' ➜ 'victor-barreto'
# 'kheller-shodi' ➜ 'keller-sodhi'
# 'william-shanon' ➜ 'william-shannon'
# 'vinicius-gimenis' ➜ 'vinicius-gimenes'
# 'ak-angerman' ➜ 'a.-angerman'
# 'g.-karakhanyon' ➜ 'g.-karakhanian'
# 'unknown' ➜ 'uknown'
# 'fabio-oliveira' ➜ 'flavio-oliveira'
# 'israel-mota' ➜ 'israel-motta'
# 'mateus-fonseca' ➜ 'matheus-fonseca'
# 'joao-marcelo' ➜ 'joao-marco'
# 'leo-brito' ➜ 'leon-brito'
# 'raphael-cadela' ➜ 'raphael-cadena'
# 'murat-besnek' ➜ 'murat-besnet'
# 'pedro-sousa' ➜ 'pedro-souza'
# 'gabriel-alejandro' ➜ 'gabriel-alexander'
# 'rojerio-narvaez' ➜ 'roger-narvaez'
# 'nonso-ebede' ➜ 'nonso-ebed'
# 'bobby-whither' ➜ 'bobby-winther'
# 'nicholas-reiner' ➜ 'nicolas-reiner'
# 'rob-sullivan' ➜ 'robert-sullivan'
# 's.-tavolaro' ➜ 'sid-tavolaro'
# 'joshua-bowling' ➜ 'joshua-bowlin'
# 'thomas-johansen' ➜ 'thomas-johanssen'
# 'ross-daniels' ➜ 'ross-daniel'
# 'jonathan-ares' ➜ 'jhonathan-marques'
# 'luiz-santis' ➜ 'luiz-santos'
# 'marcos-enrique' ➜ 'marcelo-enrique'
# 'jose-lianas' ➜ 'jose-llanas'
# 'alessandro-oliveira' ➜ 'alexandre-oliveira'
# 'marcos-tome' ➜ 'marcos-gomes'
# 'daniel-tavares' ➜ 'daniel-tavarez'
# 'daniel-rivas' ➜ 'daniel-rivera'
# 'rodolpho-bonfim' ➜ 'rodolpho-bomfim'
# 'christopher-engle' ➜ 'christopher-ong'
# 'thomas-kozlowski' ➜ 'tom-kozlowski'
# 'caio-sousa' ➜ 'caio-de-sousa'
# 'elfrankli-souza' ➜ 'elfraklin-souza'
# 'phillipe-arimatea' ➜ 'philipe-arimatea'
# 'jonnatas-novaes' ➜ 'jonatas-novaes'
# 'luis-schaerer' ➜ 'luis-shaerer'
# 'giovanne-guedes' ➜ 'guiovanne-guedes'
# 'luis-shaerer' ➜ 'luis-schaerer'
# 'rafael-goncalves' ➜ 'rafael-alves'
# 'vinicius-ferrer' ➜ 'vinicius-ferreira'
# 'jose-kuruoka' ➜ 'jose-kurowoka'
# 'gabriel-alexander' ➜ 'gabriel-alejandro'
# 'oliver-novell' ➜ 'oliver-lovell'
# 'andre-verdemare' ➜ 'andrea-verdemare'
# 'alex-de-goulart' ➜ 'alex-goulart'
# 'cassey-hellenberg' ➜ 'casey-hellenberg'
# 'marcus-geddes' ➜ 'marcus-guedes'
# 'felipe-simao' ➜ 'felipe-simoes'
# 'simonelli-emiliano' ➜ 'simoneli-emiliano'
# 'antii-simola' ➜ 'antti-simola'
# 'nicolas-rene' ➜ 'nicolas-renier'
# 'yungseung-cho' ➜ 'youngseung-cho'
# 'sylvio-duran' ➜ 'silvio-duran'
# 'khristopher-santos' ➜ 'kristopher-santos'
# 'bruno-cesar' ➜ 'bruno-cezar'
# 'lukasz-lepianka' ➜ 'lukasz-leplanka'
# 'gabriel-marinho' ➜ 'gabriel-martins'
# 'cesar-miahira' ➜ 'cesar-miyahira'
# 'youngsu-kim' ➜ 'young-kim'
# 'mohamed-alqubaisi' ➜ 'mohamed-qbasi'
# 'j-bezerra' ➜ 'joao-bezerra'
# 'alexandre-cordeiro' ➜ 'alexandre-ribeiro'
# 'alex-silva' ➜ 'alef-silva'
# 'jorge-luis' ➜ 'jorge-elias'
# 'diego-pereira' ➜ 'diego-ferreira'
# 'igor-ferreira' ➜ 'igor-pereira'
# 'thales-vieira' ➜ 'thales-oliveira'
# 'josh-calvo' ➜ 'jose-calvo'
# 'andre-vaughan' ➜ 'andrea-vaughan'
# 'e.-cummings' ➜ 'ed-cummings'
# 'adam-collarlie' ➜ 'adam-colaralie'
# 'anderson-melo' ➜ 'anderson-macedo'
# 'jose-diaz' ➜ 'jose-dias'
# 'pedro-martins' ➜ 'pedro-matias'
# 'fernando-pessoa' ➜ 'fernando-pena'
# 'fernando-silveira' ➜ 'fernando-vieira'
# 'andre-ferreira' ➜ 'anidete-ferreira'
# 'akira-hosokawa' ➜ 'akira-osokawa'
# 'douglas-barcellos' ➜ 'douglas-barcelos'
# 'jorge-dos-santos' ➜ 'jose-dos-santos'
# 'giuliano-alves' ➜ 'giulliano-alves'
# 'chris-noon' ➜ 'chris-noonan'
# 'chris-noonan' ➜ 'chris-noon'
# 'lee-rosenfeld' ➜ 'lee-rosenfield'
# 'gabriel-rosenberg' ➜ 'gabriel-roseberg'
# 'ciro-oliveira' ➜ 'carlos-oliveira'
# 'j.-fredrich' ➜ 'j.-friedrich'
# 'joe-cashin' ➜ 'joseph-cashin'
# 'alex-vieira' ➜ 'alex-taveira'
# 'gustavo-soares' ➜ 'gustavo-borges'

# %%
df_fights['opponent'] = df_fights['opponent'].replace(correcoes_sugeridas)

# %%
from rapidfuzz import process, fuzz

cats = df_fights['opponent'].dropna().unique().tolist()
threshold = 85

matches = {}
for cat in cats:
    # inicial do primeiro nome de cat
    cat_initial = cat.split('-', 1)[0][0]

    # busca candidatos
    raw = process.extract(cat, cats, scorer=fuzz.token_sort_ratio, limit=5)

    # só mantém score>=threshold, nomes diferentes, e mesma inicial
    filtered = [
        (match, score)
        for match, score, _ in raw
        if score >= threshold
           and match != cat
           and match.split('-', 1)[0][0] == cat_initial
    ]
    if filtered:
        matches[cat] = filtered

print("Possíveis variações ortográficas em opponent (mesma inicial):")
for cat, vars in matches.items():
    print(f"{cat!r}: {vars}")
# Out:
# Possíveis variações ortográficas em opponent (mesma inicial):
# 'sivio-duran': [('silvio-duran', 95.65217391304348)]
# 'tiago-macedo': [('thiago-macedo', 96.0)]
# 'renan-lopez': [('rene-lopez', 85.71428571428572)]
# 'rodrigo-francione': [('rodrigo-francioni', 94.11764705882352)]
# 'rodrigo-limera': [('rodrigo-lima', 92.3076923076923)]
# 'martin-davila': [('martin-davilla', 96.2962962962963)]
# 'felipe-preguica': [('felipe-pena-preguica', 85.71428571428572)]
# 'yuri-simes': [('yuri-simoes', 95.23809523809523)]
# 'igor-da-silva': [('igor-silva', 86.95652173913044)]
# 'jackson-souza': [('jackson-sousa', 92.3076923076923)]
# 'abdulbari-guseinov': [('abdulbary-guseinov', 94.44444444444444)]
# 'basel-fanos': [('basel-fanous', 95.65217391304348)]
# 'kamil-uminski': [('kamil-huminski', 96.2962962962963)]
# 'nicholas-penzer': [('nicolas-penzer', 96.55172413793103), ('nicholas-renier', 86.66666666666667), ('nicholas-reiner', 86.66666666666667)]
# 'pouya-rahmani': [('pouya-rahman', 96.0)]
# 'quentin-rosenzweig': [('quentin-rosensweig', 94.44444444444444)]
# 'nieman-gracie': [('neiman-gracie', 92.3076923076923)]
# 'jason-soares': [('joao-soares', 86.95652173913044)]
# 'johnathan-satava': [('jonathan-satava', 96.7741935483871)]
# 'mahamad-aly': [('mahamed-aly', 90.9090909090909)]
# 'james-poupolo': [('james-puopolo', 92.3076923076923)]
# 'vitor-hugo': [('victor-hugo', 95.23809523809523)]
# 'victor-schlosser': [('vitor-schlosser', 96.7741935483871)]
# 'rico-bastos': [('ricardo-bastos', 88.0)]
# 'joe-cashin': [('joseph-cashin', 86.95652173913044)]
# 'wellington-perotto': [('wellington-peroto', 97.14285714285714)]
# 'leo-davilla': [('leo-davila', 95.23809523809523)]
# 'samir-abdolakder': [('samir-abdolkader', 93.75)]
# 'eliot-marshal': [('eliot-marshall', 96.2962962962963)]
# 'chris-simmerling': [('christian-simmerling', 88.88888888888889)]
# 'josh-bowling': [('josh-bowlin', 95.65217391304348), ('joshua-bowling', 92.3076923076923), ('joshua-bowlin', 88.0)]
# 'kaliffa-oliveira': [('kaliffa-oliviera', 93.75)]
# 'leo-davila': [('leo-davilla', 95.23809523809523)]
# 'matt-kirchwehm': [('matt-kirchwhem', 92.85714285714286)]
# 'keneth-brown': [('kenneth-brown', 96.0)]
# 'rodrigo-farias': [('rodrigo-freitas', 89.65517241379311)]
# 'nicolas-penzer': [('nicholas-penzer', 96.55172413793103), ('nicolas-renier', 85.71428571428572), ('nicolas-reiner', 85.71428571428572)]
# 'tom-debass': [('tom-deblass', 95.23809523809523)]
# 'kevin-gallagher': [('kevin-gallager', 96.55172413793103)]
# 'ricard-abreu': [('ricardo-abreu', 96.0)]
# 'lucas-gustaw': [('lucasz-gustaw', 96.0)]
# 'brian-beaury': [('briean-beaury', 96.0)]
# 'todd-muckenheim': [('todd-mueckenheim', 96.7741935483871)]
# 'gybson-sa': [('guybson-sa', 94.73684210526316)]
# 'quentin-rosensweig': [('quentin-rosenzweig', 94.44444444444444)]
# 'jon-hansen': [('john-hansen', 95.23809523809523)]
# 'tye-ruotolo': [('t.-ruotolo', 85.71428571428572)]
# 'gabriel-souza': [('gabriel-sousa', 92.3076923076923), ('gabriel-sa', 86.95652173913044)]
# 'francisco-cueno': [('francisco-cuneo', 93.33333333333333)]
# 'thiago-rosa': [('thiago-barbosa', 88.0), ('thiago-sousa', 86.95652173913044), ('thiago-rocha', 86.95652173913044)]
# 'fredson-alves': [('fred-alves', 86.95652173913044)]
# 'joshua-prestley': [('joshua-presley', 96.55172413793103)]
# 'charles-murdoch': [('charles-murdock', 93.33333333333333)]
# 'spenser-nogawa': [('spencer-nogawa', 92.85714285714286)]
# 'brandon-walenski': [('brandon-walensky', 93.75)]
# 'tomoshigue-sera': [('tomoshige-sera', 96.55172413793103)]
# 'orlando-andavi': [('orlando-andaviza', 93.33333333333333)]
# 'luanna-silva': [('lunna-silva', 95.65217391304348), ('luan-silva', 90.9090909090909)]
# 'giovanni-marcelo': [('giovani-marcelo', 96.7741935483871)]
# 'vitor-paschoal': [('victor-paschoal', 96.55172413793103)]
# 'eduard-hohl': [('edward-hohl', 90.9090909090909)]
# 'bredley-hill': [('bradley-hill', 91.66666666666666)]
# 'felipe-matos': [('felipe-makoto', 88.0)]
# 'huthayfa-penney': [('huthayfah-penney', 96.7741935483871)]
# 'danny-vega': [('dany-vega', 94.73684210526316)]
# 'damion-orlanday': [('damion-oranday', 96.55172413793103)]
# 'j.-calestine': [('jon-calestine', 88.0)]
# 'cameron-melott': [('cameron-mellott', 96.55172413793103)]
# 'jay-rodrigues': [('jay-rodriguez', 92.3076923076923)]
# 'q.-roszenweig': [('q.-rosenzweig', 92.3076923076923)]
# 'jb-bechloff': [('jb-bechtloff', 95.65217391304348)]
# 'andre-ribeiro': [('alexandre-ribeiro', 86.66666666666667)]
# 'dimitrus-souza': [('dimitrius-souza', 96.55172413793103)]
# 'marco-souza': [('marcos-souza', 95.65217391304348)]
# 'rafael-souza': [('rafael-sousa', 91.66666666666666)]
# 'fernando-ribas': [('fernando-reis', 88.88888888888889)]
# 'jonatas-gracie': [('jonnatas-gracie', 96.55172413793103)]
# 'joshua-hinger': [('josh-hinger', 91.66666666666666)]
# 'luciano-azevedo': [('luan-azevedo', 88.88888888888889)]
# 'roosevel-sousa': [('roosevelt-sousa', 96.55172413793103)]
# 'francisco-leon': [('francisco-lo', 92.3076923076923), ('francisco-neto', 85.71428571428572)]
# 'breno-lima': [('bruno-lima', 90.0)]
# 'marcin-klonowski': [('marian-klosowski', 87.5)]
# 'pawe-nedzi': [('pawel-nedzi', 95.23809523809523)]
# 'tomasz-skorowski': [('tomasz-skorkowski', 96.96969696969697)]
# 'tomasz-skorkowski': [('tomasz-skorowski', 96.96969696969697)]
# 'arturi-salas': [('arturo-salas', 91.66666666666666)]
# 'rodolpho-bonfim': [('rodolpho-bomfim', 93.33333333333333)]
# 'mateus-rodrigues': [('matheus-rodrigues', 96.96969696969697)]
# 'luciano-rodrigues': [('lucio-rodrigues', 93.75), ('luan-rodrigues', 90.32258064516128)]
# 'rodrigo-freitas': [('rodrigo-farias', 89.65517241379311)]
# 'diego-hertzog': [('diego-herzog', 96.0)]
# 'luan-rocha': [('luan-arouca', 85.71428571428572)]
# 'wellington-modena': [('wellinton-modena', 96.96969696969697)]
# 'joachim-svenson': [('joachim-sveinson', 96.7741935483871)]
# 'marerk-zbrog': [('marek-zbrog', 95.65217391304348)]
# 'gustavo-silva': [('gustavo-saraiva', 85.71428571428572)]
# 'maciek-kozak': [('maciej-kozak', 91.66666666666666)]
# 'patryk-wysocki': [('patryk-wysoki', 96.2962962962963)]
# 'wesley-archete': [('wesley-arquete', 85.71428571428572)]
# 'tyrone-goncalves': [('tyrone-gonsalves', 93.75)]
# 'matias-ribeiro': [('mathias-ribeiro', 96.55172413793103), ('marina-ribeiro', 85.71428571428572)]
# 'andre-freitas': [('andre-reis', 86.95652173913044)]
# 'basel-fanous': [('basel-fanos', 95.65217391304348)]
# 'manoel-oliveira': [('manuel-oliveira', 93.33333333333333)]
# 'm.-maciejewski': [('m.-maciejwski', 96.2962962962963)]
# 'steev-combourg': [('steeve-combourg', 96.55172413793103)]
# 'stan.-varshavskiyi': [('stan-varshavskiy', 94.11764705882352), ('s.-varshavskiy', 87.5)]
# 'luckasz-michalec': [('lukasz-michalec', 96.7741935483871), ('lucasz-michalec', 96.7741935483871)]
# 'sergio-iris': [('sergio-rios', 90.9090909090909)]
# 'toni-ferraz': [('tony-ferraz', 90.9090909090909)]
# 'anton-mikenko': [('anton-minenko', 92.3076923076923)]
# 'silviu-nastasa': [('silviu-natasha', 92.85714285714286)]
# 'abdulbary-guseinov': [('abdulbari-guseinov', 94.44444444444444)]
# 'karol-dzienisze': [('karol-dzieniszewski', 88.23529411764706)]
# 'marcos-ruiz': [('marcus-ruiz', 90.9090909090909)]
# 'almog-britch': [('almog-britsch', 96.0)]
# 'thiag-dalcol': [('thiago-dalcol', 96.0)]
# 'marcos-junior': [('marco-junior', 96.0)]
# 'pedro-dias': [('pedro-elias', 85.71428571428572)]
# 'p.-kwiatkowski': [('pawe-kwiatkowski', 86.66666666666667)]
# 'todd-mueckenheim': [('todd-muckenheim', 96.7741935483871)]
# 'eliot-kelly': [('elliot-kelly', 95.65217391304348), ('eliott-kelly', 95.65217391304348)]
# 'guthiery-barbosa': [('guthierry-barbosa', 96.96969696969697)]
# 'marcelo-ferreira': [('marcelo-pereira', 90.32258064516128), ('marlon-ferreira', 90.32258064516128)]
# 'a.-alexandrov': [('alex-alexandrov', 85.71428571428572)]
# 'erick-bergmann': [('eric-bergmann', 96.2962962962963)]
# 'gyla-szabo': [('gyula-szabo', 95.23809523809523)]
# 'vegard-randeberg': [('vegard-vanderberg', 90.9090909090909)]
# 'sean-fishman': [('shane-fishman', 88.0)]
# 'felipe-pinheiro': [('filipe-pinheiro', 93.33333333333333)]
# 'igor-souza': [('igor-sousa', 90.0)]
# 'robert-jimenez': [('roberto-jimenez', 96.55172413793103)]
# 'filipe-pimentel': [('felipe-pimentel', 93.33333333333333)]
# 'marco-junior': [('marcos-junior', 96.0)]
# 'matheus-rodrigues': [('mateus-rodrigues', 96.96969696969697)]
# 'mackenzie-morales': [('mckenzie-morales', 96.96969696969697)]
# 'vegard-vanderberg': [('vegard-randeberg', 90.9090909090909)]
# 'macos-carrozzino': [('marcos-carrozzino', 96.96969696969697)]
# 'mourice-ramirez': [('mourece-ramirez', 93.33333333333333)]
# 'gialyson-freitas': [('gialysson-freitas', 96.96969696969697)]
# 'rafael-fernandes': [('rafael-fernando', 90.32258064516128)]
# 'charlie-adorian': [('charles-adorian', 93.33333333333333)]
# 'a.-agazarm': [('aj-agazarm', 90.0)]
# 'daniel-marciano': [('daniel-garcia', 85.71428571428572)]
# 'thiago-reinaldo': [('tiago-reinaldo', 96.55172413793103)]
# 'kenneth-brown': [('keneth-brown', 96.0)]
# 'rafael-goulart': [('raphael-goulart', 89.65517241379311)]
# 'gabriel-timbo': [('gabriel-toribio', 85.71428571428572)]
# 'daniel-statsos': [('daniel-tsatsos', 92.85714285714286), ('daniel-strauss', 85.71428571428572)]
# 'gustavo-elias': [('gustavo-dias', 88.0)]
# 'victor-nathiel': [('victor-nithael', 85.71428571428572)]
# 'alex-soares': [('alef-soares', 90.9090909090909)]
# 'nathan-chueng': [('natan-chueng', 96.0)]
# 'leandro-rounaud-lima': [('leandro-rounaud', 85.71428571428572)]
# 'joao-menezes': [('joao-mendes', 86.95652173913044)]
# 'parick-possami': [('patrick-possamai', 93.33333333333333)]
# 'diogo-freitas': [('diogo-reis', 86.95652173913044)]
# 'adrian-kozisz': [('adrian-sozisz', 92.3076923076923), ('adrian-kozicz', 92.3076923076923)]
# 'jonatas-silva': [('jonatham-silva', 88.88888888888889)]
# 'kevin-machecha': [('kevin-mahecha', 96.2962962962963)]
# 'pablo-lavaseli': [('pablo-lavaselli', 96.55172413793103)]
# 'gustavo-vieira': [('gustavo-oliveira', 86.66666666666667)]
# 'marcio-silva': [('mario-silva', 95.65217391304348)]
# 'krzysztof-flak': [('krysztof-flak', 96.2962962962963)]
# 'tyrone-elliot': [('tyrone-elliott', 96.2962962962963)]
# 'luis-santos': [('luiz-santos', 90.9090909090909), ('lucas-santos', 86.95652173913044)]
# 'vinicius-ferreira': [('vinicius-ferrer', 93.75)]
# 'mario-silva': [('marcio-silva', 95.65217391304348), ('murilo-silva', 86.95652173913044)]
# 'marlos-salgado': [('marlus-salgado', 92.85714285714286)]
# 'j.-rocha': [('jp-rocha', 87.5)]
# 'isaias-higinio': [('isaias-higino', 96.2962962962963)]
# 'rehan-mutalib': [('rehan-muttalib', 96.2962962962963)]
# 'thiago-macedo': [('tiago-macedo', 96.0)]
# 'sebastiano-serpa': [('sebastian-serpa', 96.7741935483871)]
# 'gabriell-olinto': [('gabriel-olinto', 96.55172413793103)]
# 'guilherme-bacha': [('guilherme-rocha', 86.66666666666667)]
# 'william-shanon': [('william-shannon', 96.55172413793103)]
# 'kaiser-saulebayev': [('kaisar-saulebayev', 94.11764705882352)]
# 'jarred-dopp': [('jared-dopp', 95.23809523809523)]
# 'andre-rodolfo': [('andre-rudolfo', 92.3076923076923)]
# 'henrique-rossi': [('henrique-russi', 92.85714285714286), ('henrique-rios', 88.88888888888889)]
# 'antonio-asseff': [('antonio-assef', 96.2962962962963)]
# 'alisson-ferraz': [('ailson-ferraz', 88.88888888888889)]
# 'ruan-marques': [('ryan-marques', 91.66666666666666)]
# 'raul-gomez': [('raul-gomes', 90.0)]
# 'luan-pinheiro': [('luana-pinheiro', 96.2962962962963)]
# 'lincon-silva': [('lincoln-silva', 96.0)]
# 'talison-soares': [('thalison-soares', 96.55172413793103)]
# 'matheus-porto': [('mateus-porto', 96.0)]
# 'andre-soares': [('andrew-soares', 96.0)]
# 'francielo-costa': [('franciedson-costa', 87.5)]
# 'marcos-oliveira': [('marcus-oliveira', 93.33333333333333), ('marcelo-oliveira', 90.32258064516128)]
# 'luiz-tosta': [('luiz-costa', 90.0)]
# 'nobohiro-sawada': [('nobuhiro-sawada', 93.33333333333333)]
# 'maria-nascimento': [('marcio-nascimento', 90.9090909090909)]
# 'jadson-santos': [('jailson-santos', 88.88888888888889)]
# 'andre-costa': [('andreza-costa', 91.66666666666666)]
# 'fiona-mortell': [('fiona-mortel', 96.0)]
# 'alan-rodrigues': [('anna-rodrigues', 85.71428571428572)]
# 'sophia-cassaella': [('sophia-cassella', 96.7741935483871)]
# 'faisal-elkitbe': [('faisal-kitbe', 92.3076923076923)]
# 'rofolfo-vieira': [('rodolfo-vieira', 92.85714285714286)]
# 'alexandre-sousa': [('alexandre-souza', 93.33333333333333), ('alexandre-soca', 89.65517241379311), ('alexandre-rosa', 89.65517241379311)]
# 'leonardo-oliveira': [('leonardo-vieira', 87.5)]
# 'lucas-laet': [('lucas-leite', 85.71428571428572)]
# 'jonnatas-novaes': [('jonatas-novaes', 96.55172413793103)]
# 'robert-santos': [('roberto-satoshi', 85.71428571428572)]
# 'otavio-souza': [('otavio-sousa', 91.66666666666666)]
# 'rafael-ferreira': [('rafael-pereira', 89.65517241379311)]
# 'mario-andre': [('marcio-andre', 95.65217391304348)]
# 'stephan-martinez': [('stephen-martinez', 93.75)]
# 'jake-mckenzie': [('jake-mackenzie', 96.2962962962963)]
# 'jose-cardoso': [('jose-carlos', 86.95652173913044)]
# 'marcelo-augusto': [('marcelo-fausto', 89.65517241379311)]
# 'tiago-cintra': [('thiago-cintra', 96.0)]
# 'andrew-alexandre': [('andrew-alexander', 93.75)]
# 'josh-mckinney': [('joshua-mckinney', 92.85714285714286)]
# 'dave-asare': [('davis-asare', 85.71428571428572)]
# 'oliver-geddess': [('oliver-geddes', 96.2962962962963)]
# 'antonio-antonioli': [('antonio-antoniolli', 97.14285714285714)]
# 'dennis-prokopos': [('denny-prokopos', 89.65517241379311)]
# 'diogo-reis': [('diogo-freitas', 86.95652173913044)]
# 'steven-barrett': [('steven-barnett', 92.85714285714286), ('steven-barerre', 85.71428571428572), ('steven-barrere', 85.71428571428572)]
# 'peter-cruz': [('peter-runez', 85.71428571428572)]
# 'erico-cocco': [('enrico-cocco', 95.65217391304348)]
# 'unknown': [('uknown', 92.3076923076923)]
# 'bricklin-welch': [('briklin-welch', 96.2962962962963)]
# 'pablo-henrique': [('paulo-henrique', 92.85714285714286)]
# 'ralf-carneborn': [('ralf-carneburn', 92.85714285714286)]
# 'mario-henrique': [('mauricio-henrique', 90.32258064516128), ('marcelo-henrique', 86.66666666666667), ('marcos-enrique', 85.71428571428572)]
# 'washington-luis': [('washington-lima', 86.66666666666667)]
# 'antonio-antoniolli': [('antonio-antonioli', 97.14285714285714)]
# 'marcelo-goncalves': [('marcel-goncalves', 96.96969696969697), ('mario-goncalves', 87.5)]
# 'jorge-luis': [('jorge-elias', 85.71428571428572)]
# 'nic-nikolaisen': [('nik-nikolaisen', 92.85714285714286)]
# 'luis-rosa': [('luiz-rosa', 88.88888888888889)]
# 'lucas-carvalho': [('luan-carvalho', 88.88888888888889)]
# 'dan-strauss': [('daniel-strauss', 88.0)]
# 'filipe-cesar': [('felipe-cesar', 91.66666666666666)]
# 'pedro-henriques': [('pedro-henrique', 96.55172413793103)]
# 'itua-salles': [('itua-sales', 95.23809523809523)]
# 'nichollas-welker': [('nicollas-welker', 96.7741935483871)]
# 'peter-frank': [('piter-frank', 90.9090909090909)]
# 'bret-russell': [('bret-russel', 95.65217391304348)]
# 'ron-henderson': [('ronald-henderson', 89.65517241379311)]
# 'staley-rosa': [('stanley-rosa', 95.65217391304348)]
# 'isa-able': [('issa-able', 94.11764705882352)]
# 'samuel-davis': [('samuel-dias', 86.95652173913044)]
# 'nick-ryan': [('nicky-ryan', 94.73684210526316)]
# 'lachlan-gile': [('lachlan-giles', 96.0)]
# 'marco-galvao': [('marcos-galvao', 96.0)]
# 'daniel-leith': [('daniel-seth', 86.95652173913044)]
# 'zachary-lecates': [('zachary-legates', 93.33333333333333)]
# 'cody-orrisson': [('cody-orrison', 96.0)]
# 'guto-campos': [('gustavo-campos', 88.0)]
# 'tarsys-humphreys': [('tarsis-humphreys', 93.75)]
# 'eduardo-ramos': [('eduardo-campos', 88.88888888888889)]
# 'renato-moraes': [('renato-morais', 92.3076923076923)]
# 'm.-carvalho': [('max-carvalho', 86.95652173913044)]
# 'julien-crazier': [('julien-cazier', 96.2962962962963)]
# 'alvaro-oliveira': [('alvaro-oliveiro', 93.33333333333333), ('alan-oliveira', 85.71428571428572)]
# 'filipe-bobrick': [('filipe-brobrick', 96.55172413793103), ('felipe-bobrick', 92.85714285714286), ('felipe-brobrick', 89.65517241379311)]
# 'benjamin-silva': [('benji-silva', 88.0)]
# 'rodrigo-gortati': [('rodrigo-gortari', 93.33333333333333)]
# 'vince-pezzuto': [('vincent-pezzuto', 92.85714285714286)]
# 'jz-cavalcanti': [('jz-cavalcante', 92.3076923076923)]
# 'don-stoner': [('donald-stoner', 86.95652173913044)]
# 'rehan-silva': [('rhehan-silva', 95.65217391304348)]
# 'saul-viarya': [('saul-viayra', 90.9090909090909)]
# 'jon-piersma': [('j-piersma', 90.0)]
# 'danny-stolfi': [('danny-stolfy', 91.66666666666666)]
# 'dylan-garafalo': [('dylan-garofalo', 92.85714285714286)]
# 'issa-able': [('isa-able', 94.11764705882352)]
# 'harrison-wood': [('harrison-woods', 96.2962962962963)]
# 'ricardo-rea': [('ricardo-pena', 86.95652173913044), ('ricardo-a.', 85.71428571428572)]
# 'matheus-cunha': [('matheus-luna', 88.0)]
# 'chris-wojick': [('chris-wocjik', 91.66666666666666)]
# 'bruno-tostes': [('bruno-tosto', 86.95652173913044)]
# 'tarik-hopstok': [('tarik-hopstock', 96.2962962962963)]
# 'esdras-barbosa': [('endres-barbosa', 85.71428571428572)]
# 'luis-brito': [('lucas-brito', 85.71428571428572)]
# 'harrysson-pereira': [('harryson-pereira', 96.96969696969697)]
# 'alejander-mariano': [('alehander-mariano', 94.11764705882352)]
# 'andreza-costa': [('andre-costa', 91.66666666666666)]
# 'gustavo-epee': [('gustav-espee', 91.66666666666666)]
# 'diego-sato': [('diego-pato', 90.0)]
# 'tiago-gaia': [('thiago-gaia', 95.23809523809523)]
# 'tommi-pulkkannen': [('tommi-pulkannen', 96.7741935483871), ('tommi-pulkkanen', 96.7741935483871), ('tommi-puulkannen', 93.75)]
# 'tyson-atillon': [('tyson-antillon', 96.2962962962963)]
# 'juan-cleber': [('juan-kleber', 90.9090909090909)]
# 'clayton-mayfield': [('clay-mayfield', 89.65517241379311)]
# 'fabricio-barbaroti': [('fabricio-barbarotti', 97.2972972972973)]
# 'chris-graves': [('chris-gores', 86.95652173913044)]
# 'carlos-andrade': [('carlos-andre', 92.3076923076923)]
# 'rafael-silva': [('rafal-silva', 95.65217391304348), ('rafael-silveira', 88.88888888888889)]
# 'ricardo-brito': [('ricardo-briceno', 85.71428571428572)]
# 'rehan-muttalib': [('rehan-mutalib', 96.2962962962963)]
# 'joao-marco': [('joao-marcio', 95.23809523809523), ('joao-marcelo', 90.9090909090909)]
# 'tiago-andrade': [('thiago-andrade', 96.2962962962963)]
# 'sophia-cassella': [('sophia-cassaella', 96.7741935483871)]
# 'andreza-morais': [('andressa-morais', 89.65517241379311)]
# 'alexandra-trevino': [('alexa-trevino', 86.66666666666667)]
# 'cindy-hung': [('cindy-ung', 94.73684210526316)]
# 'andrea-mario': [('andrea-amaro', 91.66666666666666)]
# 'vitor-chelloni': [('vitor-cheloni', 96.2962962962963)]
# 'jose-bisneto': [('jose-neto', 85.71428571428572)]
# 'vinicius-jesus': [('vinicius-de-jesus', 90.32258064516128)]
# 'rafael-silveira': [('rafael-silva', 88.88888888888889)]
# 'brenno-veloso': [('bruno-veloso', 88.0)]
# 'diego-almeida': [('diogo-almeida', 92.3076923076923)]
# 'rafael-sousa': [('rafael-souza', 91.66666666666666)]
# 'vinicius-soares': [('vinicius-torres', 86.66666666666667), ('vinicius-reis', 85.71428571428572)]
# 'alexandre-soca': [('alexandre-sousa', 89.65517241379311), ('alexandre-souza', 89.65517241379311), ('alexandre-rocha', 89.65517241379311), ('alexandre-rosa', 85.71428571428572)]
# 'raimon-rosa': [('ramon-rosa', 95.23809523809523)]
# 'hugo-gabino': [('hugo-gambino', 95.65217391304348)]
# 'matheus-felix': [('matheus-felipe', 88.88888888888889)]
# 'tiago-pessoa': [('thiago-pessoa', 96.0)]
# 'karol-kaina': [('karol-kania', 90.9090909090909)]
# 'erick-diovanni': [('erick-diovano', 88.88888888888889)]
# 'vinicius-marinho': [('vinicius-marilho', 93.75)]
# 'leonardo-moura': [('leonardo-souza', 85.71428571428572)]
# 'leo-brito': [('leon-brito', 94.73684210526316)]
# 'evertom-freitas': [('everton-freitas', 93.33333333333333)]
# 'thiago-andrade': [('tiago-andrade', 96.2962962962963)]
# 'marcelo-lemelle': [('marcello-lemelle', 96.7741935483871)]
# 'manuel-porto': [('manoel-porto', 91.66666666666666)]
# 'b.-george': [('b.-georgy', 88.88888888888889)]
# 'roberto-ribeiro': [('roberta-ribeiro', 93.33333333333333), ('roberto-roberto', 86.66666666666667)]
# 'thomas-johanessen': [('thomas-johannessen', 97.14285714285714), ('thomas-johanssen', 96.96969696969697), ('thomas-johansen', 93.75)]
# 'raphael-goulart': [('rafael-goulart', 89.65517241379311)]
# 'william-de-lima': [('william-lima', 88.88888888888889)]
# 'morris-ayala': [('moris-ayala', 95.65217391304348)]
# 'diogo-borges': [('diego-borges', 91.66666666666666)]
# 'carlinhos-faria': [('carlos-farias', 85.71428571428572)]
# 'otavio-nalatti': [('otavio-nalati', 96.2962962962963)]
# 'samuel-wells': [('sam-wells', 85.71428571428572)]
# 'mario-gonzalez': [('mario-gonzales', 92.85714285714286)]
# 'jonathan-ares': [('jhonathan-marques', 86.66666666666667), ('jonathan-andrew', 85.71428571428572)]
# 'josh-guerra': [('joshua-guerra', 91.66666666666666)]
# 'wallison-oliveira': [('wallisson-oliveira', 97.14285714285714)]
# 'heltor-senra': [('heitor-senra', 91.66666666666666)]
# 'matheus-moraes': [('mateus-moraes', 96.2962962962963)]
# 'vinicius-marilho': [('vinicius-marinho', 93.75)]
# 'chairo-olimpio': [('chaise-olimpio', 85.71428571428572)]
# 'marco-aurelio': [('marcos-aurelio', 96.2962962962963)]
# 'davi-raab': [('david-raab', 94.73684210526316)]
# 'yago-rodrigues': [('ygor-rodrigues', 92.85714285714286)]
# 'welington-marques': [('wellington-marques', 97.14285714285714)]
# 'alexsandro-pereira': [('alexandre-pereira', 91.42857142857143), ('alessandro-ferreira', 86.48648648648648)]
# 'o.-kassimov': [('o.-kasimov', 95.23809523809523)]
# 'pedro-farkas': [('pedro-farias', 91.66666666666666)]
# 'cristian-dellavag': [('christian-dellevag', 91.42857142857143)]
# 'chaise-olimpio': [('chairo-olimpio', 85.71428571428572)]
# 'jose-diaz': [('jose-dias', 88.88888888888889)]
# 'fabricio-barros': [('fabricio-barbosa', 90.32258064516128)]
# 'lucas-domingos': [('luis-domingos', 88.88888888888889)]
# 'alexandre-paiva': [('alexandre-silva', 86.66666666666667)]
# 'victor-matos': [('vitor-matos', 95.65217391304348), ('victor-santos', 88.0)]
# 'joao-marcelo': [('joao-marco', 90.9090909090909), ('joao-marcio', 86.95652173913044)]
# 'fabricio-barbarotti': [('fabricio-barbaroti', 97.2972972972973)]
# 'erick-souza': [('eric-souza', 95.23809523809523)]
# 'fernando-matos': [('fernando-santos', 89.65517241379311)]
# 'roger-gracie': [('roger-graci.', 91.66666666666666), ('royler-gracie', 88.0)]
# 'mario-barbosa': [('marco-barbosa', 92.3076923076923)]
# 'marco-mendes': [('marcelo-mendes', 92.3076923076923)]
# 'wellington-lima': [('wellington-dias', 86.66666666666667)]
# 'robson-gracie': [('robin-gracie', 88.0)]
# 'otavio-coutinho': [('octavio-couto', 85.71428571428572)]
# 'sasha-plavski': [('sasha-palvski', 92.3076923076923)]
# 'fernando-gomes': [('fernando-lopes', 85.71428571428572)]
# 'sasha-palvski': [('sasha-plavski', 92.3076923076923)]
# 'joey-gilbert': [('joe-gilbert', 95.65217391304348)]
# 'higor-marques': [('hugo-marques', 88.0)]
# 'felipe-cesar': [('filipe-cesar', 91.66666666666666)]
# 'andre-goes': [('andre-gomes', 95.23809523809523)]
# 'lucas-foguinho': [('lucas-moutinho', 85.71428571428572)]
# 'daniel-baia': [('daniel-maira', 86.95652173913044)]
# 'jonathan-satava': [('johnathan-satava', 96.7741935483871)]
# 'sean-fischer': [('sean-fisher', 95.65217391304348)]
# 'carlos-newton': [('carlos-neto', 91.66666666666666)]
# 'levi-j-leary': [('levi-jones-leary', 85.71428571428572)]
# 'micheal-neary': [('michael-neary', 92.3076923076923)]
# 'jakub-bajdek': [('jakub-najdek', 91.66666666666666)]
# 'elliot-kelly': [('eliot-kelly', 95.65217391304348), ('eliott-kelly', 91.66666666666666)]
# 'fabio-pititto': [('fabricio-pitittio', 86.66666666666667)]
# 'lucas-moutinho': [('lucas-foguinho', 85.71428571428572)]
# 'ganriel-avila': [('gabriel-avila', 92.3076923076923)]
# 'rodrigo-paixao': [('rodrigo-praia', 88.88888888888889)]
# 'marcello-lemelle': [('marcelo-lemelle', 96.7741935483871)]
# 'jefferson-ramos': [('jeferson-ramos', 96.55172413793103)]
# 'leonardo-vieira': [('leonardo-oliveira', 87.5), ('leonardo-vilela', 86.66666666666667)]
# 'wesley-possamai': [('weslei-possamai', 93.33333333333333)]
# 'andre-lipenski': [('andre-lipienski', 96.55172413793103)]
# 'icaro-oliveira': [('italo-oliveira', 85.71428571428572)]
# 'weslei-possamai': [('wesley-possamai', 93.33333333333333)]
# 'javi-barter': [('javier-barter', 91.66666666666666)]
# 'jose-neto': [('jose-bisneto', 85.71428571428572)]
# 'wallison-souza': [('wallisson-souza', 96.55172413793103)]
# 'gabriel-olinto': [('gabriell-olinto', 96.55172413793103)]
# 'mateus-pereira': [('matheus-pereira', 96.55172413793103), ('matheus-ferreira', 86.66666666666667)]
# 'sean-golbsy': [('sean-goolsby', 86.95652173913044)]
# 'jocsan-silva': [('joian-silva', 86.95652173913044)]
# 'leandro-rounaud': [('leandro-rounaud-lima', 85.71428571428572)]
# 'luis-eduardo': [('luis-eduhardo', 96.0)]
# 'rafael-babosa': [('rafael-barbosa', 96.2962962962963)]
# 'diogo-silva': [('diego-silva', 90.9090909090909), ('diogo-silveira', 88.0)]
# 'm.-abdulkaridov': [('m.-abdulkadirov', 86.66666666666667)]
# 'gabriela-pereira': [('gabriel-ferreira', 87.5)]
# 'lautaro-sanguime': [('lautaro-sanguimene', 94.11764705882352)]
# 'jeff-cummings': [('jef.-cummings', 92.3076923076923)]
# 'briklin-welch': [('bricklin-welch', 96.2962962962963)]
# 'breno-bitencourt': [('breno-bittencourt', 96.96969696969697)]
# 'james-guion': [('james-guyton', 86.95652173913044)]
# 'gustav-espee': [('gustavo-epee', 91.66666666666666)]
# 'daniel-silva': [('danilo-silva', 91.66666666666666)]
# 'khristopher-santos': [('kristopher-santos', 97.14285714285714)]
# 'cesar-caramajo': [('cesar-casamajo', 92.85714285714286)]
# 'nicholas-renier': [('nicolas-renier', 96.55172413793103), ('nicholas-reiner', 93.33333333333333), ('nicolas-reiner', 89.65517241379311), ('nicholas-penzer', 86.66666666666667)]
# 'filipe-desouza': [('felipe-desouza', 92.85714285714286)]
# 'josh-bacallao': [('joshua-bacallao', 92.85714285714286)]
# 'murat-besnek': [('murat-besnet', 91.66666666666666)]
# 'john-lenno': [('john-lennon', 95.23809523809523)]
# 'ayub-mogamadov': [('ayub-mogomadov', 92.85714285714286), ('ayub-magomadov', 85.71428571428572)]
# 'keji-sette': [('kenji-sette', 95.23809523809523)]
# 'cesar-miahira': [('cesar-miyahira', 96.2962962962963)]
# 'adam-perez': [('adria-perez', 85.71428571428572)]
# 'joe-breslin': [('joseph-breslin', 88.0)]
# 'tyson-antillon': [('tyson-atillon', 96.2962962962963)]
# 'jonathan-maflin': [('jonothan-maflin', 93.33333333333333)]
# 'ferando-cabrera': [('fernando-cabrera', 96.7741935483871)]
# 'kevin-melendrez': [('kevin-melendez', 96.55172413793103)]
# 'brandon-wilson': [('brandon-wilkinson', 90.32258064516128)]
# 'fernando-reis': [('fernando-ribas', 88.88888888888889)]
# 'edmond-kim': [('edmund-kim', 90.0)]
# 'matheus-galacio': [('matheus-galvao', 89.65517241379311)]
# 'desmond-mcdonald': [('desond-mcdonald', 96.7741935483871)]
# 'gustavo-esteban': [('gustavo-estebam', 93.33333333333333)]
# 'chris-passarrello': [('chris-passarello', 96.96969696969697)]
# 'guilherme-higino': [('guilherme-higuino', 96.96969696969697), ('guilherme-higinio', 96.96969696969697)]
# 'guilherme-higuino': [('guilherme-higino', 96.96969696969697), ('guilherme-higinio', 94.11764705882352)]
# 'alex.-cacareco': [('a.-cacareco', 88.0)]
# 'roger-graci.': [('roger-gracie', 91.66666666666666)]
# 'marcelinho-garcia': [('marcelo-garcia', 90.32258064516128)]
# 'marcio-corletta': [('marcio-corleta', 96.55172413793103)]
# 'denis-gomes': [('dennis-gomes', 95.65217391304348)]
# 'eric-wanderlei': [('erik-wanderlei', 92.85714285714286)]
# 'eliot-marshall': [('eliot-marshal', 96.2962962962963)]
# 'jon-einemo': [('john-einimo', 85.71428571428572)]
# 'antoine-jaoude': [('antoine-joude', 96.2962962962963)]
# 'ricardo-moraes': [('ricardo-morais', 92.85714285714286)]
# 'yukiyasu-ozawa': [('yukissyu-ozawa', 85.71428571428572)]
# 'cristiano-lazzarinni': [('cristiano-lazzarini', 97.43589743589743)]
# 'luis-theodoro': [('luiz-theodoro', 92.3076923076923)]
# 'gabriel-vilella': [('gabriel-vella', 92.85714285714286), ('gabriel-avila', 85.71428571428572)]
# 'daniel-simmler': [('dan-simmler', 88.0)]
# 'chris-moriarty': [('chris-moriarity', 96.55172413793103)]
# 'ryan-beauregard': [('ryan-beuregard', 96.55172413793103)]
# 'eduardo-silveira': [('eduardo-silva', 89.65517241379311), ('eduardo-vieira', 86.66666666666667)]
# 'alexadre-ceconi': [('alexandre-ceconi', 96.7741935483871)]
# 'yukissyu-ozawa': [('yukiyasu-ozawa', 85.71428571428572)]
# 'karim-kalifah': [('karim-khalifa', 92.3076923076923)]
# 'marcos-santos': [('marcus-santos', 92.3076923076923), ('marcelo-santos', 88.88888888888889)]
# 'jonas-henrique': [('jose-henrique', 88.88888888888889)]
# 'emiliani-simeone': [('emiliano-simone', 90.32258064516128)]
# 'giovanni-della': [('giovanne-della', 92.85714285714286)]
# 'emiliano-simone': [('emiliani-simeone', 90.32258064516128)]
# 'rodrigo-lima': [('rodrigo-limera', 92.3076923076923)]
# 'john-slater': [('john-salter', 90.9090909090909)]
# 'ruslam-chsiev': [('rustam-chsiev', 92.3076923076923)]
# 'alexandre-santos': [('alexandre-dantas', 87.5)]
# 'marcus-ruiz': [('marcos-ruiz', 90.9090909090909)]
# 'fernando-carsalade': [('fernando-carsadale', 88.88888888888889)]
# 'victor-moraes': [('vitor-moraes', 96.0)]
# 'rodrigo-modrias': [('rodrigo-dias', 88.88888888888889)]
# 'vitor-moraes': [('victor-moraes', 96.0)]
# 'victor-doria': [('viktor-doria', 91.66666666666666)]
# 'breno-celio': [('bruno-celio', 90.9090909090909)]
# 'pedro-bisneto': [('pedro-neto', 86.95652173913044)]
# 'tuomas-tammilehto': [('tuomas-tamilehto', 96.96969696969697)]
# 'raphael-cadema': [('raphael-cadena', 92.85714285714286)]
# 'igor-terraceo': [('igor-terreco', 88.0)]
# 'estras-junior': [('esdras-junior', 92.3076923076923)]
# 'ygor-rodrigues': [('yago-rodrigues', 92.85714285714286)]
# 'david-oliveira': [('davi-oliveira', 96.2962962962963)]
# 'geoffrey-villareal': [('geoffrey-villarreal', 97.2972972972973), ('geoff-villareal', 90.9090909090909), ('geoff-villarreal', 88.23529411764706)]
# 'fatima-kleine': [('fatima-kline', 96.0)]
# 'joanie-chamberland': [('joanie-chamberlain', 94.44444444444444)]
# 'haley-zhanow': [('haley-zahnow', 91.66666666666666)]
# 'nicole-mathew': [('nicole-matthew', 96.2962962962963)]
# 'bridget-mceliece': [('briget-mceliece', 96.7741935483871)]
# 'bernardo-campos': [('bernardita-campos', 87.5)]
# 'ed-cummings': [('e.-cummings', 90.9090909090909)]
# 'nicky-ryan': [('nick-ryan', 94.73684210526316)]
# 'paulo-silva': [('paulo-siva', 95.23809523809523)]
# 'pedro-elias': [('pedro-dias', 85.71428571428572)]
# 'wellington-dias': [('wellington-lima', 86.66666666666667), ('wellington-paes', 86.66666666666667)]
# 'r.-olivier': [('r.-oliveira', 85.71428571428572)]
# 'juan-lopez': [('juan-lopes', 90.0)]
# 'juan-lopes': [('juan-lopez', 90.0)]
# 'andrey-adam': [('audrey-adam', 90.9090909090909)]
# 'paulo-mello': [('paulo-melo', 95.23809523809523)]
# 'perez-figueiroa': [('perez-figueroa', 96.55172413793103)]
# 'mo-ali-hayat': [('mohd-ali-hayat', 92.3076923076923)]
# 'pedro-valencia': [('pedro-valenca', 96.2962962962963)]
# 'ulysses-fagundes': [('ulysses-faguntes', 93.75)]
# 'alexandre-oliveira': [('alexandre-vieira', 88.23529411764706)]
# 'marcus-santos': [('marcos-santos', 92.3076923076923)]
# 'audrey-adam': [('andrey-adam', 90.9090909090909)]
# 'williams-campos': [('william-campos', 96.55172413793103)]
# 'g.-augusto': [('gui-augusto', 85.71428571428572)]
# 'andre-rico': [('andre-brito', 85.71428571428572)]
# 'l.-lira': [('l.-lima', 85.71428571428572)]
# 'garett-beck': [('garrett-beck', 95.65217391304348)]
# 'sam-mc-nally': [('sam-mcnally', 95.65217391304348)]
# 'eduardo-de-jesus': [('eduardo-jesus', 89.65517241379311)]
# 'hiago-lima': [('higor-lima', 90.0)]
# 'rodney-barbosa': [('rodnei-barbosa', 92.85714285714286)]
# 'thiago-cintra': [('tiago-cintra', 96.0)]
# 'gustavo-estebam': [('gustavo-esteban', 93.33333333333333)]
# 'mateus-lima': [('matheus-lima', 95.65217391304348)]
# 'guilherme-dal-pra': [('guilherme-dalpra', 96.96969696969697)]
# 'guilherme-neves': [('guilherme-neres', 93.33333333333333), ('guilherme-jones', 86.66666666666667)]
# 'guilherme-milan': [('guilherme-silva', 86.66666666666667)]
# 'eduard-lucero': [('edward-lucero', 92.3076923076923)]
# 'guilherme-mendes': [('guilherme-fernandes', 85.71428571428572)]
# 'anderson-lira': [('anderson-lima', 92.3076923076923)]
# 'tim-hinrich': [('tim-hinrichs', 95.65217391304348)]
# 'jefferson-gomes': [('jefferson-goteu', 86.66666666666667)]
# 'm.-murtazaliev': [('m.-muratazaliev', 96.55172413793103)]
# 'nino-ambrosio': [('nino-ambrosini', 88.88888888888889)]
# 'flavio-serafim': [('flavio-serafin', 92.85714285714286)]
# 'flavio-serafin': [('flavio-serafim', 92.85714285714286)]
# 'don-schon': [('dan-schon', 88.88888888888889)]
# 'sebastien-lecoq': [('sebastien-lecocq', 96.7741935483871)]
# 'jan-baso': [('jan-basso', 94.11764705882352)]
# 'b.-menmahammed': [('b.-benmahammed', 92.85714285714286)]
# 'bilal-benmahammmed': [('bilal-benmahammed', 97.14285714285714)]
# 'j-bezerra': [('joao-bezerra', 85.71428571428572)]
# 'pavel-kavesnik': [('pavel-kalesnik', 92.85714285714286)]
# 'thabet-al-taher': [('thabet-altaher', 96.55172413793103)]
# 'grant-bogdanov': [('grant-bogdanove', 96.55172413793103)]
# 'mooelehe-cuellar': [('moolele-cuellar', 90.32258064516128)]
# 'melissa-cueto': [('melisa-cueto', 96.0)]
# 'briget-mceliece': [('bridget-mceliece', 96.7741935483871)]
# 'elizabeth-mitrov': [('elizabeth-mitrovic', 94.11764705882352)]
# 'chayse-diekema': [('chayse-diekma', 96.2962962962963)]
# 'maria-ruffato': [('maria-ruffatto', 96.2962962962963)]
# 'melisa-cueto': [('melissa-cueto', 96.0)]
# 'stephanie-delphin': [('stephanie-delphine', 97.14285714285714)]
# 'leticia-cartozo': [('leticia-cardozo', 93.33333333333333)]
# 'julia-maee': [('julia-maele', 95.23809523809523)]
# 'britney-elkin': [('brittney-elkin', 96.2962962962963)]
# 'fernanda-mazzeli': [('fernanda-mazzelli', 96.96969696969697)]
# 'maria-malyjasik': [('maria-malyjasiak', 96.7741935483871)]
# 'maissa-gurgel': [('maisa-gurgel', 96.0)]
# 'isadora-cristina': [('izadora-cristina', 93.75)]
# 'izadora-cristina': [('isadora-cristina', 93.75)]
# 'graciele-del-fava': [('graciele-fava', 86.66666666666667)]
# 'maria-karolina': [('maria-carolina', 92.85714285714286)]
# 'andre-cavalcante': [('andreia-cavalcante', 94.11764705882352)]
# 'alex-arantes': [('alexia-arantes', 92.3076923076923)]
# 'maria-luisa': [('maria-luiza', 90.9090909090909)]
# 'suellen-desterro': [('suelen-desterro', 96.7741935483871)]
# 'alexandre-silva': [('alexandre-paiva', 86.66666666666667), ('alexandr-silaev', 86.66666666666667)]
# 'ryron-gracie': [('rayron-gracie', 96.0)]
# 'akira-shoji': [('akira-shouji', 95.65217391304348)]
# 'thaynara-ferreira': [('thamara-ferreira', 90.9090909090909)]
# 'amy-dadwell': [('amy-cadwell', 90.9090909090909)]
# 'edin-johnson': [('erin-johnson', 91.66666666666666)]
# 'vanessa-griffin': [('vannessa-griffin', 96.7741935483871)]
# 'brethany-wright': [('bethany-wright', 96.55172413793103)]
# 'polyana-araujo': [('polyanna-araujo', 96.55172413793103)]
# 'maria-vincentini': [('maria-vicentini', 96.7741935483871)]
# 'n.-blackman': [('nia-blackman', 86.95652173913044)]
# 'walllace-costa': [('wallace-costa', 96.2962962962963)]
# 'marcelo-montoro': [('marcelo-monteiro', 90.32258064516128)]
# 'maique-azavedo': [('maique-azevedo', 92.85714285714286)]
# 'harryson-pereira': [('harrysson-pereira', 96.96969696969697)]
# 'luan-silva': [('luanna-silva', 90.9090909090909), ('lunna-silva', 85.71428571428572)]
# 'elioenai-braz': [('elionai-braz', 96.0)]
# 'nicolas-santos': [('nicollas-santos', 96.55172413793103)]
# 'gabriel-marinho': [('gabriel-martins', 86.66666666666667)]
# 'cleiton-flores': [('cleyton-flores', 92.85714285714286)]
# 'julian-stonkek': [('julian-stonjek', 92.85714285714286)]
# 'joao-vieira': [('joao-viera', 95.23809523809523)]
# 'leonardo-brocca': [('leonardo-rocha', 89.65517241379311)]
# 'carlos-goncalves': [('caio-goncalves', 86.66666666666667), ('carlos-alves', 85.71428571428572)]
# 'matheus-d-oliveira': [('matheus-oliveira', 94.11764705882352)]
# 'pedro-matias': [('pedro-maia', 90.9090909090909)]
# 'lucas-canto': [('lucas-santos', 86.95652173913044), ('lucas-castro', 86.95652173913044)]
# 'julian-syan': [('julian-synan', 95.65217391304348)]
# 'tiago-alves': [('thiago-alves', 95.65217391304348)]
# 'thiago-gaia': [('tiago-gaia', 95.23809523809523)]
# 'anthony-erbert': [('anthony-elbert', 92.85714285714286)]
# 'clay-mayfield': [('clayton-mayfield', 89.65517241379311)]
# 'gialysson-freitas': [('gialyson-freitas', 96.96969696969697)]
# 'eduardo-santos': [('eduardo-santoro', 89.65517241379311)]
# 'fernando-di-piero': [('fernando-piero', 90.32258064516128)]
# 'max-carvalho': [('m.-carvalho', 86.95652173913044)]
# 'marcel-louzado': [('marcelo-louzado', 96.55172413793103)]
# 'chris-wideman': [('chris-weidman', 92.3076923076923)]
# 'diogo-gamonal': [('diego-gamonal', 92.3076923076923)]
# 'nolan-dutcher': [('nol.-dutcher', 88.0)]
# 'rustam-chsiev': [('ruslam-chsiev', 92.3076923076923)]
# 'rayron-gracie': [('ryron-gracie', 96.0)]
# 'james-sargison': [('james-harbison', 85.71428571428572)]
# 'nik-ruben': [('nic-ruben', 88.88888888888889)]
# 'gabriel-roseberg': [('gabriel-rosenberg', 96.96969696969697)]
# 'thomas-johannessen': [('thomas-johanessen', 97.14285714285714), ('thomas-johanssen', 94.11764705882352), ('thomas-johansen', 90.9090909090909)]
# 'alexandre-ceconi': [('alexadre-ceconi', 96.7741935483871)]
# 'thiago-pessoa': [('tiago-pessoa', 96.0)]
# 'filipe-mota': [('felipe-mota', 90.9090909090909)]
# 'thiago-abreu': [('thiago-abud', 86.95652173913044)]
# 'lucas-lira': [('luccas-lira', 95.23809523809523)]
# 'ryan-aiken': [('ryan-aitken', 95.23809523809523)]
# 'jordan-more': [('jordan-moore', 95.65217391304348)]
# 'stuart-maddoc': [('stuart-maddox', 92.3076923076923)]
# 'mckenzie-morales': [('mackenzie-morales', 96.96969696969697)]
# 'nathan-mendesohn': [('nathan-mendelsohn', 96.96969696969697), ('nathan-mendelson', 93.75)]
# 'lucas-leite': [('lucas-laet', 85.71428571428572)]
# 'joao-pedro': [('joao-pedrosa', 90.9090909090909)]
# 'andreia-cavalcante': [('andre-cavalcante', 94.11764705882352)]
# 'tiago-santos': [('thiago-santos', 96.0)]
# 'delso-heleno': [('delson-heleno', 96.0)]
# 'breno-peterson': [('bryan-peterson', 85.71428571428572)]
# 'stephen-hergett': [('stephen-hargett', 93.33333333333333)]
# 'felipe-pimentel': [('filipe-pimentel', 93.33333333333333)]
# 'd.-martinez': [('dan-martinez', 86.95652173913044)]
# 'sergio-vilas': [('sergio-villas', 96.0)]
# 'enrique-falarza': [('enrique-galarza', 93.33333333333333)]
# 'daniel-maguire': [('daniel-mcguire', 92.85714285714286), ('daniel-aguiar', 88.88888888888889), ('daniel-aguilar', 85.71428571428572)]
# 'b.-georgy': [('b.-george', 88.88888888888889)]
# 'a.-la-montague': [('a.-la-montagne', 92.85714285714286)]
# 'david-stoil': [('david-stoyle', 86.95652173913044)]
# 'chris-wocjik': [('chris-wojick', 91.66666666666666)]
# 'enrico-said': [('erico-said', 95.23809523809523)]
# 'brandon-manarin': [('brandon-mandarim', 90.32258064516128)]
# 'thiago-carvalho': [('tiago-carvalho', 96.55172413793103)]
# 'leonardo-martins': [('leonardo-mario', 86.66666666666667)]
# 'khalel-alshehhi': [('khaled-alshehi', 89.65517241379311)]
# 'xavier-bas': [('xavi-bas', 88.88888888888889)]
# 'klaus-meine': [('klaus-maine', 90.9090909090909)]
# 'mateus-fonseca': [('matheus-fonseca', 96.55172413793103)]
# 'flavio-fernandes': [('fabio-fernandes', 90.32258064516128)]
# 'jeferson-fagundes': [('jefferson-fagundes', 97.14285714285714)]
# 'felipe-simao': [('felipe-simoes', 88.0)]
# 'tadiyah-danfort': [('tadiyah-danforth', 96.7741935483871)]
# 'marko-oikaraine': [('marko-oikarainen', 96.7741935483871)]
# 'omar-alswaidi': [('omar-alsuwaidi', 96.2962962962963)]
# 'matheus-honda': [('matheus-onda', 96.0)]
# 'isaiah-right': [('isiah-wright', 91.66666666666666)]
# 'vitor-silva': [('victor-silva', 95.65217391304348)]
# 'rafael-domngos': [('rafael-domingos', 96.55172413793103)]
# 'gabriela-matos': [('gabriel-santos', 85.71428571428572)]
# 'daniel-manasoiou': [('daniel-manasoiu', 96.7741935483871), ('dan-manasoiu', 85.71428571428572)]
# 'damion-anderson': [('damien-anderson', 93.33333333333333)]
# 'fabio-ramirez': [('fabian-ramirez', 88.88888888888889)]
# 'rene-souza': [('rene-sousa', 90.0)]
# 'robert-winther': [('rob-winther', 88.0)]
# 'troy-russel': [('troy-russell', 95.65217391304348)]
# 'josh-squires': [('joshua-squires', 92.3076923076923)]
# 'leonardo-domingo': [('leonardo-domingos', 96.96969696969697)]
# 'matheus-pereira': [('mateus-pereira', 96.55172413793103), ('matheus-ferreira', 90.32258064516128)]
# 'j.-albuquerque': [('joao-albuquerque', 86.66666666666667)]
# 'anthony-elbert': [('anthony-erbert', 92.85714285714286)]
# 'wallisson-oliveira': [('wallison-oliveira', 97.14285714285714)]
# 'gabriel-ferreira': [('gabriela-pereira', 87.5)]
# 'dina-sena': [('dyna-sena', 88.88888888888889)]
# 'mikaele-damaceno': [('mika-damaceno', 89.65517241379311)]
# 'ann-kneibb': [('ann-kneib', 94.73684210526316)]
# 'raiane-santos': [('rayanne-santos', 88.88888888888889)]
# 'dyna-sena': [('dina-sena', 88.88888888888889)]
# 'rita-lynn': [('rita-lynne', 94.73684210526316)]
# 'luciano-araujo': [('luciane-araujo', 92.85714285714286)]
# 'ariadne-de-oliveira': [('ariadne-oliveira', 91.42857142857143)]
# 'zofia-szawernowska': [('zofia-szawenowska', 97.14285714285714)]
# 'alicja-stypukowska': [('alicja-stypulkow', 88.23529411764706)]
# 'diego-pereira': [('diego-ferreira', 88.88888888888889)]
# 'briean-beaury': [('brian-beaury', 96.0)]
# 'jhoannan-vielma': [('johanan-vielma', 89.65517241379311)]
# 'christhian-cevallos': [('christian-cevallos', 97.2972972972973)]
# 'pedro-neto': [('pedro-bisneto', 86.95652173913044)]
# 'drylan-freedman': [('dylan-freedman', 96.55172413793103)]
# 'salomao-ribeiro': [('saulo-ribeiro', 85.71428571428572)]
# 'egan-inoe': [('egan-inoue', 94.73684210526316)]
# 'rodrigo-texieira': [('rodrigo-teixeira', 93.75)]
# 'eduardo-machado': [('eduardo-macedo', 89.65517241379311)]
# 'arthur-silva': [('artur-silva', 95.65217391304348)]
# 'lucas-luciani': [('lucas-luciano', 92.3076923076923)]
# 'luzia-fernandes': [('luan-fernandes', 89.65517241379311)]
# 'luciano-queiroz': [('luciando-queiroz', 96.7741935483871)]
# 'luis-finnochio': [('luiz-finocchio', 85.71428571428572)]
# 'lasse-rahkolin': [('lasse-rhakolin', 92.85714285714286)]
# 'victor-futurik': [('victor-futrik', 96.2962962962963)]
# 'adriano-camolesi': [('adriano-comolese', 87.5)]
# 'mat-jubera': [('matt-jubera', 95.23809523809523)]
# 'stephen-hal': [('stephen-hall', 95.65217391304348)]
# 'marcio-corleta': [('marcio-corletta', 96.55172413793103)]
# 'mike-wilson': [('mick-wilson', 90.9090909090909)]
# 'i.-praporshchikov': [('igor-praporschchikov', 86.48648648648648)]
# 'josete-filho': [('jose-filho', 90.9090909090909)]
# 'rafael-borges': [('rafhael-borges', 96.2962962962963)]
# 'felipe-mota': [('filipe-mota', 90.9090909090909), ('felipe-costa', 86.95652173913044)]
# 'thiago-alves': [('tiago-alves', 95.65217391304348)]
# 'edson-de-oliveira': [('edson-oliveira', 90.32258064516128)]
# 'max-danrley': [('max-danrlei', 90.9090909090909)]
# 'cameron-chaffee': [('cameron-chafee', 96.55172413793103)]
# 'alexandre-dantas': [('alexandre-santos', 87.5)]
# 'marcus-vinicius': [('markus-vinicius', 93.33333333333333)]
# 'dai-yoshida': [('dai-yoshioka', 86.95652173913044)]
# 'kouhei-ebashi': [('kouhel-ebashi', 92.3076923076923)]
# 'severi-nendnen': [('severi-nenonen', 92.85714285714286)]
# 'jonathan-van-buren': [('jonathan-buren', 87.5)]
# 'olando-silva': [('orlando-silva-jr', 85.71428571428572)]
# 'kayo-cesar': [('kaio-cesar', 90.0)]
# 'eduardoyezeguie': [('eduardo-yezeguie', 96.7741935483871)]
# 'isaac-dull': [('isaac-dul', 94.73684210526316)]
# 'patryk-wysoki': [('patryk-wysocki', 96.2962962962963)]
# 'robin-gracie': [('robson-gracie', 88.0)]
# 'chris-bowles': [('chris-bowe', 90.9090909090909)]
# 'm.-maciejwski': [('m.-maciejewski', 96.2962962962963)]
# 'marek-zbrog': [('marerk-zbrog', 95.65217391304348)]
# 'yuji-arai': [('yuji-harai', 94.73684210526316)]
# 'rubens-fonseca': [('ruben-fonseca', 96.2962962962963)]
# 'dino-bucalet': [('dinu-bucalet', 91.66666666666666)]
# 'omar-frederik': [('omar-frederick', 96.2962962962963)]
# 'wesley-caixet': [('wesley-caixeta', 96.2962962962963)]
# 'miles-ivankovic': [('mile-ivankovic', 96.55172413793103)]
# 'allef-silva': [('alef-silva', 95.23809523809523)]
# 'junyong-cho': [('jun-yong-cho', 95.65217391304348)]
# 'michael-demarco': [('michael-marco', 92.85714285714286)]
# 'josh-rios': [('jose-rios', 88.88888888888889)]
# 'vinicius-torres': [('vinicius-corrales', 87.5), ('vinicius-soares', 86.66666666666667), ('vinicius-reis', 85.71428571428572)]
# 'mike-jesus': [('myke-jesus', 90.0)]
# 'joao-marcio': [('joao-marco', 95.23809523809523), ('joao-marcelo', 86.95652173913044)]
# 'jonathan-tomasian': [('jonathan-thomas', 87.5)]
# 'dinu-bucalet': [('dino-bucalet', 91.66666666666666)]
# 'gairbek-ibragimov': [('gairbeg-ibragimov', 94.11764705882352)]
# 'eduardo-jesus': [('eduardo-de-jesus', 89.65517241379311)]
# 'riku-hapulathi': [('riku-hapulahti', 92.85714285714286)]
# 'tuomas-tamilehto': [('tuomas-tammilehto', 96.96969696969697)]
# 'jay-buttler': [('jay-butler', 95.23809523809523)]
# 'sergio-hernandes': [('sergio-hernandez', 93.75)]
# 'jay-butler': [('jay-buttler', 95.23809523809523)]
# 'rafael-reis': [('rafaela-reis', 95.65217391304348), ('rafael-freitas', 88.0)]
# 'kev-corkhill': [('kevin-corkhill', 92.3076923076923)]
# 'lee-renaut': [('lee-renault', 95.23809523809523)]
# 'sean-whyte': [('sean-white', 90.0)]
# 'lukas-andrade': [('lucas-andrade', 92.3076923076923)]
# 'bornis-tonev': [('boris-tonev', 95.65217391304348)]
# 'mario-goncalves': [('maria-goncalves', 93.33333333333333), ('mario-gonzales', 89.65517241379311), ('marcelo-goncalves', 87.5)]
# 'eduardo-goncalves': [('eduarda-goncalves', 94.11764705882352)]
# 'mika-lima': [('mica-lima', 88.88888888888889)]
# 'angel-lopez': [('anabel-lopez', 86.95652173913044)]
# 'rafa-mendes': [('rafael-mendes', 91.66666666666666)]
# 'guilherme-fernandes': [('guilherme-mendes', 85.71428571428572)]
# 'eduardo-campos': [('eduardo-ramos', 88.88888888888889)]
# 'steven-rosenberg': [('steve-rosenburg', 90.32258064516128)]
# 'marcel-goncalves': [('marcelo-goncalves', 96.96969696969697)]
# 'spenser-gilliam': [('spenser-guilliam', 96.7741935483871), ('spencer-gilliam', 93.33333333333333), ('spencer-guilliam', 90.32258064516128)]
# 'michael-maia': [('michel-maia', 95.65217391304348)]
# 'nicolas-renier': [('nicholas-renier', 96.55172413793103), ('nicolas-reiner', 92.85714285714286), ('nicholas-reiner', 89.65517241379311), ('nicolas-penzer', 85.71428571428572)]
# 'victor-paschoal': [('vitor-paschoal', 96.55172413793103)]
# 'gabriel-d.-oliveira': [('gabriel-de-oliveira', 94.73684210526316)]
# 'marcos-paes': [('marcos-lopes', 86.95652173913044), ('marcos-alves', 86.95652173913044)]
# 'justin-labac': [('justin-fabac', 91.66666666666666)]
# 'vitor-barreto': [('victor-barreto', 96.2962962962963)]
# 'kevin-berberich': [('kevin-berbrich', 96.55172413793103)]
# 'marcus-geddes': [('marcus-guedes', 92.3076923076923)]
# 'lukas-pollard': [('lucas-pollard', 92.3076923076923)]
# 't.-freeman': [('ty-freeman', 90.0)]
# 'marcus-oliveira': [('marcos-oliveira', 93.33333333333333)]
# 'sean-goolsby': [('sean-golbsy', 86.95652173913044)]
# 'amr-ghoneim': [('amir-ghoneim', 95.65217391304348)]
# 'rani-yahya': [('rany-yahya', 90.0)]
# 'mike-davilla': [('mike-davila', 95.65217391304348)]
# 'gustavo-santos': [('gustavo-santiago', 86.66666666666667)]
# 'alexandre-souza': [('alexandre-sousa', 93.33333333333333), ('alexandre-soca', 89.65517241379311)]
# 'tetsu-suzuki': [('tetsu-suzuko', 91.66666666666666)]
# 'takezawa-keisuke': [('takizawa-keusuke', 87.5)]
# 'takizawa-keusuke': [('takezawa-keisuke', 87.5)]
# 'kouhei-yasumi': [('kohei-yasumi', 96.0)]
# 'jakson-bernardo': [('jackson-bernardo', 96.7741935483871)]
# 'alex-ecklin': [('alex-eklin', 95.23809523809523)]
# 'ronald-henderson': [('ron-henderson', 89.65517241379311)]
# 'paulo-cesar': [('paulo-cezar', 90.9090909090909)]
# 'gabriel-sousa': [('gabriel-souza', 92.3076923076923), ('gabriel-sa', 86.95652173913044)]
# 'troy-russell': [('troy-russel', 95.65217391304348)]
# 'daniel-manasoiu': [('daniel-manasoiou', 96.7741935483871), ('dan-manasoiu', 88.88888888888889)]
# 'jonathan-thomas': [('jonathan-tomasian', 87.5)]
# 'charles-pearson': [('charles-parsons', 93.33333333333333)]
# 'leomar-souza': [('leo-souza', 85.71428571428572)]
# 'vinicius-barros': [('vinicius-barbosa', 90.32258064516128)]
# 'kaua-barbosa': [('kauan-barboza', 88.0)]
# 'saul-viayra': [('saul-viarya', 90.9090909090909)]
# 'felipe-vieira': [('felipe-teixeira', 85.71428571428572)]
# 'hayden-bucner': [('hayden-buckner', 96.2962962962963)]
# 'luan-gomes': [('luan-gomez', 90.0)]
# 'stephen-martinez': [('stephan-martinez', 93.75)]
# 'berbardo-delibero': [('bernardo-delibero', 94.11764705882352)]
# 'bryce-layme': [('bryce-lamb', 85.71428571428572)]
# 'leonardo-vilela': [('leonardo-vieira', 86.66666666666667)]
# 'thiago-sousa': [('thiago-souza', 91.66666666666666), ('thiago-rosa', 86.95652173913044)]
# 'diego-silva': [('diogo-silva', 90.9090909090909)]
# 'christopher-powell': [('christopher-bowe', 88.23529411764706)]
# 'marcos-souza': [('marco-souza', 95.65217391304348)]
# 'lucas-sashs': [('lucas-sachs', 90.9090909090909)]
# 'roger-ambrosio': [('roger-ambrosi', 96.2962962962963)]
# 'gustavo-saraiva': [('gustavo-silva', 85.71428571428572)]
# ...
# 'jose-rios': [('josh-rios', 88.88888888888889)]
# 'anabel-lopez': [('angel-lopez', 86.95652173913044)]
# 'lautaro-sanguimene': [('lautaro-sanguime', 94.11764705882352)]
# 'diego-pato': [('diego-sato', 90.0)]
# 'felipe-teixeira': [('felipe-vieira', 85.71428571428572)]
# 'jorge-oliveira': [('jose-oliveira', 88.88888888888889)]
# 'adam-maslach': [('adam-malasch', 91.66666666666666)]
# 'lukasz-lepianka': [('lukasz-leplanka', 93.33333333333333)]
# 'tony-ferraz': [('toni-ferraz', 90.9090909090909)]
# 'francisco-neto': [('francisco-bonetto', 90.32258064516128), ('francisco-cuneo', 89.65517241379311), ('francisco-leon', 85.71428571428572)]
# 'krysztof-suchora': [('krzysztof-suchor', 93.75)]
# 'edivaldo-ferreira': [('edvaldo-ferreira', 96.96969696969697)]
# 'andre-fernando': [('andre-fernandes', 89.65517241379311), ('andres-fernandez', 86.66666666666667)]
# 't,-hopstock': [('t.-hopstock', 90.9090909090909)]
# 'joachim-sveinson': [('joachim-svenson', 96.7741935483871)]
# 'kristjan-mae': [('kristian-mae', 91.66666666666666)]
# 'adrian-kozicz': [('adrian-kozisz', 92.3076923076923)]
# 'm.-abdulkadirov': [('m.-abdulkaridov', 86.66666666666667)]
# 'tarik-hopstock': [('tarik-hopstok', 96.2962962962963)]
# 'diego-heirich': [('diego-heinrich', 96.2962962962963)]
# 'manoel-porto': [('manuel-porto', 91.66666666666666)]
# 'aj-agazarm': [('a.-agazarm', 90.0)]
# 'e.-cummings': [('ed-cummings', 90.9090909090909)]
# 'nicholas-reiner': [('nicolas-reiner', 96.55172413793103), ('nicholas-renier', 93.33333333333333), ('nicolas-renier', 89.65517241379311), ('nicholas-penzer', 86.66666666666667)]
# 'uros-culic': [('uros-cilic', 90.0)]
# 'marcelo-figueiredo': [('marcia-figueiredo', 85.71428571428572)]
# 'lunna-silva': [('luanna-silva', 95.65217391304348), ('luan-silva', 85.71428571428572)]
# 'roberto-roberto': [('roberto-ribeiro', 86.66666666666667)]
# 'matt-jubera': [('mat-jubera', 95.23809523809523)]
# 'dimitri-vostrivov': [('dimitri-vostrikov', 94.11764705882352)]
# 'cameron-florczak': [('cameron-floczak', 96.7741935483871)]
# 'anderson-ferreira': [('anderson-pereira', 90.9090909090909)]
# 'marcos-campos': [('marcos-campo', 96.0)]
# 'jonathan-lopez': [('jonathan-lopes', 92.85714285714286)]
# 'ricardo-franco': [('ricardo-soranco', 89.65517241379311)]
# 'lucas-castro': [('lucas-castelo', 88.0), ('lucas-canto', 86.95652173913044)]
# 'walkler-barroso': [('walker-barroso', 96.55172413793103)]
# 's.-villas': [('s.-vilas', 94.11764705882352)]
# 's.-vilas': [('s.-villas', 94.11764705882352)]
# 'christian-simmerling': [('chris-simmerling', 88.88888888888889)]
# 'wallace-costa': [('walllace-costa', 96.2962962962963)]
# 'carlos-geovani': [('carlos-geovanni', 96.55172413793103)]
# 'lucas-campelo': [('lucas-campos', 88.0)]
# 'breno-novais': [('brenno-novais', 96.0), ('breno-novaes', 91.66666666666666), ('brenno-novaes', 88.0)]
# 'luis-lopes': [('lucas-lopes', 85.71428571428572)]
# 'nolan-stuart': [('nolas-stuart', 91.66666666666666)]
# 'chris-weidman': [('chris-wideman', 92.3076923076923)]
# 'ronny-marques': [('ronny-markes', 88.0)]
# 'ronny-markes': [('ronny-marques', 88.0)]
# 'luiz-athayde': [('luis-athayde', 91.66666666666666)]
# 'wilhiam-mateus': [('wilhiam-matheus', 96.55172413793103)]
# 'pedro-anjos': [('pedro-santos', 86.95652173913044)]
# 'vinicius-ceconi': [('vinicius-cecconi', 96.7741935483871)]
# 'victor-batista': [('victor-bastista', 96.55172413793103)]
# 'leo-nascimento': [('leandro-nascimento', 87.5)]
# 'elfrankli-souza': [('elfraklin-souza', 93.33333333333333)]
# 'fabio-fernandes': [('flavio-fernandes', 90.32258064516128)]
# 'fletcher-linton-jr': [('fletcher-linton', 90.9090909090909)]
# 'eliezer-skaf': [('ekiezer-skaf', 91.66666666666666)]
# 'rayan-melo': [('rayla-melo', 90.0)]
# 'thamara-ferreira': [('thaynara-ferreira', 90.9090909090909)]
# 'suelen-desterro': [('suellen-desterro', 96.7741935483871)]
# 'stephanie-delphine': [('stephanie-delphin', 97.14285714285714)]
# 'ludmila-fiori': [('ludimira-fiori', 88.88888888888889)]
# 'otavio-nalati': [('otavio-nalatti', 96.2962962962963)]
# 'henrique-rios': [('henrique-rossi', 88.88888888888889)]
# 'adilson-lima': [('adson-lima', 90.9090909090909)]
# 'brendo-babilonia': [('breno-babilonia', 96.7741935483871)]
# 'joao-vitor': [('joao-victor', 95.23809523809523)]
# 'royler-gracie': [('roger-gracie', 88.0)]
# 'jhonatha-angelim': [('jhonathan-angelim', 96.96969696969697)]
# 'davi-souza': [('david-souza', 95.23809523809523)]
# 'tim-hinrichs': [('tim-hinrich', 95.65217391304348)]
# 'leandro-kussano': [('leandro-kusano', 96.55172413793103)]
# 'luciane-araujo': [('luciano-araujo', 92.85714285714286)]
# 'adam-adshead': [('adam-dashed', 86.95652173913044)]
# 'harry-grech': [('harry-gretch', 95.65217391304348)]
# 't.-cellamare': [('tom-cellamare', 88.0)]
# 'nimrod-ryeder': [('nimrod-ryder', 96.0)]
# 'chris-gores': [('chris-graves', 86.95652173913044)]
# 'jaakko-hulkkonen': [('jaakko-hukkonen', 96.7741935483871)]
# 'victoria-martins': [('victor-martins', 93.33333333333333)]
# 'khalid-alshamsi': [('khaled-shamsi', 85.71428571428572)]
# 'thaynara-dias': [('thayara-dias', 96.0)]
# 'elizabeth-mitrovic': [('elizabeth-mitrov', 94.11764705882352)]
# 'kauany-queiroz': [('kauani-queiroz', 92.85714285714286)]
# 'gabriel-santos': [('gabriela-matos', 85.71428571428572)]
# 'aquila-de-paula': [('aquila-paula', 88.88888888888889)]
# 'michel-maia': [('michael-maia', 95.65217391304348)]
# 'michael-tohme': [('michael-thome', 92.3076923076923)]
# 'kouhel-ebashi': [('kouhei-ebashi', 92.3076923076923)]
# 'william-mello': [('william-melo', 96.0)]
# 'jocsan-ferreira': [('jacson-ferreira', 86.66666666666667), ('joao-ferreira', 85.71428571428572)]
# 'matheus-cardoso': [('matheus-carlos', 89.65517241379311)]
# 'felipe-ribas': [('felipe-reis', 86.95652173913044)]
# 'rodrigo-francioni': [('rodrigo-francione', 94.11764705882352)]
# 'josh-lorton': [('joshua-lorton', 91.66666666666666)]
# 'joshua-murdock': [('joshua-murdok', 96.2962962962963), ('josh-murdock', 92.3076923076923), ('josh-murdoc', 88.0)]
# 'breno-azevedo': [('bruno-azevedo', 92.3076923076923)]
# 'omar-alsuwaidi': [('omar-alswaidi', 96.2962962962963)]
# 'kaique-affonso': [('kaike-affonso', 88.88888888888889)]
# 'raul-marcelo': [('raul-marcello', 96.0)]
# 'leandro-souza': [('leandro-sousa', 92.3076923076923)]
# 't.-alnuami': [('t.-alnuaimi', 95.23809523809523)]
# 'igor-ferreira': [('igor-pereira', 88.0)]
# 't.-alnuaimi': [('t.-alnuami', 95.23809523809523)]
# 'rafael-gomes': [('rafael-gomez', 91.66666666666666)]
# 'said-almazrouei': [('said-almazrouie', 93.33333333333333)]
# 'xavi-bas': [('xavier-bas', 88.88888888888889)]
# 'said-almazrouie': [('said-almazrouei', 93.33333333333333)]
# 'bruno-azevedo': [('breno-azevedo', 92.3076923076923)]
# 's.-magomedov': [('s.-magomed', 90.9090909090909)]
# 'chris-dellevag': [('christian-dellevag', 87.5)]
# 'j.-pietlainen': [('j.-pietkainen', 92.3076923076923)]
# 'thomas-julien': [('thomas-jules', 88.0)]
# 'carlos-elias': [('carlos-reis', 86.95652173913044)]
# 'tarsis-humphreys': [('tarsys-humphreys', 93.75)]
# 'julian-stonjek': [('julian-stonkek', 92.85714285714286)]
# 'elfrankli-araruna': [('eltrankin-araruna', 88.23529411764706)]
# 'fabio-oliveira': [('flavio-oliveira', 89.65517241379311)]
# 'bruno-de-franca': [('bruno-franca', 88.88888888888889)]
# 'josh-hinger': [('joshua-hinger', 91.66666666666666)]
# 'walton-presto': [('waltan-presto', 92.3076923076923)]
# 'k.-suchorabski': [('k.-schorabski', 96.2962962962963)]
# 'mateo-tenzera': [('mateo-tenzara', 92.3076923076923)]
# 'mile-ivankovic': [('miles-ivankovic', 96.55172413793103)]
# 'tanno-odilio': [('tano-odilio', 95.65217391304348)]
# 'piter-frank': [('peter-frank', 90.9090909090909)]
# 'nicholas-greene': [('nichollas-greene', 96.7741935483871), ('nichollas-grene', 93.33333333333333), ('nicholas-renier', 86.66666666666667), ('nicholas-reiner', 86.66666666666667)]
# 'phillip-lietz': [('phil-lietz', 86.95652173913044)]
# 'sid-tavolaro': [('sidney-tavolaro', 88.88888888888889)]
# 'daniel-tsatsos': [('daniel-statsos', 92.85714285714286)]
# 'raphael-ribeiro': [('rafael-ribeiro', 89.65517241379311)]
# 'antonio-jr.': [('antonio-jr', 95.23809523809523)]
# 'emanuel-felix': [('emanoel-felix', 92.3076923076923)]
# 'a.-cacareco': [('alex.-cacareco', 88.0)]
# 'chico-lo': [('chico-melo', 88.88888888888889)]
# 'dennis-gomes': [('denis-gomes', 95.65217391304348)]
# 'andre-da-silva': [('andre-silva', 88.0)]
# 'gildassio-santana': [('gildasio-santana', 96.96969696969697)]
# 'javier-cardenas': [('javier-cardenez', 86.66666666666667)]
# 'matheus-luna': [('matheus-cunha', 88.0)]
# 'jose-calvo': [('josh-calvo', 90.0), ('jose-carlos', 85.71428571428572)]
# 'marcos-alves': [('marcos-alves-jr', 88.88888888888889), ('marcos-paes', 86.95652173913044)]
# 'jackson-sousa': [('jackson-souza', 92.3076923076923)]
# 'hugo-marques': [('higor-marques', 88.0)]
# 'matheus-monteiro': [('matheus-soeiro', 86.66666666666667)]
# 'j.-echevarria': [('j.-echeverria', 92.3076923076923)]
# 'steve-rosenburg': [('steven-rosenberg', 90.32258064516128)]
# 'fletcher-linton': [('fletcher-linton-jr', 90.9090909090909)]
# 'sergio-hernandez': [('sergio-hernandes', 93.75)]
# 'ricardo-a.': [('ricardo-p.', 90.0), ('ricardo-rea', 85.71428571428572)]
# 'joshua-rodriguez': [('josh-rodriguez', 93.33333333333333)]
# 'evan-ramsden': [('evan-ramdsen', 91.66666666666666)]
# 'geoff-villareal': [('geoff-villarreal', 96.7741935483871), ('geoffrey-villareal', 90.9090909090909), ('geoffrey-villarreal', 88.23529411764706)]
# 'kevin-corkhill': [('kev-corkhill', 92.3076923076923)]
# 'joao-gabriel': [('j-gabriel', 85.71428571428572)]
# 'thiago-braga': [('thiago-aragao', 88.0)]
# 'otavio-serafim': [('otavio-seravim', 92.85714285714286)]
# 'leo-chocolate': [('l.-chocolate', 88.0)]
# 'roger-ambrosi': [('roger-ambrosio', 96.2962962962963)]
# 'cleyton-flores': [('cleiton-flores', 92.85714285714286)]
# 'j.-lopez': [('j.-lopes', 87.5)]
# 'john-rickel': [('john-rickell', 95.65217391304348)]
# 'ruben-fonseca': [('rubens-fonseca', 96.2962962962963)]
# 'andre-vaughan': [('andrea-vaughan', 96.2962962962963)]
# 'marlon-ferreira': [('marcelo-ferreira', 90.32258064516128)]
# 'vinicius-silva': [('vinicius-saraiva', 86.66666666666667)]
# 'luan-azevedo': [('luciano-azevedo', 88.88888888888889)]
# 'raphael-cadena': [('raphael-cadema', 92.85714285714286)]
# 'guilherme-silva': [('guilherme-milan', 86.66666666666667)]
# 'pedro-valenca': [('pedro-valencia', 96.2962962962963)]
# 'rafael-castro': [('raphael-castro', 88.88888888888889)]
# 'douglas-barcellos': [('douglas-barcelos', 96.96969696969697)]
# 'marcio-andre': [('mario-andre', 95.65217391304348)]
# 'joe-isataka': [('joe-histaka', 90.9090909090909)]
# 'grafton-skaggs': [('grafton-skraggs', 96.55172413793103)]
# 'john-hansen': [('jon-hansen', 95.23809523809523)]
# 'yuto-hirao': [('yuuto-hirao', 95.23809523809523)]
# 'kazuyuki-miyata': [('kazuyuki-miyazi', 86.66666666666667)]
# 'vitor-riciotti': [('vitor-ricotti', 96.2962962962963)]
# 'magomed-dzharbaev': [('magomed-djarbaev', 90.9090909090909)]
# 'narciso-vilaca': [('narciso-vila', 92.3076923076923)]
# 'luiz-andre': [('luiz-andrade', 90.9090909090909)]
# 'magno-mota': [('magno-motta', 95.23809523809523)]
# 'kevlyn-pontes': [('kelvyn-pontes', 92.3076923076923)]
# 'felippe-mello': [('felippe-melo', 96.0), ('fellipe-mello', 92.3076923076923), ('fellipe-melo', 88.0)]
# 'fellipe-melo': [('fellipe-mello', 96.0), ('felippe-melo', 91.66666666666666), ('felippe-mello', 88.0)]
# 'igor-terreco': [('igor-terraceo', 88.0)]
# 'masaaki-todokoro': [('massaki-todokoro', 93.75)]
# 'josh-jerome': [('joshua-jerome', 91.66666666666666)]
# 'lucasz-michalec': [('luckasz-michalec', 96.7741935483871), ('lukasz-michalec', 93.33333333333333)]
# 'ricardo-morais': [('ricardo-moraes', 92.85714285714286)]
# 'diego-fernandes': [('diogo-fernandes', 93.33333333333333)]
# 'jose-kuruoka': [('jose-kurowoka', 88.0)]
# 'gabriel-rosenberg': [('gabriel-roseberg', 96.96969696969697)]
# 'samat-aitpanbet': [('samat-aitapanbet', 96.7741935483871)]
# 'lucas-andrade': [('lukas-andrade', 92.3076923076923)]
# 'mohammod-alim': [('mohammed-ali', 88.0)]
# 'victor-barreto': [('vitor-barreto', 96.2962962962963)]
# 'keller-sodhi': [('kheller-shodi', 88.0)]
# 'william-shannon': [('william-shanon', 96.55172413793103)]
# 'vinicius-gimenes': [('vinicius-gimenis', 93.75)]
# 'a.-angerman': [('ak-angerman', 90.9090909090909)]
# 'g.-karakhanian': [('g.-karakhanyon', 85.71428571428572)]
# 'uknown': [('unknown', 92.3076923076923)]
# 'flavio-oliveira': [('fabio-oliveira', 89.65517241379311)]
# 'israel-motta': [('israel-mota', 95.65217391304348)]
# 'matheus-fonseca': [('mateus-fonseca', 96.55172413793103)]
# 'leon-brito': [('leo-brito', 94.73684210526316)]
# 'murat-besnet': [('murat-besnek', 91.66666666666666)]
# 'pedro-souza': [('pedro-sousa', 90.9090909090909)]
# 'gabriel-alexander': [('gabriel-alejandro', 88.23529411764706)]
# 'roger-narvaez': [('rojerio-narvaez', 85.71428571428572)]
# 'nonso-ebed': [('nonso-ebede', 95.23809523809523)]
# 'bobby-winther': [('bobby-whither', 92.3076923076923)]
# 'nicolas-reiner': [('nicholas-reiner', 96.55172413793103), ('nicolas-renier', 92.85714285714286), ('nicholas-renier', 89.65517241379311), ('nicolas-penzer', 85.71428571428572)]
# 'robert-sullivan': [('rob-sullivan', 88.88888888888889)]
# 'thomas-johanssen': [('thomas-johanessen', 96.96969696969697), ('thomas-johansen', 96.7741935483871), ('thomas-johannessen', 94.11764705882352)]
# 'ross-daniel': [('ross-daniels', 95.65217391304348)]
# 'jhonathan-marques': [('jonathan-ares', 86.66666666666667)]
# 'jose-llanas': [('jose-lianas', 90.9090909090909)]
# 'marcos-gomes': [('marcos-tome', 86.95652173913044)]
# 'daniel-tavarez': [('daniel-tavares', 92.85714285714286), ('danielle-alvarez', 86.66666666666667)]
# 'daniel-rivera': [('daniel-rivas', 88.0)]
# 'rodolpho-bomfim': [('rodolpho-bonfim', 93.33333333333333)]
# 'christopher-ong': [('christopher-engle', 87.5)]
# 'tom-kozlowski': [('thomas-kozlowski', 89.65517241379311)]
# 'caio-de-sousa': [('caio-sousa', 86.95652173913044)]
# 'elfraklin-souza': [('elfrankli-souza', 93.33333333333333)]
# 'philipe-arimatea': [('phillipe-arimatea', 96.96969696969697)]
# 'jonatas-novaes': [('jonnatas-novaes', 96.55172413793103)]
# 'luis-shaerer': [('luis-schaerer', 96.0)]
# 'guiovanne-guedes': [('giovanne-guedes', 96.7741935483871)]
# 'luis-schaerer': [('luis-shaerer', 96.0)]
# 'rafael-alves': [('rafael-goncalves', 85.71428571428572)]
# 'jose-kurowoka': [('jose-kuruoka', 88.0)]
# 'gabriel-alejandro': [('gabriel-alexander', 88.23529411764706)]
# 'oliver-lovell': [('oliver-novell', 92.3076923076923)]
# 'alex-goulart': [('alex-de-goulart', 88.88888888888889)]
# 'casey-hellenberg': [('cassey-hellenberg', 96.96969696969697)]
# 'marcus-guedes': [('marcus-geddes', 92.3076923076923)]
# 'felipe-simoes': [('felipe-simao', 88.0)]
# 'simoneli-emiliano': [('simonelli-emiliano', 97.14285714285714)]
# 'antti-simola': [('antii-simola', 91.66666666666666)]
# 'kristopher-santos': [('khristopher-santos', 97.14285714285714)]
# 'bruno-cezar': [('bruno-cesar', 90.9090909090909)]
# 'lukasz-leplanka': [('lukasz-lepianka', 93.33333333333333)]
# 'gabriel-martins': [('gabriel-marinho', 86.66666666666667)]
# 'cesar-miyahira': [('cesar-miahira', 96.2962962962963)]
# 'young-kim': [('youngsu-kim', 90.0)]
# 'mohamed-qbasi': [('mohamed-alqubaisi', 86.66666666666667)]
# 'joao-bezerra': [('j-bezerra', 85.71428571428572)]
# 'jorge-elias': [('jorge-luis', 85.71428571428572)]
# 'diego-ferreira': [('diego-pereira', 88.88888888888889)]
# 'igor-pereira': [('igor-ferreira', 88.0)]
# 'thales-oliveira': [('thales-vieira', 85.71428571428572)]
# 'andrea-vaughan': [('andre-vaughan', 96.2962962962963)]
# 'adam-colaralie': [('adam-collarlie', 92.85714285714286)]
# 'anderson-macedo': [('anderson-melo', 85.71428571428572)]
# 'jose-dias': [('jose-diaz', 88.88888888888889)]
# 'fernando-pena': [('fernando-pessoa', 85.71428571428572)]
# 'anidete-ferreira': [('andre-ferreira', 86.66666666666667)]
# 'akira-osokawa': [('akira-hosokawa', 96.2962962962963)]
# 'douglas-barcelos': [('douglas-barcellos', 96.96969696969697)]
# 'jose-dos-santos': [('jorge-dos-santos', 90.32258064516128)]
# 'giulliano-alves': [('giuliano-alves', 96.55172413793103)]
# 'chris-noonan': [('chris-noon', 90.9090909090909)]
# 'chris-noon': [('chris-noonan', 90.9090909090909)]
# 'j.-friedrich': [('j.-fredrich', 95.65217391304348)]
# 'joseph-cashin': [('joe-cashin', 86.95652173913044)]
# 'alex-taveira': [('alex-vieira', 86.95652173913044)]
# 'gustavo-borges': [('gustavo-soares', 85.71428571428572)]

# %%
# 2) Monte o mapping variant → canonical
mapping = {}
for canonical, variants in matches.items():
    for variant, score in variants:
        mapping[variant] = canonical


# 2) Aplique as substituições na coluna opponent
df_fights['opponent'] = df_fights['opponent'].replace(mapping)

# %%
df_fights = df_fights.sort_values('fight_id', ascending=True)
df_fights
# Out:
#                    fighter  fight_id          opponent result  competition  \
# 18768  master-helio-gracie         2  antonio-portugal      W      Unknown
# 18769  master-helio-gracie         3    takashi-namiki      D      Unknown
# 18770  master-helio-gracie         4        fred-ebert      D      Unknown
# 18771  master-helio-gracie         5    wladek-zbyszko      D      Unknown
# 18772  master-helio-gracie         6            miyake      W      Unknown
# ...                    ...       ...               ...    ...          ...
# 51360       manuel-ribamar     58855    seonghyeon-joo      W  Oklahoma CO
# 12351        enderson-dias     58856   gabriel-cardoso      W  Oklahoma CO
# 47658        vitoria-assis     58857       mona-bailey      W  Oklahoma CO
# 11898      emily-fernandez     58858   gabriele-schuck      W  Oklahoma CO
# 11936      emily-fernandez     58858   gabriele-schuck      W  Oklahoma CO
#
#       weight  year
# 18768    ABS  1932
# 18769    ABS  1932
# 18770    ABS  1932
# 18771    ABS  1934
# 18772    ABS  1934
# ...      ...   ...
# 51360    ABS  2025
# 12351    ABS  2025
# 47658   58KG  2025
# 11898   69KG  2025
# 11936   69KG  2025
#
# [54641 rows x 7 columns]

# %%
# Cria uma nova coluna com valores únicos e incrementais
df_fights['id_fight'] = range(1, len(df_fights) + 1)
df_fights = df_fights.drop(columns=['fight_id'])
df_fights
# Out:
#                    fighter          opponent result  competition weight  year  \
# 18768  master-helio-gracie  antonio-portugal      W      Unknown    ABS  1932
# 18769  master-helio-gracie    takashi-namiki      D      Unknown    ABS  1932
# 18770  master-helio-gracie        fred-ebert      D      Unknown    ABS  1932
# 18771  master-helio-gracie    wladek-zbyszko      D      Unknown    ABS  1934
# 18772  master-helio-gracie            miyake      W      Unknown    ABS  1934
# ...                    ...               ...    ...          ...    ...   ...
# 51360       manuel-ribamar    seonghyeon-joo      W  Oklahoma CO    ABS  2025
# 12351        enderson-dias   gabriel-cardoso      W  Oklahoma CO    ABS  2025
# 47658        vitoria-assis       mona-bailey      W  Oklahoma CO   58KG  2025
# 11898      emily-fernandez   gabriele-schuck      W  Oklahoma CO   69KG  2025
# 11936      emily-fernandez   gabriele-schuck      W  Oklahoma CO   69KG  2025
#
#        id_fight
# 18768         1
# 18769         2
# 18770         3
# 18771         4
# 18772         5
# ...         ...
# 51360     54637
# 12351     54638
# 47658     54639
# 11898     54640
# 11936     54641
#
# [54641 rows x 7 columns]

# %%
# 2) Calcule value_counts e nomeie a Series
weight_counts = df_fights['weight'].value_counts()
weight_counts.name = 'count'
weight_counts.index.name = 'weight_category'

# 3) Converta em DataFrame
weight_counts_df = weight_counts.reset_index()


from rapidfuzz import process, fuzz

cats = df_fights['weight'].dropna().unique().tolist()
threshold = 85

matches = {
    cat: [
        (match, score)
        for match, score, _ in process.extract(cat, cats, scorer=fuzz.token_sort_ratio, limit=5)
        if score >= threshold and match != cat
    ]
    for cat in cats
}

# Exiba só as categorias que têm correspondentes semelhantes
similar = {k: v for k, v in matches.items() if v}
print("Possíveis variações ortográficas em weight:")
for cat, vars in similar.items():
    print(f"{cat!r}: {vars}")
# Out:
# Possíveis variações ortográficas em weight:
# '82KG': [('O82KG', 88.88888888888889)]
# '76KG': [('O76KG', 88.88888888888889)]
# '70KG': [('O70KG', 88.88888888888889)]
# '100KG': [('O100KG', 90.9090909090909), ('100KG+', 90.9090909090909)]
# '88KG': [('O88KG', 88.88888888888889), ('88K', 85.71428571428572), ('88G', 85.71428571428572)]
# 'O88KG': [('88KG', 88.88888888888889)]
# '77KG': [('U77KG', 88.88888888888889), ('O77KG', 88.88888888888889)]
# '99KG': [('O99KG', 88.88888888888889)]
# 'O99KG': [('99KG', 88.88888888888889)]
# '94KG': [('O94KG', 88.88888888888889)]
# 'O100KG': [('100KG', 90.9090909090909)]
# '74KG': [('O74KG', 88.88888888888889)]
# '75KG': [('O75KG', 88.88888888888889)]
# 'O91KG': [('91KG', 88.88888888888889)]
# '98KG': [('O98KG', 88.88888888888889)]
# '108KG': [('O108KG', 90.9090909090909)]
# 'O108KG': [('108KG', 90.9090909090909)]
# 'O75KG': [('75KG', 88.88888888888889)]
# '72KG': [('O72KG', 88.88888888888889)]
# '81KG': [('O81KG', 88.88888888888889)]
# '91KG': [('O91KG', 88.88888888888889)]
# '63KG': [('O63KG', 88.88888888888889)]
# '79KG': [('O79KG', 88.88888888888889)]
# 'O79KG': [('79KG', 88.88888888888889)]
# '65KG': [('O65KG', 88.88888888888889)]
# '83KG': [('O83KG', 88.88888888888889)]
# '92KG': [('O92KG', 88.88888888888889)]
# 'O92KG': [('92KG', 88.88888888888889)]
# 'O63KG': [('63KG', 88.88888888888889)]
# 'O72KG': [('72KG', 88.88888888888889)]
# 'O60KG': [('60KG', 88.88888888888889)]
# '85KG': [('O85KG', 88.88888888888889)]
# 'O94KG': [('94KG', 88.88888888888889)]
# '100KG+': [('100KG', 90.9090909090909)]
# 'O85KG': [('85KG', 88.88888888888889)]
# '95KG': [('O95KG', 88.88888888888889)]
# 'O95KG': [('95KG', 88.88888888888889)]
# 'O74KG': [('74KG', 88.88888888888889)]
# '97KG': [('O97KG', 88.88888888888889)]
# '62KG': [('62 KG', 88.88888888888889)]
# '60KG': [('O60KG', 88.88888888888889)]
# 'U77KG': [('77KG', 88.88888888888889)]
# 'O77KG': [('77KG', 88.88888888888889)]
# 'O76KG': [('76KG', 88.88888888888889)]
# '110KG': [('U110KG', 90.9090909090909)]
# 'O97KG': [('97KG', 88.88888888888889)]
# '93KG': [('O93KG', 88.88888888888889)]
# '80KG': [('O80KG', 88.88888888888889)]
# 'U110KG': [('110KG', 90.9090909090909)]
# '62 KG': [('62KG', 88.88888888888889)]
# 'O82KG': [('82KG', 88.88888888888889)]
# 'O98KG': [('98KG', 88.88888888888889)]
# 'O93KG': [('93KG', 88.88888888888889)]
# 'O81KG': [('81KG', 88.88888888888889)]
# '88K': [('88KG', 85.71428571428572)]
# 'O83KG': [('83KG', 88.88888888888889)]
# 'O80KG': [('80KG', 88.88888888888889)]
# 'O70KG': [('70KG', 88.88888888888889)]
# 'O65KG': [('65KG', 88.88888888888889)]
# '88G': [('88KG', 85.71428571428572)]

# %%
import re

def normalize_weight(w):
    w = str(w).upper().strip()
    # tenta extrair dígitos (p.ex. 62, 100, 88)
    m = re.search(r'(\d+)', w)
    if m:
        return f"{m.group(1)}KG"
    # caso não seja um peso numérico, mantém (ex.: ABS, UNKNOWN)
    return w

# aplica ao seu df_unico
df_fights['weight'] = df_fights['weight'].apply(normalize_weight)

# converte para categoria (opcional, mas economiza memória)
df_fights['weight'] = df_fights['weight'].astype('category')

# confira as novas categorias e frequências
print(df_fights['weight'].value_counts())
# Out:
# weight
# ABS      11543
# 70KG      3788
# 76KG      3733
# 82KG      3649
# 88KG      3515
#          ...
# 54KG         2
# 125KG        1
# //KG         1
# 4KG          1
# SF           1
# Name: count, Length: 80, dtype: int64

# %%
standard_kg = [48, 52, 57, 58, 63, 64, 69, 70, 76, 82, 88, 94, 98, 100]

def standardize_weight(w):
    w_str = str(w).upper().strip()
    # Preserve ABS e UNKNOWN como estão
    if w_str in ("ABS", "UNKNOWN"):
        return w_str
    # Tenta extrair o número
    m = re.search(r"(\d+)", w_str)
    if not m:
        # Se não for numérico, vira UNKNOWN
        return "UNKNOWN"
    num = int(m.group(1))
    # Qualquer peso >= 100 vira 100KG (ultra-pesado sem limite)
    if num >= 100:
        return "100KG"
    # Encontre o padrão mais próximo para pesos < 100
    diffs = [(abs(num - std), std) for std in standard_kg if std < 100]
    _, best_std = min(diffs, key=lambda x: x[0])
    return f"{best_std}KG"

# Aplique a padronização
df_fights["weight"] = df_fights["weight"].apply(standardize_weight).astype("category")

# Veja as contagens finais
print(df_fights["weight"].value_counts())
# Out:
# weight
# ABS        11543
# 76KG        8483
# 82KG        6750
# 70KG        4701
# 88KG        4205
# 94KG        4136
# 100KG       3955
# 64KG        2820
# 69KG        2038
# 98KG        1445
# 63KG        1351
# 57KG        1135
# UNKNOWN      746
# 58KG         614
# 48KG         468
# 52KG         251
# Name: count, dtype: int64

# %%
df_fights = df_fights.sort_values('id_fight', ascending=True)
df_fights

df_fights.to_csv('df_fights_final.csv', index=False)
