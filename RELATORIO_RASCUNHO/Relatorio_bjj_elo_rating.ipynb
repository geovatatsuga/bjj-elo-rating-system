# %% [markdown]
# <a href="https://colab.research.google.com/github/geovatatsuga/bjj-elo-rating-system/blob/main/RELATORIO_RASCUNHO/Relatorio_bjj_elo_rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Documentação do Projeto - **BJJ Elo Rating** : Implementando ranquemanto por Elo em atletas de jiu-jitsu.

# %% [markdown]
# 🥋**Análise da Performance Competitiva no Jiu-Jitsu por ELO Rating**
#
# Como fã de Jiu-Jitsu, sempre tive a curiosidade de entender, de maneira quantitativa, quem foram os grandes campeões da história do esporte, quais atletas realmente se destacaram em suas épocas e como seria possível comparar essas trajetórias com lendas de outros esportes, como acontece no xadrez, onde o sistema de ELO já é tradicionalmente utilizado para ranquear jogadores.
#
# Inspirado por essa busca, este projeto propõe uma análise aprofundada do cenário competitivo do Jiu-Jitsu, utilizando um modelo de ELO Rating adaptado para lutas. O objetivo é não apenas identificar os atletas de maior destaque ao longo do tempo, mas também entender padrões e dinâmicas presentes nas competições, respondendo perguntas como:
#
# **Quem dominou cada geração?**
#
# **Como se comparam os maiores campeões em termos de performance?**
#
# **Quem obteve o maior ranque da história?**
#
# A base de dados utilizada neste estudo reúne informações históricas de competições, com registros detalhados de lutas, vitórias, derrotas e evolução de **ELO** de cada atleta. Com esses dados, torna-se possível analisar trajetórias, identificar momentos de ascensão e queda, e trazer uma perspectiva estatística sobre quem, de fato, foi dominante em cada período.
#
#
#
# ---
#
#
#
#
#
#
#
# A base de dados utilizada neste estudo reúne informações históricas de competições, com registros detalhados de lutas, vitórias, derrotas e evolução de ELO de cada atleta. Com esses dados, torna-se possível analisar trajetórias, identificar momentos de ascensão e queda, e trazer uma perspectiva estatística sobre quem, de fato, foi dominante em cada período.
#
# Ao final do processo, foi aplicado o algoritmo de K-means para segmentar os atletas em três grandes grupos:
#
# **Cluster 0**: Iniciantes ou atletas em desenvolvimento
#
# **Cluster 1**: Avançados e de elite competitiva
#
# **Cluster 2**: Intermediários
#
# Essa **divisão** permite visualizar diferentes perfis competitivos e compreender melhor a dinâmica do esporte, as barreiras para chegar à elite e o papel do volume de lutas e regularidade de resultados na construção de uma carreira vitoriosa.

# %% [markdown]
# ## Coleta e Extração dos Dados – Histórico de Lutas via **BJJ Heroes**
#
# Para realizar este projeto, foi necessário construir uma base de dados robusta contendo o histórico de lutas dos principais atletas do Jiu-Jitsu competitivo. Essa coleta foi feita a partir do site ***BJJ Heroes***, uma das maiores referências mundiais em registros e biografias de lutadores da modalidade.
#
# A extração dos dados foi realizada por meio de web scraping, utilizando bibliotecas **Python** como **requests** e **BeautifulSoup**. Inicialmente, foi feita uma varredura na página principal do site, que contém uma **lista A–Z** com todos os atletas cadastrados. Dessa lista, foram coletados os links individuais de perfil de cada lutador.
#
# Em seguida, para cada atleta, foi acessada sua página de perfil e extraído o nome real, além do bloco contendo o histórico de lutas. Cada linha desse bloco representa uma luta, da qual foram registrados dados como:
#
#
# *   Nome do Atleta
#
# *   Adversário
#
# *   Resultado (vitória, derrota, empate)
#
# *   Método de vitória
#
# *   Evento e ano
#
# *   Categoria de peso e fase do campeonato
#
# *   Fight_id
#
#
#
#
#
# O processo foi automatizado para garantir maior performance e evitar sobrecarga no servidor do site, utilizando uma sessão persistente **(requests.Session())** e processamento paralelo com **ThreadPoolExecutor**, agilizando a coleta e tornando-a escalável para centenas de atletas.
#
# Após a extração de todas as lutas, os dados foram organizados em um DataFrame pandas e salvos em arquivo **CSV**, formando uma base consolidada com milhares de registros de combates históricos.
#
# Durante essa extração, além dos dados visíveis (nome do adversário, resultado, método de vitória, evento, categoria, fase e ano), foi coletada também uma coluna oculta chamada “id”. Este identificador único, presente de forma implícita na tabela do site, é fundamental porque representa a ordem cronológica dos combates daquele atleta — sendo normalmente um código interno usado para rastreamento ou referência de cada luta.
#
# A coluna id permitiu que todas as lutas fossem organizadas na ordem correta em que aconteceram, o que é absolutamente essencial para análises temporais, cálculo preciso de evolução do ELO Rating e reconstrução das trajetórias competitivas dos atletas. Sem esse identificador, as lutas poderiam ficar fora de ordem, prejudicando a análise de progressão dos atletas ao longo dos anos.

# %% [markdown]
# **Instalando bibliotecas necessárias**

# %%
pip install requests pandas beautifulsoup4 tqdm unicode rapidfuzz yellowbrick  adjustText
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting unicode
#   Downloading unicode-2.9-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: yellowbrick in /usr/local/lib/python3.11/dist-packages (1.5)
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from yellowbrick) (3.10.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from yellowbrick) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from yellowbrick) (1.6.1)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# Downloading unicode-2.9-py2.py3-none-any.whl (14 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 28.9 MB/s eta 0:00:00
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: unicode, rapidfuzz, adjustText
# Successfully installed adjustText-1.3.0 rapidfuzz-3.13.0 unicode-2.9

# %% [markdown]
# **Importando ibliotecas neccesárias**

# %%
import re
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import pandas as pd
from collections import defaultdict
from collections import Counter
import unicodedata
from rapidfuzz import process, fuzz
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.interpolate import make_interp_spline
from adjustText import adjust_text
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import matplotlib.gridspec as gridspec
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import KElbowVisualizer

# %% [markdown]
# Inicializando o **WEB-SCRAPING**, usando sessão e thread.

# %%
# Sessão persistente para performance
session = requests.Session()

# Armazena as lutas por slug de lutador
lutas_por_lutador = defaultdict(list)

def slugify_name(full_name: str) -> str:
    """
    Converte um nome completo em slug:
    """
    clean = re.sub(r"[^\w\s-]", "", full_name, flags=re.UNICODE)
    parts = re.split(r"[\s]+", clean.strip())
    return "-".join(parts).lower()

def get_fighters():
    """
    Coleta da página A–Z os hrefs originais (?p=####) de cada lutador,
    garantindo que a URL exista e evitando 404 por slug incorreto.
    """
    url = "https://www.bjjheroes.com/a-z-bjj-fighters-list"
    resp = session.get(url, timeout=10)
    if resp.status_code != 200:
        print("Erro ao acessar a lista de lutadores.")
        return []
    soup = BeautifulSoup(resp.content, 'html.parser')
    fighter_ids = []
    for a in soup.select("td.column-1 a"):
        href = a.get("href")
        if href:
            fighter_ids.append(href)  # ex: "?p=8141"
    return fighter_ids

def scrape_fighter(fighter_id):
    """
    Usa o ID  para acessar o perfil:
    1) extrai o nome real do <h1>
    2) gera um slug amigável via slugify_name()
    3) coleta o histórico de lutas sob esse slug
    Retorna (slug, erro).
    """
    url = f"https://www.bjjheroes.com/bjj-fighters/{fighter_id}"
    try:
        resp = session.get(url, timeout=5)
        if resp.status_code != 200:
            return fighter_id, f"HTTP {resp.status_code}"

        soup = BeautifulSoup(resp.content, 'html.parser')

        # 1) pega nome completo do <h1>
        h1 = soup.find("h1")
        real_name = h1.get_text(strip=True) if h1 else fighter_id
        slug = slugify_name(real_name)

        # 2) localiza o bloco de lutas
        content = soup.find("div", class_="text-content")
        if not content:
            return slug, "sem text-content"
        plug = content.find("div", class_="fighter_info_plug")
        if not plug:
            return slug, "sem fighter_info_plug"
        wrapper = plug.find("div", class_="table-responsive")
        if not wrapper:
            return slug, "sem table-responsive"
        table = wrapper.find("table")
        if not table:
            return slug, "sem <table>"
        tbody = table.find("tbody")
        if not tbody:
            return slug, "sem <tbody>"

        # 3) itera cada linha de luta
        for row in tbody.find_all("tr"):
            cols = row.find_all("td")
            if len(cols) < 8:
                continue
            lutas_por_lutador[slug].append({
                "fighter":     slug,
                "fight_id":    cols[0].get_text(strip=True),
                "opponent":    cols[1].get_text(strip=True),
                "result":      cols[2].get_text(strip=True),
                "method":      cols[3].get_text(strip=True),
                "competition": cols[4].get_text(strip=True),
                "weight":      cols[5].get_text(strip=True),
                "stage":       cols[6].get_text(strip=True),
                "year":        cols[7].get_text(strip=True),
            })

        return slug, None

    except requests.exceptions.RequestException:
        return fighter_id, "erro de rede"

def process_fighters(fighter_ids, max_workers=10):
    """
    Processa em paralelo todos os IDs, exibe progresso e coleta eventuais erros.
    """
    errors = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(scrape_fighter, fid): fid for fid in fighter_ids}
        with tqdm(total=len(futures), desc="Lutadores processados", unit="lutador") as pbar:
            for future in as_completed(futures):
                slug, err = future.result()
                count = len(lutas_por_lutador.get(slug, []))
                pbar.set_postfix_str(f"{slug}: {count} lutas")
                pbar.update(1)
                if err:
                    errors.append(f"{slug} → {err}")

    if errors:
        print("\nErros encontrados:")
        for e in errors:
            print(" •", e)

def salvar_csv(path='historico_lutas.csv'):
    """
    Concatena todas as lutas coletadas em um DataFrame e salva em CSV.
    """
    total = sum(len(v) for v in lutas_por_lutador.values())
    if total == 0:
        print("Nenhuma luta coletada. Verifique os seletores.")
        return
    df = pd.DataFrame([item for sub in lutas_por_lutador.values() for item in sub])
    df.to_csv(path, index=False, encoding='utf-8-sig')
    print(f"✅ {len(df)} lutas salvas em '{path}'.")

if __name__ == "__main__":
    print("📥 Coletando lista de lutadores (IDs)...")
    fighters = get_fighters()
    print(f"🔍 {len(fighters)} perfis encontrados:")
    print(fighters[:20])  # inspecione os primeiros 20 IDs
    process_fighters(fighters, max_workers=10)
    salvar_csv()
# Out:
# 📥 Coletando lista de lutadores (IDs)...
# 🔍 1445 perfis encontrados:
# ['/?p=8141', '/?p=9246', '/?p=8494', '/?p=390', '/?p=3083', '/?p=14157', '/?p=8814', '/?p=8131', '/?p=1133', '/?p=7478', '/?p=13245', '/?p=6339', '/?p=8968', '/?p=9541', '/?p=13498', '/?p=699', '/?p=1116', '/?p=909', '/?p=4328', '/?p=2189']
# Lutadores processados:  78%|███████▊  | 1126/1445 [04:23<01:12,  4.42lutador/s, sylvio-behring: 0 lutas]WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Lutadores processados: 100%|██████████| 1445/1445 [05:35<00:00,  4.31lutador/s, vinicius-garcia: 58 lutas]
# Erros encontrados:
#  • aarae-alexander → sem fighter_info_plug
#  • abmar-barbosa → sem fighter_info_plug
#  • adam-shahir-kayoom → sem fighter_info_plug
#  • admilson-juquinha-brites → sem fighter_info_plug
#  • adriano-martins → sem fighter_info_plug
#  • adriana-martins → sem fighter_info_plug
#  • adriano-silva → sem fighter_info_plug
#  • alan-moraes → sem fighter_info_plug
#  • alberto-crane → sem fighter_info_plug
#  • beto-carmona → sem fighter_info_plug
#  • alex-martins → sem fighter_info_plug
#  • leka-vieira → sem fighter_info_plug
#  • alessandro-capodeferro → sem fighter_info_plug
#  • alexandre-baraúna → sem fighter_info_plug
#  • alexandre-de-souza → sem fighter_info_plug
#  • alexandro-ceconi → sem fighter_info_plug
#  • alexandre-paiva-gigi → sem fighter_info_plug
#  • alexandre-pulga-pimentel → sem fighter_info_plug
#  • alexandre-puga → sem fighter_info_plug
#  • alexandre-baiano-santos → sem fighter_info_plug
#  • alexsandro-leke-machado → sem fighter_info_plug
#  • allan-góes → sem fighter_info_plug
#  • alvaro-barreto → sem fighter_info_plug
#  • alvaro-cabeção-bobadilla → sem fighter_info_plug
#  • amanda-tubby-alequin → sem fighter_info_plug
#  • amal-amjahid → sem fighter_info_plug
#  • amanda-monteiro-canuto → sem fighter_info_plug
#  • amin-touati-camelinho → sem fighter_info_plug
#  • ana-carolina-vieira → sem fighter_info_plug
#  • ana-carolina-schmitt → sem fighter_info_plug
#  • ana-laura-cordeiro → sem fighter_info_plug
#  • ana-maria-india-checkmat → sem fighter_info_plug
#  • anderson-pereira-deton → sem fighter_info_plug
#  • andré-almeida → sem fighter_info_plug
#  • andrea-baggio → sem fighter_info_plug
#  • andré-dedeco-almeida → sem fighter_info_plug
#  • andre-maracaba → sem fighter_info_plug
#  • andre-tim-monteiro → sem fighter_info_plug
#  • andre-pederneiras → sem fighter_info_plug
#  • andre-quiles → sem fighter_info_plug
#  • andre-negão-terêncio → sem fighter_info_plug
#  • andressa-cintra → sem fighter_info_plug
#  • angelica-galvão → sem fighter_info_plug
#  • tony-pacenski → sem fighter_info_plug
#  • aj-scales → sem fighter_info_plug
#  • anthony-perosh → sem fighter_info_plug
#  • antonio-de-melo-brazil-021 → sem fighter_info_plug
#  • antonio-peinado → sem fighter_info_plug
#  • juninho-crivelari → sem fighter_info_plug
#  • antônio-rodrigo-nogueira-minotauro → sem fighter_info_plug
#  • arlisson-kiki-melo → sem fighter_info_plug
#  • armando-wridt → sem fighter_info_plug
#  • augusto-ferrari → sem fighter_info_plug
#  • guto-monteiro → sem fighter_info_plug
#  • beatriz-mesquita → sem fighter_info_plug
#  • ben-baxter → sem fighter_info_plug
#  • bernardo-pitel → sem fighter_info_plug
#  • bianca-andrade → sem fighter_info_plug
#  • brenda-heller → sem fighter_info_plug
#  • brian-beaury → sem fighter_info_plug
#  • brian-beauchamp → sem fighter_info_plug
#  • bruno-amorim → sem fighter_info_plug
#  • bruno-alves → sem fighter_info_plug
#  • bruno-barbosa → sem fighter_info_plug
#  • bruno-bastos → sem fighter_info_plug
#  • bruno-de-paula → sem fighter_info_plug
#  • bruno-ferreira → sem fighter_info_plug
#  • bruno-matias → sem fighter_info_plug
#  • bruno-mendes → sem fighter_info_plug
#  • caio-almeida → sem fighter_info_plug
#  • caio-terra → sem fighter_info_plug
#  • carina-santi → sem fighter_info_plug
#  • carlos-henrique-elias-caique → sem fighter_info_plug
#  • carley-gracie → sem fighter_info_plug
#  • carlos-gracie-sr → sem fighter_info_plug
#  • carlos-gracie-junior-carlinhos → sem fighter_info_plug
#  • carlos-henrique → sem fighter_info_plug
#  • carlos-lemos-escorrega → sem fighter_info_plug
#  • carlos-machado → sem fighter_info_plug
#  • carlos-melo → sem fighter_info_plug
#  • carlos-portugues-vieira → sem fighter_info_plug
#  • carlson-gracie → sem fighter_info_plug
#  • caroline-de-lazzer → sem fighter_info_plug
#  • cassio-werneck → sem fighter_info_plug
#  • catherine-perret → sem fighter_info_plug
#  • cleber-luciano → sem fighter_info_plug
#  • cezar-guimarães-casquinha → sem fighter_info_plug
#  • cesar-gracie → sem fighter_info_plug
#  • charlotte-von-baumgarten → sem fighter_info_plug
#  • charles-do-bronx-oliveira → sem fighter_info_plug
#  • christian-graugart → sem fighter_info_plug
#  • chris-moriarty → sem fighter_info_plug
#  • christian-xaropinho-uflacker → sem fighter_info_plug
#  • cícero-costha → sem fighter_info_plug
#  • claudia-do-val → sem fighter_info_plug
#  • claudio-franca → sem fighter_info_plug
#  • claudio-joanino → sem fighter_info_plug
#  • cosmo-dias → sem fighter_info_plug
#  • craig-kukuk → sem fighter_info_plug
#  • crézio-chavez → sem fighter_info_plug
#  • crezio-de-souza → sem fighter_info_plug
#  • cristiano-marcello → sem fighter_info_plug
#  • cristiano-carioca → sem fighter_info_plug
#  • cristiano-lazzarini → sem fighter_info_plug
#  • crolin-gracie → sem fighter_info_plug
#  • daisuke-shiraki → sem fighter_info_plug
#  • cindy-omatsu → sem fighter_info_plug
#  • daniel-azevedo → sem fighter_info_plug
#  • daniel-beleza → sem fighter_info_plug
#  • daniel-garcia → sem fighter_info_plug
#  • daniel-otero → sem fighter_info_plug
#  • danielle-alvarez → sem fighter_info_plug
#  • daniel-valverde → sem fighter_info_plug
#  • danilo-cherman → sem fighter_info_plug
#  • dave-camarillo → sem fighter_info_plug
#  • david-avellan → sem fighter_info_plug
#  • david-juliano-lemes → sem fighter_info_plug
#  • david-jacobs → sem fighter_info_plug
#  • david-raab → sem fighter_info_plug
#  • david-onuma → sem fighter_info_plug
#  • david-meyer → sem fighter_info_plug
#  • delson-heleno-pé-de-chumbo → sem fighter_info_plug
#  • denilson-pimenta → sem fighter_info_plug
#  • denny-prokopos → sem fighter_info_plug
#  • dennis-asche → sem fighter_info_plug
#  • denys-darzi → sem fighter_info_plug
#  • deoclecio-paulo → sem fighter_info_plug
#  • diego-bispo → sem fighter_info_plug
#  • dima-murovanni → sem fighter_info_plug
#  • diego-vivaldo → sem fighter_info_plug
#  • donald-achnick → sem fighter_info_plug
#  • dustin-clean-denes → sem fighter_info_plug
#  • doug-pelinkovic → sem fighter_info_plug
#  • edson-diniz → sem fighter_info_plug
#  • /?p=199 → HTTP 404
#  • eduardo-jamelão-conceição → sem fighter_info_plug
#  • eduardo-galvão → sem fighter_info_plug
#  • eduardo-gonçalves → sem fighter_info_plug
#  • /?p=4874 → HTTP 404
#  • eduardo-monteiro → sem fighter_info_plug
#  • eduardo-santoro-portuguese → sem fighter_info_plug
#  • eduardo-rios → sem fighter_info_plug
#  • ed-ramos-jiu-jitsu → sem fighter_info_plug
#  • eduardo-brigadeiro-venâncio → sem fighter_info_plug
#  • eloisa-souto → sem fighter_info_plug
#  • eliot-marshall → sem fighter_info_plug
#  • elina-moestam → sem fighter_info_plug
#  • elvira-karppinen → sem fighter_info_plug
#  • emilly-alves-vasconcelos → sem fighter_info_plug
#  • éricka-almeida → sem fighter_info_plug
#  • erik-wanderley → sem fighter_info_plug
#  • erin-herle → sem fighter_info_plug
#  • everton-santana-dentinho → sem fighter_info_plug
#  • fabiana-borges → sem fighter_info_plug
#  • fabiano-silva-att → sem fighter_info_plug
#  • fabbio-passos → sem fighter_info_plug
#  • fabio-coringa → sem fighter_info_plug
#  • fábio-andrade → sem fighter_info_plug
#  • fabio-clemente → sem fighter_info_plug
#  • fabio-gurgel → sem fighter_info_plug
#  • fabio-leopoldo → sem fighter_info_plug
#  • fabio-pateta-prado → sem fighter_info_plug
#  • fabio-santos → sem fighter_info_plug
#  • fabricio-morango → sem fighter_info_plug
#  • fabricio-martins → sem fighter_info_plug
#  • fabricio-medici → sem fighter_info_plug
#  • fabrício-moreira → sem fighter_info_plug
#  • faustino-pina-neto → sem fighter_info_plug
#  • federico-tisi → sem fighter_info_plug
#  • felipe-cavalcante-fredson-alves-jj → sem fighter_info_plug
#  • felipe-costa → sem fighter_info_plug
#  • felipe-zicro-neto → sem fighter_info_plug
#  • felipe-bocão-silva → sem fighter_info_plug
#  • felipe-mota → sem fighter_info_plug
#  • fernando-di-piero-soluço → sem fighter_info_plug
#  • fernando-pinduka → sem fighter_info_plug
#  • fernando-boi → sem fighter_info_plug
#  • fernando-pinduka → sem fighter_info_plug
#  • fernando-monteiro-brasil-021 → sem fighter_info_plug
#  • fernando-paradeda → sem fighter_info_plug
#  • firas-zahabi → sem fighter_info_plug
#  • flavio-behring → sem fighter_info_plug
#  • flávio-almeida-cachorrinho → sem fighter_info_plug
#  • francisco-toco-albuquerque → sem fighter_info_plug
#  • francisco-toco-albuquerque → sem fighter_info_plug
#  • chico-mendes → sem fighter_info_plug
#  • master-francisco-mansor → sem fighter_info_plug
#  • master-francisco-sá → sem fighter_info_plug
#  • fredson-paixao → sem fighter_info_plug
#  • gabriel-gonzaga → sem fighter_info_plug
#  • gabriel-goulart → sem fighter_info_plug
#  • gabriel-kitober → sem fighter_info_plug
#  • gabriel-marinho → sem fighter_info_plug
#  • gabriel-rainho → sem fighter_info_plug
#  • gabriel-ribeiro-brazil-021 → sem fighter_info_plug
#  • gabriel-willlcox → sem fighter_info_plug
#  • gabriela-fechter → sem fighter_info_plug
#  • gabrielle-mccomb → sem fighter_info_plug
#  • gabriel-procópio-fonseca → sem fighter_info_plug
#  • garth-taylor → sem fighter_info_plug
#  • gastão-gracie → sem fighter_info_plug
#  • geny-rebelo → sem fighter_info_plug
#  • george-gracie → sem fighter_info_plug
#  • gezary-matuda → sem fighter_info_plug
#  • geraldo-flôres → sem fighter_info_plug
#  • greg-souders → sem fighter_info_plug
#  • guilherme-cascon → sem fighter_info_plug
#  • gustavo-dantas → sem fighter_info_plug
#  • gustavo-machado → sem fighter_info_plug
#  • gustavo-dias-elias → sem fighter_info_plug
#  • gustavo-pires-siri → sem fighter_info_plug
#  • guybson-sá → sem fighter_info_plug
#  • heath-pedigo → sem fighter_info_plug
#  • hannette-staack → sem fighter_info_plug
#  • heather-raftery → sem fighter_info_plug
#  • helder-medeiros-spongebob → sem fighter_info_plug
#  • helio-vigio → sem fighter_info_plug
#  • helio-soneca-moreira → sem fighter_info_plug
#  • helvecio-penna → sem fighter_info_plug
#  • henrique-machado → sem fighter_info_plug
#  • hillary-williams → sem fighter_info_plug
#  • huanderson-pavão-gfteam → sem fighter_info_plug
#  • humberto-silveira → sem fighter_info_plug
#  • ian-behring → sem fighter_info_plug
#  • ida-hansson → sem fighter_info_plug
#  • ian-mcpherson → sem fighter_info_plug
#  • ighor-horta → sem fighter_info_plug
#  • igor-rodrigues → sem fighter_info_plug
#  • italo-lins → sem fighter_info_plug
#  • ítallo-vilardo → sem fighter_info_plug
#  • ivaniel-oliveira → sem fighter_info_plug
#  • ivan-gomes → sem fighter_info_plug
#  • jair-lourenço → sem fighter_info_plug
#  • jaqueline-amorim → sem fighter_info_plug
#  • jake-mackenzie → sem fighter_info_plug
#  • james-brasco → sem fighter_info_plug
#  • jim-harbison → sem fighter_info_plug
#  • janni-larsson → sem fighter_info_plug
#  • javier-vazquez → sem fighter_info_plug
#  • jean-kleber → sem fighter_info_plug
#  • jeff-joslin → sem fighter_info_plug
#  • jena-bishop → sem fighter_info_plug
#  • jeremy-arel-gerbil → sem fighter_info_plug
#  • jessica-cristina-santos → sem fighter_info_plug
#  • jessica-swanson → sem fighter_info_plug
#  • jessica-flowers → sem fighter_info_plug
#  • joão-johnny-faria → sem fighter_info_plug
#  • joão-zeferino → sem fighter_info_plug
#  • joão-roque → sem fighter_info_plug
#  • joao-alberto-barreto → sem fighter_info_plug
#  • joão-jones-oliveira → sem fighter_info_plug
#  • joe-baize → sem fighter_info_plug
#  • joe-moreira → sem fighter_info_plug
#  • joel-tudor → sem fighter_info_plug
#  • joel-gingery → sem fighter_info_plug
#  • jorge-britto → sem fighter_info_plug
#  • john-danaher → sem fighter_info_plug
#  • john-crouch → sem fighter_info_plug
#  • john-kavanagh → sem fighter_info_plug
#  • john-frankl → sem fighter_info_plug
#  • john-lewis → sem fighter_info_plug
#  • john-will → sem fighter_info_plug
#  • jonatas-tagarela-gurgel → sem fighter_info_plug
#  • jonatas-novaes → sem fighter_info_plug
#  • josé-aldo → sem fighter_info_plug
#  • josé-leão-teixeira-zé-beleza → sem fighter_info_plug
#  • jose-junior → sem fighter_info_plug
#  • jose-carlos → sem fighter_info_plug
#  • zé-mario-esfiha-queiroga → sem fighter_info_plug
#  • zé-marcello → sem fighter_info_plug
#  • josef-manuel-zé-cobra → sem fighter_info_plug
#  • zé-radiola → sem fighter_info_plug
#  • josh-griffiths → sem fighter_info_plug
#  • juan-miguel-iturralde → sem fighter_info_plug
#  • juan-lopes-da-silva → sem fighter_info_plug
#  • julio-cesar-pereira → sem fighter_info_plug
#  • julius-park → sem fighter_info_plug
#  • julio-foca-fernandez → sem fighter_info_plug
#  • julia-boscher → sem fighter_info_plug
#  • juliana-borges → sem fighter_info_plug
#  • jurandir-moura → sem fighter_info_plug
#  • justin-ordinario → sem fighter_info_plug
#  • jw-wright → sem fighter_info_plug
#  • jurandir-moura → sem fighter_info_plug
#  • keith-mckenzie → sem fighter_info_plug
#  • kid-peligro → sem fighter_info_plug
#  • keiser-girão → sem fighter_info_plug
#  • karel-pravec-silver-fox → sem fighter_info_plug
#  • koji-shibamoto → sem fighter_info_plug
#  • kyra-gracie → sem fighter_info_plug
#  • kristen-martin → sem fighter_info_plug
#  • kristin-mikkelson → sem fighter_info_plug
#  • kurt-osiander → sem fighter_info_plug
#  • kleber-buiú → sem fighter_info_plug
#  • larissa-campos → sem fighter_info_plug
#  • larissa-paes → sem fighter_info_plug
#  • laércio-fernandes → sem fighter_info_plug
#  • laura-barker → sem fighter_info_plug
#  • laurence-cousin-fouillat → sem fighter_info_plug
#  • leandro-escobar-tatu → sem fighter_info_plug
#  • leandro-nyza → sem fighter_info_plug
#  • leandro-lora → sem fighter_info_plug
#  • leandro-leu-martins → sem fighter_info_plug
#  • livia-gluchowska → sem fighter_info_plug
#  • laurah-hallock → sem fighter_info_plug
#  • leo-arruda → sem fighter_info_plug
#  • leo-davila → sem fighter_info_plug
#  • leonardo-castello-branco → sem fighter_info_plug
#  • leonardo-peçanha → sem fighter_info_plug
#  • luanna-alzuguir → sem fighter_info_plug
#  • letícia-ribeiro → sem fighter_info_plug
#  • lloyd-irvin → sem fighter_info_plug
#  • louie-cercedez → sem fighter_info_plug
#  • lucas-sachs → sem fighter_info_plug
#  • luciano-nucci-casquinha → sem fighter_info_plug
#  • lucio-rodrigues-lagarto → sem fighter_info_plug
#  • luis-carlos-manimal → sem fighter_info_plug
#  • luis-heredia → sem fighter_info_plug
#  • luis-gustavo-guga-campos → sem fighter_info_plug
#  • luis-roberto-duarte-bebeo → sem fighter_info_plug
#  • luis-marques → sem fighter_info_plug
#  • luis-sergio-roman → sem fighter_info_plug
#  • luiz-guilherme → sem fighter_info_plug
#  • luiz-frança → sem fighter_info_plug
#  • luiz-dias → sem fighter_info_plug
#  • luiz-ribeiro-manxinha → sem fighter_info_plug
#  • luiz-renato-tom-abdo → sem fighter_info_plug
#  • luzia-fernandes → sem fighter_info_plug
#  • luiza-monteiro → sem fighter_info_plug
#  • luke-harris → sem fighter_info_plug
#  • maggie-grindatti → sem fighter_info_plug
#  • marcel-louzado → sem fighter_info_plug
#  • marc-laimon → sem fighter_info_plug
#  • marcelino-freitas → sem fighter_info_plug
#  • marcelo-behring → sem fighter_info_plug
#  • marcelo-azevedo-uirapuru → sem fighter_info_plug
#  • marcelo-cohen → sem fighter_info_plug
#  • marcelo-cohen → sem fighter_info_plug
#  • marcelo-nunes → sem fighter_info_plug
#  • marcelo-capo-martins → sem fighter_info_plug
#  • marcelo-machado → sem fighter_info_plug
#  • marcelo-ribeiro → sem fighter_info_plug
#  • marcelo-pereira → sem fighter_info_plug
#  • marcello-salazar → sem fighter_info_plug
#  • marcelo-saporito → sem fighter_info_plug
#  • marcio-dos-santos → sem fighter_info_plug
#  • marcio-stambowsky → sem fighter_info_plug
#  • marco-barbosa → sem fighter_info_plug
#  • marco-vilella-gigante → sem fighter_info_plug
#  • marco-canha → sem fighter_info_plug
#  • marcos-barreto → sem fighter_info_plug
#  • marcos-da-matta-parrumpinha → sem fighter_info_plug
#  • marcos-cerqueira → sem fighter_info_plug
#  • marcos-escobar → sem fighter_info_plug
#  • marcos-galvao-lôro → sem fighter_info_plug
#  • marcos-de-souza → sem fighter_info_plug
#  • marcos-ratinho → sem fighter_info_plug
#  • marcos-de-oliveira → sem fighter_info_plug
#  • marcos-torregrosa-yemaso → sem fighter_info_plug
#  • marcus-bello → sem fighter_info_plug
#  • marcus-norat → sem fighter_info_plug
#  • maria-malyjasiak → sem fighter_info_plug
#  • marina-ribeiro → sem fighter_info_plug
#  • mario-claudio-tallarico → sem fighter_info_plug
#  • mario-yokoyama-gracie-oceania → sem fighter_info_plug
#  • mariusz-linke-gold-team → sem fighter_info_plug
#  • mark-ramos → sem fighter_info_plug
#  • marlon-sandro → sem fighter_info_plug
#  • matt-thornton → sem fighter_info_plug
#  • mauricio-antunes → sem fighter_info_plug
#  • mauricio-gomes → sem fighter_info_plug
#  • maurício-mariano → sem fighter_info_plug
#  • mauro-pacífico → sem fighter_info_plug
#  • mauro-chueng → sem fighter_info_plug
#  • mayko-araújo → sem fighter_info_plug
#  • mayara-custódio → sem fighter_info_plug
#  • max-carvalho → sem fighter_info_plug
#  • maxine-thylin → sem fighter_info_plug
#  • max-trombini → sem fighter_info_plug
#  • melissa-cueto → sem fighter_info_plug
#  • melqui-galvão → sem fighter_info_plug
#  • michael-zenga → sem fighter_info_plug
#  • michel-langhi → sem fighter_info_plug
#  • michelle-nicolini → sem fighter_info_plug
#  • mike-fowler → sem fighter_info_plug
#  • milton-bastos → sem fighter_info_plug
#  • mitsuyoshi-hayakawa → sem fighter_info_plug
#  • milton-regis → sem fighter_info_plug
#  • moacir-mendes-júnior → sem fighter_info_plug
#  • moisés-muradi → sem fighter_info_plug
#  • monir-salomão → sem fighter_info_plug
#  • monique-ricardo → sem fighter_info_plug
#  • monica-vanessa-silva → sem fighter_info_plug
#  • murilo-bustamante → sem fighter_info_plug
#  • muzio-de-angelis → sem fighter_info_plug
#  • nabil-aziz-master-nabil → sem fighter_info_plug
#  • nathalie-ribeiro → sem fighter_info_plug
#  • natasha-quiza → sem fighter_info_plug
#  • nathan-carroll → sem fighter_info_plug
#  • nathan-mendelsohn → sem fighter_info_plug
#  • nahum-rabay → sem fighter_info_plug
#  • nelson-monteiro → sem fighter_info_plug
#  • nicolas-gregoriades → sem fighter_info_plug
#  • nikki-sullivan → sem fighter_info_plug
#  • nina-moura → sem fighter_info_plug
#  • octavio-couto-ratinho → sem fighter_info_plug
#  • nuno-martins → sem fighter_info_plug
#  • nyjah-rollins → sem fighter_info_plug
#  • bold-erdene-odsuren → sem fighter_info_plug
#  • octavio-de-almeida-senior → sem fighter_info_plug
#  • olavo-abreu → sem fighter_info_plug
#  • oliver-geddes → sem fighter_info_plug
#  • omar-salum → sem fighter_info_plug
#  • osvaldo-alves → sem fighter_info_plug
#  • oswaldo-fadda → sem fighter_info_plug
#  • oswaldo-gracie → sem fighter_info_plug
#  • oswaldo-paqueta → sem fighter_info_plug
#  • patricia-lage → sem fighter_info_plug
#  • patrick-bittan → sem fighter_info_plug
#  • pablo-silva → sem fighter_info_plug
#  • pámela-bóveda-aguirre → sem fighter_info_plug
#  • paul-schreiner → sem fighter_info_plug
#  • paulo-filho → sem fighter_info_plug
#  • paulo-gazze-jr → sem fighter_info_plug
#  • paulo-mauricio-strauch → sem fighter_info_plug
#  • pedro-hemeterio → sem fighter_info_plug
#  • pedro-mello → sem fighter_info_plug
#  • pedro-pacheco-fernandes-tu-kaha-bjj → sem fighter_info_plug
#  • pedro-sauer → sem fighter_info_plug
#  • pete-the-greek-letsos → sem fighter_info_plug
#  • penny-thomas → sem fighter_info_plug
#  • philippe-balmant → sem fighter_info_plug
#  • radek-turek → sem fighter_info_plug
#  • rafael-barbosa → sem fighter_info_plug
#  • rafael-fofitio-barros → sem fighter_info_plug
#  • rafael-correa-gordinho → sem fighter_info_plug
#  • rafael-freitas → sem fighter_info_plug
#  • rafael-heck → sem fighter_info_plug
#  • rafael-rafinha-dallinha → sem fighter_info_plug
#  • rafael-dos-anjos → sem fighter_info_plug
#  • ralph-gracie → sem fighter_info_plug
#  • raphael-abi-rihan → sem fighter_info_plug
#  • ramon-lemos → sem fighter_info_plug
#  • raquel-paaluhi-canuto → sem fighter_info_plug
#  • renato-migliaccio → sem fighter_info_plug
#  • raphael-chaves-catatau → sem fighter_info_plug
#  • raoni-barcelos → sem fighter_info_plug
#  • raul-gomes → sem fighter_info_plug
#  • reginaldo-gurgel-almeida → sem fighter_info_plug
#  • reinaldo-ribeiro → sem fighter_info_plug
#  • relson-gracie → sem fighter_info_plug
#  • renata-marinho → sem fighter_info_plug
#  • renan-barão → sem fighter_info_plug
#  • renato-barreto → sem fighter_info_plug
#  • renato-tavares → sem fighter_info_plug
#  • renato-migliaccio → sem fighter_info_plug
#  • reyson-gracie → sem fighter_info_plug
#  • ricardo-cavalcanti → sem fighter_info_plug
#  • ricardo-de-la-riva → sem fighter_info_plug
#  • ricardo-rey-diogo → sem fighter_info_plug
#  • ricardo-feliciano → sem fighter_info_plug
#  • ricardo-marques → sem fighter_info_plug
#  • ricardo-franjinha-miller → sem fighter_info_plug
#  • ricardo-soranco → sem fighter_info_plug
#  • richard-dickie-martin → sem fighter_info_plug
#  • rikako-yuasa → sem fighter_info_plug
#  • rilion-gracie → sem fighter_info_plug
#  • robert-drysdale → sem fighter_info_plug
#  • roberto-atalla → sem fighter_info_plug
#  • roberto-gordo-correa → sem fighter_info_plug
#  • roberto-godoi → sem fighter_info_plug
#  • roberto-lage → sem fighter_info_plug
#  • roberto-tozi → sem fighter_info_plug
#  • robson-chaves → sem fighter_info_plug
#  • robson-gracie → sem fighter_info_plug
#  • robson-mau-mau → sem fighter_info_plug
#  • rockson-gracie → sem fighter_info_plug
#  • /?p=2048 → HTTP 404
#  • rodney-ellis → sem fighter_info_plug
#  • rodolphe-olivier → sem fighter_info_plug
#  • rodrigo-carvalho → sem fighter_info_plug
#  • rodrigo-brucutu-cabral → sem fighter_info_plug
#  • rodrigo-fajardo-pimpolho → sem fighter_info_plug
#  • rodrigo-medeiros → sem fighter_info_plug
#  • rodrigo-ranieri-mike → sem fighter_info_plug
#  • rodrigo-munduruca → sem fighter_info_plug
#  • rodrigo-siqueira → sem fighter_info_plug
#  • roger-coelho → sem fighter_info_plug
#  • rodrigo-ribeiro → sem fighter_info_plug
#  • rogerio-poggio → sem fighter_info_plug
#  • rogerio-taborda → sem fighter_info_plug
#  • rolker-gracie → sem fighter_info_plug
#  • rolles-gracie → sem fighter_info_plug
#  • romero-jacaré-cavalcanti → sem fighter_info_plug
#  • royce-gracie → sem fighter_info_plug
#  • rufino-gomes-morcego → sem fighter_info_plug
#  • ryan-beauregard → sem fighter_info_plug
#  • ryan-murphy-crosley-gracie-jj → sem fighter_info_plug
#  • ryo-ominami → sem fighter_info_plug
#  • ryron-gracie → sem fighter_info_plug
#  • saeed-dunkaev → sem fighter_info_plug
#  • samantha-cook → sem fighter_info_plug
#  • samuel-braga → sem fighter_info_plug
#  • salvatore-pace → sem fighter_info_plug
#  • samy-al-jamal → sem fighter_info_plug
#  • scott-kaplan → sem fighter_info_plug
#  • serena-gabrielli → sem fighter_info_plug
#  • sergio-calderon → sem fighter_info_plug
#  • sergio-benini → sem fighter_info_plug
#  • sérgio-íris → sem fighter_info_plug
#  • sergio-penha → sem fighter_info_plug
#  • sergio-babu-gasparelli → sem fighter_info_plug
#  • sergio-rios → sem fighter_info_plug
#  • sergio-zimmermann-canudo → sem fighter_info_plug
#  • sergio-bolão-souza → sem fighter_info_plug
#  • shane-rice → sem fighter_info_plug
#  • shanti-abelha → sem fighter_info_plug
#  • shawn-williams → sem fighter_info_plug
#  • sim-go → sem fighter_info_plug
#  • silvana-abreu → sem fighter_info_plug
#  • shinya-aoki → sem fighter_info_plug
#  • stéfano-corrêa → sem fighter_info_plug
#  • sylvio-behring → sem fighter_info_plug
#  • p13193 → sem text-content
#  • sofia-amarante → sem fighter_info_plug
#  • talia-marie-vaughan → sem fighter_info_plug
#  • talita-nogueira-treta → sem fighter_info_plug
#  • tammi-musumeci → sem fighter_info_plug
#  • tracey-goodell → sem fighter_info_plug
#  • thaís-ramos → sem fighter_info_plug
#  • thamires-monteiro → sem fighter_info_plug
#  • theodoro-canal → sem fighter_info_plug
#  • thiago-barreto → sem fighter_info_plug
#  • thiago-monstro-borges → sem fighter_info_plug
#  • thiago-fernandes → sem fighter_info_plug
#  • thiago-leiras-brazil-021 → sem fighter_info_plug
#  • thiago-rogerio-dos-santos-brazil-021 → sem fighter_info_plug
#  • thibaut-olivier → sem fighter_info_plug
#  • tiago-alves → sem fighter_info_plug
#  • tiago-rocha → sem fighter_info_plug
#  • todd-margolis → sem fighter_info_plug
#  • totila-jordan → sem fighter_info_plug
#  • travis-lutter → sem fighter_info_plug
#  • ulpiano-malachias → sem fighter_info_plug
#  • valmyr-neto → sem fighter_info_plug
#  • vanessa-english → sem fighter_info_plug
#  • vedha-toscano → sem fighter_info_plug
#  • vanessa-oliveira → sem fighter_info_plug
#  • vicente-junior → sem fighter_info_plug
#  • victor-costa → sem fighter_info_plug
#  • vinicius-aieta → sem fighter_info_plug
#  • vincent-nguyen → sem fighter_info_plug
#  • vinícius-coelho → sem fighter_info_plug
#  • vinicius-corrales → sem fighter_info_plug
#  • vinicius-draculino-magalhães → sem fighter_info_plug
#  • vinicius-marinho → sem fighter_info_plug
#  • vinícius-pedrosa → sem fighter_info_plug
#  • vitor-toledo → sem fighter_info_plug
#  • wagner-galeto-campos → sem fighter_info_plug
#  • wagnney-fabiano → sem fighter_info_plug
#  • waldemar-santana → sem fighter_info_plug
#  • waldomiro-perez-jr → sem fighter_info_plug
#  • washington-luis → sem fighter_info_plug
#  • walter-mattos → sem fighter_info_plug
#  • wellington-megaton-dias → sem fighter_info_plug
#  • wilson-bueno → sem fighter_info_plug
#  • william-abreu → sem fighter_info_plug
#  • wendell-alexander → sem fighter_info_plug
#  • master-wilson-mattos → sem fighter_info_plug
#  • wilson-moreira → sem fighter_info_plug
#  • xiong-yuxing-emma → sem fighter_info_plug
#  • yacinta-nguyen → sem fighter_info_plug
#  • yuki-nakai → sem fighter_info_plug
#  • yukinori-sasa → sem fighter_info_plug
#  • yusuke-honma → sem fighter_info_plug
#  • zach-maslany → sem fighter_info_plug
#  • yvone-duarte → sem fighter_info_plug
#  • zak-maxwell → sem fighter_info_plug
#  • shimon-mochizuki → sem fighter_info_plug
#  • andre-marola → sem fighter_info_plug
#  • alain-pozo → sem fighter_info_plug
#  • budo-jake → sem fighter_info_plug
#  • josé-higino → sem fighter_info_plug
#  • riccardo-ammendolia → sem fighter_info_plug
#  • mauro-ayres → sem fighter_info_plug
#  • paulo-coelho-brandão → sem fighter_info_plug
#  • fabio-binho-monteiro → sem fighter_info_plug
#  • henry-akins → sem fighter_info_plug
#  • renato-miragaia → sem fighter_info_plug
#  • fernando-gurgel → sem fighter_info_plug
#  • fernando-yamasaki → sem fighter_info_plug
#  • henry-akins → sem fighter_info_plug
#  • bruno-fernandes → sem fighter_info_plug
#  • luca-atalla → sem fighter_info_plug
#  • marcelo-alonso → sem fighter_info_plug
#  • marcelo-mello → sem fighter_info_plug
#  • kim-terra → sem fighter_info_plug
#  • sergio-malibu-jardim → sem fighter_info_plug
#  • monique-elias → sem fighter_info_plug
#  • roy-harris → sem fighter_info_plug
#  • fernando-gurgel → sem fighter_info_plug
#  • bruno-fernandes → sem fighter_info_plug
#  • rodrigo-pagani → sem fighter_info_plug
#  • givanildo-santana → sem fighter_info_plug
#  • enson-inoue → sem fighter_info_plug
#  • fabiano-pega-leve-scherner → sem fighter_info_plug
#  • carlos-rosado → sem fighter_info_plug
#  • vinícius-cruz → sem fighter_info_plug
#  • rosângela-zanza-conceição → sem fighter_info_plug
#  • andré-motta → sem fighter_info_plug
#  • carlos-rollyson → sem fighter_info_plug
#  • tony-passos → sem fighter_info_plug
#  • tom-deblass → sem fighter_info_plug
#  • beneil-dariush → sem fighter_info_plug
#  • dean-liebenberg → sem fighter_info_plug
#  • venla-luukkonen → sem fighter_info_plug
#  • i̇brahim-i̇nal → sem fighter_info_plug
#  • herbert-burns → sem fighter_info_plug
#  • sebastian-lalli → sem fighter_info_plug
#  • jamie-cruz → sem fighter_info_plug
#  • márcio-rodrigues → sem fighter_info_plug
#  • alan-gumby-marques → sem fighter_info_plug
#  • emily-kwok → sem fighter_info_plug
#  • steve-maxwell → sem fighter_info_plug
#  • louis-vintaloro → sem fighter_info_plug
#  • joaquina-bonfim → sem fighter_info_plug
#  • rodrigo-freitas → sem fighter_info_plug
#  • josé-tiago-barros → sem fighter_info_plug
#  • bruno-paulista → sem fighter_info_plug
#  • everdan-mestre-dan-olegário → sem fighter_info_plug
#  • paulo-guillobel → sem fighter_info_plug
#  • andré-glodzinski → sem fighter_info_plug
#  • dc-maxwell → sem fighter_info_plug
#  • chris-haueter → sem fighter_info_plug
#  • jorge-pereira → sem fighter_info_plug
#  • fábio-negão-nascimento → sem fighter_info_plug
#  • felicia-oh → sem fighter_info_plug
#  • daniel-wanderley → sem fighter_info_plug
#  • wilson-reis → sem fighter_info_plug
#  • carlson-gracie-junior → sem fighter_info_plug
#  • paulo-rezende → sem fighter_info_plug
#  • vinicius-amaral → sem fighter_info_plug
#  • nic-ruben → sem fighter_info_plug
#  • adriano-moraes → sem fighter_info_plug
#  • reylson-gracie → sem fighter_info_plug
#  • gazzy-parman → sem fighter_info_plug
#  • suga-pop → sem fighter_info_plug
#  • ataíde-junior → sem fighter_info_plug
#  • wander-braga → sem fighter_info_plug
#  • karen-antunes → sem fighter_info_plug
#  • elan-santiago → sem fighter_info_plug
#  • luigi-mondelli → sem fighter_info_plug
#  • aldo-januário → sem fighter_info_plug
#  • suyan-queiroz → sem fighter_info_plug
#  • carlos-barreto → sem fighter_info_plug
#  • alison-tremblay → sem fighter_info_plug
#  • sophia-mcdermott-drysdale → sem fighter_info_plug
#  • ailson-brites → sem fighter_info_plug
#  • pirillo-roriz → sem fighter_info_plug
#  • alex-paz → sem fighter_info_plug
#  • paulo-sergio → sem fighter_info_plug
#  • emyr-shark-bussade → sem fighter_info_plug
#  • jason-gagnon → sem fighter_info_plug
#  • marcel-gonçalves → sem fighter_info_plug
#  • leo-dalla → sem fighter_info_plug
#  • henrique-gama-filho → sem fighter_info_plug
#  • pedro-duarte → sem fighter_info_plug
#  • patricia-fontes → sem fighter_info_plug
#  • pedro-gama-filho → sem fighter_info_plug
#  • amal-easton → sem fighter_info_plug
#  • neiman-gracie → sem fighter_info_plug
#  • régis-lebre → sem fighter_info_plug
#  • egan-inoue → sem fighter_info_plug
#  • kristina-barlaan → sem fighter_info_plug
#  • bruno-alminha-moreno → sem fighter_info_plug
#  • francisco-sázinho → sem fighter_info_plug
#  • james-boran → sem fighter_info_plug
#  • kiko-velloso → sem fighter_info_plug
#  • luciana-luka-dias → sem fighter_info_plug
#  • deborah-gracie-stambowsky → sem fighter_info_plug
#  • ryan-gracie → sem fighter_info_plug
#  • juarez-soares → sem fighter_info_plug
#  • carlos-terrinha → sem fighter_info_plug
#  • rodrigo-feijão → sem fighter_info_plug
#  • fernanda-mazzelli → sem fighter_info_plug
#  • adilson-bitta-lima → sem fighter_info_plug
#  • jared-weiner → sem fighter_info_plug
#  • danny-alvarez → sem fighter_info_plug
#  • vinicius-magoo-canevari → sem fighter_info_plug
#  • nathiely-de-jesus → sem fighter_info_plug
#  • stephen-roberto → sem fighter_info_plug
#  • jack-mcvicker → sem fighter_info_plug
#  • ariadne-oliveira → sem fighter_info_plug
#  • carlos-farias → sem fighter_info_plug
#  • wagner-mota → sem fighter_info_plug
#  • talita-alencar → sem fighter_info_plug
#  • luiz-tosta → sem fighter_info_plug
#  • marcus-antelante → sem fighter_info_plug
#  • rodrigo-pinheiro → sem fighter_info_plug
#  • tiago-pereira → sem fighter_info_plug
#  • fabricio-bicudo → sem fighter_info_plug
#  • manuel-manny-diaz → sem fighter_info_plug
#  • diogo-almeida → sem fighter_info_plug
#  • outi-järvilehto → sem fighter_info_plug
#  • andré-ushirobira → sem fighter_info_plug
#  • paulo-caruso → sem fighter_info_plug
#  • mauricio-russo → sem fighter_info_plug
#  • roli-delgado → sem fighter_info_plug
#  • manoel-neto → sem fighter_info_plug
#  • thamires-aquino → sem fighter_info_plug
#  • valdir-tio-chico-canuto → sem fighter_info_plug
#  • nakapan-phungephorn → sem fighter_info_plug
#  • eliot-kelly → sem fighter_info_plug
#  • maurição-da-hunter → sem fighter_info_plug
# ✅ 56591 lutas salvas em 'historico_lutas.csv'.

# %%
df_fights = pd.read_csv('historico_lutas.csv')
df_fights.head()
# Out:
#         fighter  fight_id                    opponent result           method  \
# 0  adam-ferrara     14013        Joao MiyaoJoao Miyao      L              RNC
# 1  adam-ferrara     14639    Silvio DuranSilvio Duran      L         Pts: 4x2
# 2  adam-ferrara     15153  Thiago MacedoThiago Macedo      L  Choke from back
# 3  adam-ferrara     15592                  Rene Lopez      L              Adv
# 4  adam-ferrara     16401  Thiago MacedoThiago Macedo      L    Pts: 2x2, Adv
#
#         competition weight stage  year
# 0     No Gi Pan Am.   61KG    SF  2017
# 1   Cincinnati Open   70KG    SF  2017
# 2      Houston Open   70KG     F  2018
# 3  Chicago Sp. Open   64KG    SF  2018
# 4         Miami SPO   70KG    SF  2018

# %% [markdown]
# **LIMPEZA DE DADOS**

# %%
print(df_fights.isnull().sum())
# Out:
# fighter           0
# fight_id          0
# opponent        154
# result            0
# method         1386
# competition      20
# weight          674
# stage           334
# year              0
# dtype: int64

# %%
# Analisando todos os valores unicos que apareecm em OPPONENT

if df_fights is not None:
  fighters = df_fights['fighter'].unique()
  opponents = df_fights['opponent'].unique()

  # Acha opponents que nao estão presente em fighters
  missing_fighters = set(opponents) - set(fighters)

  # Conta a ocorrencia dos lutadores que mais aparecem na coluna Oponnent mas que nao estão  em Figters
  opponent_counts = df_fights['opponent'].value_counts()
  missing_fighters_counts = opponent_counts[opponent_counts.index.isin(missing_fighters)]

print("Top 20 oponentes que não estão presentes na coluna 'fighter':")
print(missing_fighters_counts.head(100))
# Out:
# Top 20 oponentes que não estão presentes na coluna 'fighter':
# opponent
# Unknown                           399
# Leandro LoLeandro Lo              208
# Fellipe AndrewFellipe Andrew      207
# Gianni GrippoGianni Grippo        183
# Adam WardzinskiAdam Wardzinski    175
#                                  ...
# Fellipe TrovoFellipe Trovo         73
# Augusto MendesAugusto Mendes       73
# Pedro MarinhoPedro Marinho         73
# Tainan DalpraTainan Dalpra         72
# Lucas PinheiroLucas Pinheiro       71
# Name: count, Length: 100, dtype: int64

# %%
#Dropando as colunas 'method' e 'stage' pois sao inuteis na analise, também dropando as linhas onde o oponente é "Unknown" pois nao é possivel calcular.

df_fights = (
    df_fights
    .drop(columns=['method', 'stage'])
    .dropna(subset=['opponent'])
)
df_fights = df_fights[df_fights['opponent'] != 'Unknown']

# Preenchendo valores ausentes nas colunas 'competition' e 'weight' com "Unknown"
df_fights['competition'].fillna('Unknown', inplace=True)
df_fights['weight'].fillna('Unknown', inplace=True)

df_fights
# Out:
# <ipython-input-7-d26d5c922ecc>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fights['competition'].fillna('Unknown', inplace=True)
# <ipython-input-7-d26d5c922ecc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fights['competition'].fillna('Unknown', inplace=True)
# <ipython-input-7-d26d5c922ecc>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fights['weight'].fillna('Unknown', inplace=True)
# <ipython-input-7-d26d5c922ecc>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fights['weight'].fillna('Unknown', inplace=True)
#                fighter  fight_id                    opponent result  \
# 0         adam-ferrara     14013        Joao MiyaoJoao Miyao      L
# 1         adam-ferrara     14639    Silvio DuranSilvio Duran      L
# 2         adam-ferrara     15153  Thiago MacedoThiago Macedo      L
# 3         adam-ferrara     15592                  Rene Lopez      L
# 4         adam-ferrara     16401  Thiago MacedoThiago Macedo      L
# ...                ...       ...                         ...    ...
# 56586  vinicius-garcia     22023                 Cody Heller      W
# 56587  vinicius-garcia     23372              Daniel Olivier      W
# 56588  vinicius-garcia     23380              Joshua Murdock      W
# 56589  vinicius-garcia     24048               Kyle Raemisch      W
# 56590  vinicius-garcia     24245                Kevin Vieira      W
#
#             competition weight  year
# 0         No Gi Pan Am.   61KG  2017
# 1       Cincinnati Open   70KG  2017
# 2          Houston Open   70KG  2018
# 3      Chicago Sp. Open   64KG  2018
# 4             Miami SPO   70KG  2018
# ...                 ...    ...   ...
# 56586   Atlanta SM Open    ABS  2019
# 56587  New Orleans Open   88KG  2020
# 56588  New Orleans Open    ABS  2020
# 56589           F2W 153   85KG  2020
# 56590      Pan American   82KG  2020
#
# [56038 rows x 7 columns]

# %% [markdown]
# **Fazendo padronização dos nomes em 'Opponent' como hifen, selecionar apenas ap rimeira metade do nome, deixar em minculo.**

# %%
def normalize_text(s):
    if pd.isna(s):
        return s
    # Remove acentos
    s = unicodedata.normalize('NFKD', s)
    s = s.encode('ascii', 'ignore').decode('utf-8')
    # Converte para minúsculas
    return s.lower().strip()

# Aplica a normalização em df_unico
df_fights['fighter']  = df_fights['fighter'].apply(normalize_text)
df_fights['opponent'] = df_fights['opponent'].apply(normalize_text)

df_fights['fighter'] = (
    df_fights['fighter']
    .str.replace(r'\s+', '-', regex=True)
    .str.strip('-')
)

df_fights['opponent'] = (
    df_fights['opponent']
    .str.replace(r'\s+', '-', regex=True)
    .str.strip('-')
)

def corrigir_nome(nome):
    meio = len(nome) // 2
    if nome[:meio] == nome[meio:]:
        return nome[:meio]
    return nome

df_fights['opponent'] = df_fights['opponent'].apply(corrigir_nome)


df_fights
# Out:
#                fighter  fight_id        opponent result       competition  \
# 0         adam-ferrara     14013      joao-miyao      L     No Gi Pan Am.
# 1         adam-ferrara     14639    silvio-duran      L   Cincinnati Open
# 2         adam-ferrara     15153   thiago-macedo      L      Houston Open
# 3         adam-ferrara     15592      rene-lopez      L  Chicago Sp. Open
# 4         adam-ferrara     16401   thiago-macedo      L         Miami SPO
# ...                ...       ...             ...    ...               ...
# 56586  vinicius-garcia     22023     cody-heller      W   Atlanta SM Open
# 56587  vinicius-garcia     23372  daniel-olivier      W  New Orleans Open
# 56588  vinicius-garcia     23380  joshua-murdock      W  New Orleans Open
# 56589  vinicius-garcia     24048   kyle-raemisch      W           F2W 153
# 56590  vinicius-garcia     24245    kevin-vieira      W      Pan American
#
#       weight  year
# 0       61KG  2017
# 1       70KG  2017
# 2       70KG  2018
# 3       64KG  2018
# 4       70KG  2018
# ...      ...   ...
# 56586    ABS  2019
# 56587   88KG  2020
# 56588    ABS  2020
# 56589   85KG  2020
# 56590   82KG  2020
#
# [56038 rows x 7 columns]

# %%
# 1) Dicionário manual mapeando opponent → fighter correto
manual_map = {
    'lucas-barbosa':    'lucas-hulk-barbosa',
    'roberto-abreu':    'roberto-cyborg-abreu',
    'felipe-pena':      'felipe-pena-preguica',
    'r.-evangelista':   'ricardo-evangelista',
    'osvaldo-moizinho': 'osvaldo-queixinho-moizinho',
    'rafael-lovato':    'rafael-lovato-jr',
    'helton-jose':      'helton-jose-junior',
    'marcus-almeida':   'marcus-buchecha-almeida',
    'diego-oliveira':   'diego-pato-oliveira',
    'joao-rocha':       'joao-gabriel-rocha',
    'michael-liera':    'michael-liera-jr',
    'c.-negromonte':    'charles-negromonte',
    'leo-saggioro':     'leonardo-saggioro',
    'vitor-oliveira':   'vitor-henrique-oliveira',
    'augusto-mendes':   'augusto-mendes-tanquinho',
    'mica-galvao':      'micael-galvao',
    'rubens-charles':   'rubens-charles-cobrinha',
    'alexandre-jesus':  'alexandre-de-jesus',
    'wellington-luis':  'wellington-alemao-luis',
    'thiago-sa':        'thiago-sa-fortes',
    'henrique-cardoso': 'henrique-cardoso-ceconi',
    'pedro-alex':       'pedro-alex-bombom',
    'israel-sousa':     'israel-sousa-almeida',
    'lucas-valle':      'lucas-valente',
    'diogo-sampaio':    'diogo-sampaio-moreno',
    'celso-vinicius':   'celso-celsinho-venicius',
    'bruno-matias':     'jose-bruno-matias',
    'gilbert-burns':    'gilbert-burns-durinho',
    'levi-jones':       'levi-jones-leary',
    'yan-lucas':               'yan-pica-pau-lucas',
    'leo-nogueira':            'leonardo-nogueira',
    'marcos-martins':          'marcos-petcho-martins',
    'gabriel-costa':           'gabriel-costa-maranhao',
    'gabriel-henrique':        'gabriel-henrique-oliveira',
    'braga-neto':              'antonio-braga-neto',
    'rodrigo-tatu':            'rodrigo-lopes-tatu',
    'ademir-barreto':          'ademir-barreto-araujo',
    'rafael-anjos':            'rafael-dos-anjos-torres',
    'mikey-musumeci':          'michael-musumeci',
    'valdir-araujo':           'valdir-araujo-bb-monstro',
    'leo-silva':               'leonardo-silva',
    'rodrigo-fajardo':         'rodrigo-francioni',
    'ruan-oliveira':           'ruan-de-oliveira',
    'mauricio-oliveira':       'mauricio-oliveira-neto',
    'yago-souza':              'yago-de-souza',
    'alan-finfou':             'alan-nascimento-finfou',
    'eldar-rafigaev':          'eldar-yakuza-rafigaev',
    'orlando-castillo':        'orlando-sanchez',
    'leandro-lima':            'leandro-rounaud-lima',
    'catriel-oliveira':        'catriel-oliveira-rodrigues',
    'gabriel-oliveira':        'gabriel-de-oliveira',
    'g.-lambertucci':          'guilherme-lambertucci',
    'claudio-mattos':          'claudio-mattos-caloquinha',
    'inacio-santos':           'inacio-dos-santos',
    'bill-cooper':             'bill-the-grill-cooper',
    'luis-oliveira':           'luis-oliveira-cantareira',
    'faisal-alkitbe':          'faisal-al-kitbe',
    'marcio-cruz':             'marcio-cruz-pe-de-pano',
    'marcos-costa':            'marcos-paulo-costa'
}

# Verificação anterior ao replace: quantas ocorrências cada chave tinha
counts_before = df_fights['opponent'].value_counts()
print("Ocorrências antes da substituição:")
print(counts_before.reindex(manual_map.keys(), fill_value=0))

# Aplica apenas essas substituições em opponent
df_fights['opponent'] = df_fights['opponent'].replace(manual_map)

# Converte para categoria (recomendado)
df_fights['opponent'] = df_fights['opponent'].astype('category')

# Verificação após o replace
print("\nTotal de fighters únicos em 'opponent' após mapeamento:", df_fights['opponent'].nunique())

# Confira que as chaves foram realmente substituídas, mostrando zeros
counts_after = df_fights['opponent'].value_counts()
print("\nOcorrências após a substituição (esperado zeros nas chaves):")
print(counts_after.reindex(manual_map.keys(), fill_value=0))
# Out:
# Ocorrências antes da substituição:
# opponent
# lucas-barbosa        163
# roberto-abreu        130
# felipe-pena          126
# r.-evangelista       115
# osvaldo-moizinho     110
# rafael-lovato        106
# helton-jose          102
# marcus-almeida       102
# diego-oliveira       102
# joao-rocha            99
# michael-liera         89
# c.-negromonte         86
# leo-saggioro          80
# vitor-oliveira        78
# augusto-mendes        73
# mica-galvao           71
# rubens-charles        68
# alexandre-jesus       71
# wellington-luis       69
# thiago-sa             66
# henrique-cardoso      66
# pedro-alex            65
# israel-sousa          64
# lucas-valle           61
# diogo-sampaio         53
# celso-vinicius        52
# bruno-matias          47
# gilbert-burns         47
# levi-jones            47
# yan-lucas            103
# leo-nogueira          50
# marcos-martins        51
# gabriel-costa         49
# gabriel-henrique      44
# braga-neto            43
# rodrigo-tatu          41
# ademir-barreto        40
# rafael-anjos          39
# mikey-musumeci        37
# valdir-araujo         37
# leo-silva             37
# rodrigo-fajardo       36
# ruan-oliveira         36
# mauricio-oliveira     37
# yago-souza            33
# alan-finfou           33
# eldar-rafigaev        32
# orlando-castillo      32
# leandro-lima          32
# catriel-oliveira      32
# gabriel-oliveira      33
# g.-lambertucci        31
# claudio-mattos        31
# inacio-santos         33
# bill-cooper           30
# luis-oliveira         39
# faisal-alkitbe        30
# marcio-cruz           29
# marcos-costa          28
# Name: count, dtype: int64
#
# Total de fighters únicos em 'opponent' após mapeamento: 11916
#
# Ocorrências após a substituição (esperado zeros nas chaves):
# opponent
# lucas-barbosa        0
# roberto-abreu        0
# felipe-pena          0
# r.-evangelista       0
# osvaldo-moizinho     0
# rafael-lovato        0
# helton-jose          0
# marcus-almeida       0
# diego-oliveira       0
# joao-rocha           0
# michael-liera        0
# c.-negromonte        0
# leo-saggioro         0
# vitor-oliveira       0
# augusto-mendes       0
# mica-galvao          0
# rubens-charles       0
# alexandre-jesus      0
# wellington-luis      0
# thiago-sa            0
# henrique-cardoso     0
# pedro-alex           0
# israel-sousa         0
# lucas-valle          0
# diogo-sampaio        0
# celso-vinicius       0
# bruno-matias         0
# gilbert-burns        0
# levi-jones           0
# yan-lucas            0
# leo-nogueira         0
# marcos-martins       0
# gabriel-costa        0
# gabriel-henrique     0
# braga-neto           0
# rodrigo-tatu         0
# ademir-barreto       0
# rafael-anjos         0
# mikey-musumeci       0
# valdir-araujo        0
# leo-silva            0
# rodrigo-fajardo      0
# ruan-oliveira        0
# mauricio-oliveira    0
# yago-souza           0
# alan-finfou          0
# eldar-rafigaev       0
# orlando-castillo     0
# leandro-lima         0
# catriel-oliveira     0
# gabriel-oliveira     0
# g.-lambertucci       0
# claudio-mattos       0
# inacio-santos        0
# bill-cooper          0
# luis-oliveira        0
# faisal-alkitbe       0
# marcio-cruz          0
# marcos-costa         0
# Name: count, dtype: int64

# %% [markdown]
# Limpeza usando fuzzymatch para os que sobraram. usando 85% de trheshold

# %%
#  Garante que as colunas sejam do tipo string
df_fights['opponent'] = df_fights['opponent'].astype(str)
df_fights['fighter'] = df_fights['fighter'].astype(str)

#  Nomes únicos da coluna opponent (removendo nulos novamente apenas pq sim :) )
opponent_names = df_fights['opponent'].dropna().unique().tolist()
threshold = 85
matches = {}

#  Mapa com nomes corretos (quando opponent == fighter)
opponent_fighter_map = (
    df_fights[df_fights['opponent'] == df_fights['fighter']]
    [['opponent', 'fighter']]
    .drop_duplicates()
    .set_index('opponent')['fighter']
    .to_dict()
)

#  Encontra variações ortográficas
for name in opponent_names:
    initial = name.split('-', 1)[0][0]  # primeira letra do primeiro nome
    raw_matches = process.extract(name, opponent_names, scorer=fuzz.token_sort_ratio, limit=10)

    similares = [
        (match, score)
        for match, score, _ in raw_matches
        if score >= threshold
        and match != name
        and match.split('-', 1)[0][0] == initial
    ]

    if similares:
        matches[name] = similares

#. Gera sugestões baseadas na coluna 'fighter'
correcoes_sugeridas = {}

for nome_errado, similares in matches.items():
    candidatos_validos = [s for s, _ in similares if s in opponent_fighter_map]

    if candidatos_validos:
        nome_correto = opponent_fighter_map[candidatos_validos[0]]
        correcoes_sugeridas[nome_errado] = nome_correto
    else:
        correcoes_sugeridas[nome_errado] = similares[0][0]

df_fights['opponent'] = df_fights['opponent'].replace(correcoes_sugeridas)

cats = df_fights['opponent'].dropna().unique().tolist()
threshold = 85

matches = {}
for cat in cats:
    # inicial do primeiro nome de cat
    cat_initial = cat.split('-', 1)[0][0]

    # busca candidatos
    raw = process.extract(cat, cats, scorer=fuzz.token_sort_ratio, limit=5)

    # só mantém score>=threshold, nomes diferentes, e mesma inicial
    filtered = [
        (match, score)
        for match, score, _ in raw
        if score >= threshold
           and match != cat
           and match.split('-', 1)[0][0] == cat_initial
    ]
    if filtered:
        matches[cat] = filtered

#Monte o mapping variant → canonical
mapping = {}
for canonical, variants in matches.items():
    for variant, score in variants:
        mapping[variant] = canonical


# Aplique as substituições na coluna opponent
df_fights['opponent'] = df_fights['opponent'].replace(mapping)

# %%
df_fights = df_fights.sort_values('fight_id', ascending=True)
df_fights
# Out:
#                    fighter  fight_id            opponent result   competition  \
# 19292  master-helio-gracie         2    antonio-portugal      W       Unknown
# 19293  master-helio-gracie         3      takashi-namiki      D       Unknown
# 19294  master-helio-gracie         4          fred-ebert      D       Unknown
# 19295  master-helio-gracie         5      wladek-zbyszko      D       Unknown
# 19296  master-helio-gracie         6              miyake      W       Unknown
# ...                    ...       ...                 ...    ...           ...
# 55619      tayane-porfirio     59922    michelle-dunchus      W  World Champ.
# 17107    gabrieli-pessanha     59924  bridgett-brumbaugh      W  World Champ.
# 55620      tayane-porfirio     59925       maria-barboza      W  World Champ.
# 17108    gabrieli-pessanha     59926     tayane-porfirio      W  World Champ.
# 55579      tayane-porfirio     59926   gabrieli-pessanha      L  World Champ.
#
#       weight  year
# 19292    ABS  1932
# 19293    ABS  1932
# 19294    ABS  1932
# 19295    ABS  1934
# 19296    ABS  1934
# ...      ...   ...
# 55619  O79KG  2025
# 17107  O79KG  2025
# 55620  O79KG  2025
# 17108  O79KG  2025
# 55579  O79KG  2025
#
# [56038 rows x 7 columns]

# %%
# Criando uma nova coluna 'id_fight' com um identificador numérico sequencial para cada luta,
# começando em 1 até o número total de linhas no DataFrame.
df_fights['id_fight'] = range(1, len(df_fights) + 1)

# Removendo a coluna original 'fight_id', pois será substituída pela nova 'id_fight'.
df_fights = df_fights.drop(columns=['fight_id'])

# Exibindo o DataFrame atualizado com a nova coluna de identificação.
df_fights
# Out:
#                    fighter            opponent result   competition weight  \
# 19292  master-helio-gracie    antonio-portugal      W       Unknown    ABS
# 19293  master-helio-gracie      takashi-namiki      D       Unknown    ABS
# 19294  master-helio-gracie          fred-ebert      D       Unknown    ABS
# 19295  master-helio-gracie      wladek-zbyszko      D       Unknown    ABS
# 19296  master-helio-gracie              miyake      W       Unknown    ABS
# ...                    ...                 ...    ...           ...    ...
# 55619      tayane-porfirio    michelle-dunchus      W  World Champ.  O79KG
# 17107    gabrieli-pessanha  bridgett-brumbaugh      W  World Champ.  O79KG
# 55620      tayane-porfirio       maria-barboza      W  World Champ.  O79KG
# 17108    gabrieli-pessanha     tayane-porfirio      W  World Champ.  O79KG
# 55579      tayane-porfirio   gabrieli-pessanha      L  World Champ.  O79KG
#
#        year  id_fight
# 19292  1932         1
# 19293  1932         2
# 19294  1932         3
# 19295  1934         4
# 19296  1934         5
# ...     ...       ...
# 55619  2025     56034
# 17107  2025     56035
# 55620  2025     56036
# 17108  2025     56037
# 55579  2025     56038
#
# [56038 rows x 7 columns]

# %% [markdown]
# **Padronizando a coluna PESOS**

# %%
#  Calcule value_counts e nomeie a Series
weight_counts = df_fights['weight'].value_counts()
weight_counts.name = 'count'
weight_counts.index.name = 'weight_category'

#  Converta em DataFrame
weight_counts_df = weight_counts.reset_index()



cats = df_fights['weight'].dropna().unique().tolist()
threshold = 85

matches = {
    cat: [
        (match, score)
        for match, score, _ in process.extract(cat, cats, scorer=fuzz.token_sort_ratio, limit=5)
        if score >= threshold and match != cat
    ]
    for cat in cats
}

# Exiba só as categorias que têm correspondentes semelhantes
similar = {k: v for k, v in matches.items() if v}
print("Possíveis variações ortográficas em weight:")
for cat, vars in similar.items():
    print(f"{cat!r}: {vars}")

def normalize_weight(w):
    w = str(w).upper().strip()
    # tenta extrair dígitos (p.ex. 62, 100, 88)
    m = re.search(r'(\d+)', w)
    if m:
        return f"{m.group(1)}KG"
    # caso não seja um peso numérico, mantém (ex.: ABS, UNKNOWN)
    return w

# aplica ao seu df_unico
df_fights['weight'] = df_fights['weight'].apply(normalize_weight)

# converte para categoria (opcional, mas economiza memória)
df_fights['weight'] = df_fights['weight'].astype('category')

# confira as novas categorias e frequências
print(df_fights['weight'].value_counts())
# Out:
# Possíveis variações ortográficas em weight:
# '82KG': [('O82KG', 88.88888888888889)]
# '76KG': [('O76KG', 88.88888888888889)]
# '70KG': [('O70KG', 88.88888888888889)]
# '100KG': [('O100KG', 90.9090909090909), ('100KG+', 90.9090909090909)]
# '88KG': [('O88KG', 88.88888888888889), ('88K', 85.71428571428572), ('88G', 85.71428571428572)]
# 'O88KG': [('88KG', 88.88888888888889)]
# '77KG': [('U77KG', 88.88888888888889), ('O77KG', 88.88888888888889)]
# '99KG': [('O99KG', 88.88888888888889)]
# 'O99KG': [('99KG', 88.88888888888889)]
# '94KG': [('O94KG', 88.88888888888889)]
# 'O100KG': [('100KG', 90.9090909090909)]
# '74KG': [('O74KG', 88.88888888888889)]
# '75KG': [('O75KG', 88.88888888888889)]
# 'O91KG': [('91KG', 88.88888888888889)]
# '98KG': [('O98KG', 88.88888888888889)]
# '108KG': [('O108KG', 90.9090909090909)]
# 'O108KG': [('108KG', 90.9090909090909)]
# 'O75KG': [('75KG', 88.88888888888889)]
# '72KG': [('O72KG', 88.88888888888889)]
# '81KG': [('O81KG', 88.88888888888889)]
# '91KG': [('O91KG', 88.88888888888889)]
# '63KG': [('O63KG', 88.88888888888889)]
# '79KG': [('O79KG', 88.88888888888889)]
# 'O79KG': [('79KG', 88.88888888888889)]
# '65KG': [('O65KG', 88.88888888888889)]
# '83KG': [('O83KG', 88.88888888888889)]
# '92KG': [('O92KG', 88.88888888888889)]
# 'O92KG': [('92KG', 88.88888888888889)]
# 'O63KG': [('63KG', 88.88888888888889)]
# 'O72KG': [('72KG', 88.88888888888889)]
# 'O60KG': [('60KG', 88.88888888888889)]
# '85KG': [('O85KG', 88.88888888888889)]
# 'O94KG': [('94KG', 88.88888888888889)]
# '100KG+': [('100KG', 90.9090909090909)]
# 'O85KG': [('85KG', 88.88888888888889)]
# '95KG': [('O95KG', 88.88888888888889)]
# 'O95KG': [('95KG', 88.88888888888889)]
# 'O74KG': [('74KG', 88.88888888888889)]
# '97KG': [('O97KG', 88.88888888888889)]
# '62KG': [('62 KG', 88.88888888888889)]
# '60KG': [('O60KG', 88.88888888888889)]
# 'U77KG': [('77KG', 88.88888888888889)]
# 'O77KG': [('77KG', 88.88888888888889)]
# 'O76KG': [('76KG', 88.88888888888889)]
# 'O70KG': [('70KG', 88.88888888888889)]
# '110KG': [('U110KG', 90.9090909090909)]
# 'O97KG': [('97KG', 88.88888888888889)]
# '93KG': [('O93KG', 88.88888888888889)]
# '80KG': [('O80KG', 88.88888888888889)]
# 'U110KG': [('110KG', 90.9090909090909)]
# '62 KG': [('62KG', 88.88888888888889)]
# 'O82KG': [('82KG', 88.88888888888889)]
# 'O98KG': [('98KG', 88.88888888888889)]
# 'O93KG': [('93KG', 88.88888888888889)]
# 'O81KG': [('81KG', 88.88888888888889)]
# '88K': [('88KG', 85.71428571428572)]
# 'O83KG': [('83KG', 88.88888888888889)]
# 'O80KG': [('80KG', 88.88888888888889)]
# 'O65KG': [('65KG', 88.88888888888889)]
# '88G': [('88KG', 85.71428571428572)]
# weight
# ABS      11833
# 70KG      3908
# 76KG      3822
# 82KG      3716
# 88KG      3618
#          ...
# 54KG         2
# 125KG        1
# //KG         1
# 4KG          1
# SF           1
# Name: count, Length: 80, dtype: int64

# %%
standard_kg = [48, 52, 57, 58, 63, 64, 69, 70, 76, 82, 88, 94, 98, 100]

def standardize_weight(w):
    w_str = str(w).upper().strip()
    # Preserve ABS e UNKNOWN como estão
    if w_str in ("ABS", "UNKNOWN"):
        return w_str
    # Tenta extrair o número
    m = re.search(r"(\d+)", w_str)
    if not m:
        # Se não for numérico, vira UNKNOWN
        return "UNKNOWN"
    num = int(m.group(1))
    # Qualquer peso >= 100 vira 100KG (ultra-pesado sem limite)
    if num >= 100:
        return "100KG"
    # Encontre o padrão mais próximo para pesos < 100
    diffs = [(abs(num - std), std) for std in standard_kg if std < 100]
    _, best_std = min(diffs, key=lambda x: x[0])
    return f"{best_std}KG"

# Aplique a padronização
df_fights["weight"] = df_fights["weight"].apply(standardize_weight).astype("category")

# Veja as contagens finais
print(df_fights["weight"].value_counts())
# Out:
# weight
# ABS        11833
# 76KG        8696
# 82KG        6876
# 70KG        4846
# 88KG        4320
# 94KG        4226
# 100KG       4081
# 64KG        2896
# 69KG        2082
# 98KG        1451
# 63KG        1359
# 57KG        1162
# UNKNOWN      764
# 58KG         676
# 48KG         490
# 52KG         280
# Name: count, dtype: int64

# %%
df_fights.to_csv('df_fights_final.csv', index=False)

# %%
df_fights = pd.read_csv('df_fights_final.csv')
df_fights
# Out:
#                    fighter            opponent result   competition weight  \
# 0      master-helio-gracie    antonio-portugal      W       Unknown    ABS
# 1      master-helio-gracie      takashi-namiki      D       Unknown    ABS
# 2      master-helio-gracie          fred-ebert      D       Unknown    ABS
# 3      master-helio-gracie      wladek-zbyszko      D       Unknown    ABS
# 4      master-helio-gracie              miyake      W       Unknown    ABS
# ...                    ...                 ...    ...           ...    ...
# 56033      tayane-porfirio    michelle-dunchus      W  World Champ.   76KG
# 56034    gabrieli-pessanha  bridgett-brumbaugh      W  World Champ.   76KG
# 56035      tayane-porfirio       maria-barboza      W  World Champ.   76KG
# 56036    gabrieli-pessanha     tayane-porfirio      W  World Champ.   76KG
# 56037      tayane-porfirio   gabrieli-pessanha      L  World Champ.   76KG
#
#        year  id_fight
# 0      1932         1
# 1      1932         2
# 2      1932         3
# 3      1934         4
# 4      1934         5
# ...     ...       ...
# 56033  2025     56034
# 56034  2025     56035
# 56035  2025     56036
# 56036  2025     56037
# 56037  2025     56038
#
# [56038 rows x 7 columns]

# %% [markdown]
# ## Preparando o DATASET para o Elo Rating
#
# Antes de iniciar o cálculo do ELO Rating para cada atleta, foi necessário preparar o DataFrame com alguns passos fundamentais para garantir a ordem correta dos combates e a correta atribuição das pontuações iniciais. A seguir, detalho cada etapa:
#
# **Inicialização das pontuações ELO**
# Todas as lutas foram iniciadas com a pontuação padrão de 1500 pontos tanto para o lutador (“fighter”) quanto para seu oponente (“opponent”). Isso garante que todos partam de uma base neutra, similar ao padrão adotado em outros esportes e no xadrez, permitindo uma evolução justa dos ratings ao longo das lutas.
#
# **Conversão e tratamento da coluna de ID das lutas**
# A coluna id_fight, responsável por identificar de forma única cada combate, foi convertida para o formato numérico. Esse passo é importante para garantir que a ordenação cronológica das lutas seja feita corretamente, já que valores não numéricos ou inconsistentes poderiam prejudicar a análise.
# Caso algum valor problemático fosse encontrado durante a conversão, as linhas seriam destacadas para inspeção e correção manual.
#
# **Ordenação dos dados por combate**
# Com a coluna de IDs convertida, as lutas foram ordenadas de forma crescente por id_fight. Dessa forma, garantiu-se que os cálculos de ELO considerassem a real sequência dos combates ao longo do tempo, simulando a progressão da carreira de cada atleta.
#
# **Criação do dicionário de pontuações ELO iniciais**
# Para cada lutador e oponente presente na base de dados, foi criado um dicionário que associa seus nomes à pontuação inicial de 1500 pontos. Isso possibilita atualizar e consultar rapidamente o ELO atual de qualquer atleta durante o processamento das lutas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Inicializar as pontuações Elo
df_fights['fighter_elo'] = 1500
df_fights['opponent_elo'] = 1500

# Converter 'id_fight' para numérico e tratar erros
try:
    df_fights['id_fight'] = pd.to_numeric(df_fights['id_fight'], errors='coerce')
except Exception as e:
    print(f"Ocorreu um erro durante a conversão de 'id_fight': {e}")
    # Investigar e corrigir os valores problemáticos em 'id_fight'
    problematic_rows = df_fights[df_fights['id_fight'].isnull()]
    if not problematic_rows.empty:
        print("Linhas problemáticas:")
        display(problematic_rows)

# Ordenar por 'id_fight'
df_fights = df_fights.sort_values('id_fight')

# Criar o dicionário de pontuações Elo
elo_ratings = {}
for fighter in df_fights['fighter'].unique():
    elo_ratings[fighter] = 1500
for opponent in df_fights['opponent'].unique():
    if opponent not in elo_ratings:
        elo_ratings[opponent] = 1500

# Exibir as primeiras linhas do DataFrame modificado para verificar as alterações
display(df_fights.head())
# Out:
#                fighter          opponent result competition weight  year  \
# 0  master-helio-gracie  antonio-portugal      W     Unknown    ABS  1932
# 1  master-helio-gracie    takashi-namiki      D     Unknown    ABS  1932
# 2  master-helio-gracie        fred-ebert      D     Unknown    ABS  1932
# 3  master-helio-gracie    wladek-zbyszko      D     Unknown    ABS  1934
# 4  master-helio-gracie            miyake      W     Unknown    ABS  1934
#
#    id_fight  fighter_elo  opponent_elo
# 0         1         1500          1500
# 1         2         1500          1500
# 2         3         1500          1500
# 3         4         1500          1500
# 4         5         1500          1500

# %% [markdown]
# ## Iterando as lutas e calculando

# %%
import math

# Iterar pelas lutas e atualizar as pontuações Elo
k_factor = 40
for index, fight in df_fights.iterrows():
    fighter = fight['fighter']
    opponent = fight['opponent']

    fighter_elo = elo_ratings[fighter]
    opponent_elo = elo_ratings[opponent]

    expected_fighter = 1 / (1 + 10**((opponent_elo - fighter_elo) / 400))
    expected_opponent = 1 / (1 + 10**((fighter_elo - opponent_elo) / 400))

    if fight['result'] == 'W':
        actual_fighter = 1
        actual_opponent = 0
    elif fight['result'] == 'L':
        actual_fighter = 0
        actual_opponent = 1
    else:  # Empate ou outro resultado
        actual_fighter = 0.5
        actual_opponent = 0.5

    new_fighter_elo = round(fighter_elo + k_factor * (actual_fighter - expected_fighter))
    new_opponent_elo = round(opponent_elo + k_factor * (actual_opponent - expected_opponent))

    elo_ratings[fighter] = new_fighter_elo
    elo_ratings[opponent] = new_opponent_elo

    df_fights.loc[index, 'fighter_elo_post'] = new_fighter_elo
    df_fights.loc[index, 'opponent_elo_post'] = new_opponent_elo

display(df_fights.head())
# Out:
#                fighter          opponent result competition weight  year  \
# 0  master-helio-gracie  antonio-portugal      W     Unknown    ABS  1932
# 1  master-helio-gracie    takashi-namiki      D     Unknown    ABS  1932
# 2  master-helio-gracie        fred-ebert      D     Unknown    ABS  1932
# 3  master-helio-gracie    wladek-zbyszko      D     Unknown    ABS  1934
# 4  master-helio-gracie            miyake      W     Unknown    ABS  1934
#
#    id_fight  fighter_elo  opponent_elo  fighter_elo_post  opponent_elo_post
# 0         1         1500          1500            1520.0             1480.0
# 1         2         1500          1500            1519.0             1501.0
# 2         3         1500          1500            1518.0             1501.0
# 3         4         1500          1500            1517.0             1501.0
# 4         5         1500          1500            1536.0             1481.0

# %% [markdown]
# ## Visualizando Dados

# %%
# Extrair as pontuações Elo finais
final_elo_ratings = {fighter: elo for fighter, elo in elo_ratings.items()}

# Criar um DataFrame com as pontuações finais
final_elo_df = pd.DataFrame(list(final_elo_ratings.items()), columns=['Lutador', 'Elo Final'])

# Ordenar o DataFrame pela pontuação Elo de forma decrescente
final_elo_df_sorted = final_elo_df.sort_values(by='Elo Final', ascending=False)

# Visualizar a distribuição das pontuações Elo finais com histograma + curva de densidade
plt.figure(figsize=(12, 6))
sns.histplot(final_elo_df['Elo Final'], bins=50, kde=True, color='skyblue', edgecolor='black')
plt.xlabel('Pontuação Elo Final')
plt.ylabel('Número de Lutadores')
plt.title('Distribuição das Pontuações Elo Finais')
plt.grid(True)
plt.tight_layout()
plt.show()

# Exibir o top 10 lutadores
display(final_elo_df_sorted.head(10))

# Informações estatísticas básicas
media = final_elo_df['Elo Final'].mean()
desvio = final_elo_df['Elo Final'].std()
print(f"Média da pontuação Elo: {media:.2f}")
print(f"Desvio padrão: {desvio:.2f}")

# Analisar a simetria da distribuição
print("\nAnálise da Distribuição Elo:")
skew = final_elo_df['Elo Final'].skew()
if skew > 0.5:
    print("A distribuição é assimétrica à direita (positivamente inclinada).")
elif skew < -0.5:
    print("A distribuição é assimétrica à esquerda (negativamente inclinada).")
else:
    print("A distribuição é aproximadamente simétrica.")
# Out:
#                      Lutador  Elo Final
# 248              gordon-ryan       2483
# 292        nicholas-meregali       2445
# 501              erich-munis       2419
# 528            tainan-dalpra       2399
# 599             jansen-gomes       2389
# 440        gabrieli-pessanha       2335
# 549            micael-galvao       2334
# 119  marcus-buchecha-almeida       2298
# 283          adam-wardzinski       2295
# 420              victor-hugo       2279
# Média da pontuação Elo: 1500.00
# Desvio padrão: 80.65
#
# Análise da Distribuição Elo:
# A distribuição é assimétrica à direita (positivamente inclinada).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from adjustText import adjust_text
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import matplotlib.gridspec as gridspec

# === 1. Preparar os dados ===
top_fighters = final_elo_df_sorted.head(10)['Lutador'].tolist()
dados_tabela = []
dados_linhas = {}

for fighter in top_fighters:
    df = df_fights[(df_fights['fighter'] == fighter) | (df_fights['opponent'] == fighter)].copy()
    df = df.sort_values(by=['year', 'id_fight'])

    df['elo'] = df.apply(
        lambda row: row['fighter_elo_post'] if row['fighter'] == fighter else row['opponent_elo_post'],
        axis=1
    )

    peak_elo = df['elo'].max()
    elo_2025 = df[df['year'] == 2025].sort_values(by='id_fight')['elo'].iloc[-1] if not df[df['year'] == 2025].empty else None

    if elo_2025 is not None and isinstance(elo_2025, (int, float)):
        if elo_2025 == peak_elo:
            var_label = "Peak"
            var_color = "#FFD700"
        else:
            var_pct = ((elo_2025 - peak_elo) / peak_elo) * 100
            var_label = f"{var_pct:.1f}%"
            var_color = "#1a9850" if var_pct > 0 else "#d73027"
    else:
        var_label = "N/A"
        var_color = "#f0f0f0"

    dados_tabela.append({
        'Lutador': fighter,
        'Peak Elo': peak_elo,
        'Elo em 2025': elo_2025 if elo_2025 is not None else 'N/A',
        'Variação': var_label,
        'Cor': var_color
    })

    max_por_ano = df.groupby('year')['elo'].max().reset_index()
    dados_linhas[fighter] = max_por_ano

# Converte para DataFrame ordenado por Peak Elo
tabela_info = pd.DataFrame(dados_tabela).sort_values(by='Peak Elo', ascending=False)

# === 2. Layout com gráfico e tabela ===
fig = plt.figure(figsize=(22, 9))
gs = gridspec.GridSpec(1, 2, width_ratios=[3, 1])
ax0 = plt.subplot(gs[0])

# Paleta de cores
cmap = plt.get_cmap('viridis', len(top_fighters))
colors = [mcolors.to_hex(cmap(i)) for i in range(len(top_fighters))]

# === 3. Gráfico suavizado com texto nas bolinhas ===
min_ano, max_ano = float('inf'), float('-inf')
label_positions = {}
for i, fighter in enumerate(top_fighters):
    data = dados_linhas[fighter]
    x = data['year'].values.astype(float)
    y = data['elo'].values
    min_ano = min(min_ano, x.min())
    max_ano = max(max_ano, x.max())

    if len(x) > 3:
        x_smooth = np.linspace(x.min(), x.max(), 300)
        try:
            spline = make_interp_spline(x, y, k=3)
            y_smooth = spline(x_smooth)
            ax0.plot(x_smooth, y_smooth, label=fighter, color=colors[i])
            label_positions[fighter] = (x_smooth[-1], y_smooth[-1])
        except ValueError:
            ax0.plot(x, y, linestyle='-', label=fighter, color=colors[i])
            label_positions[fighter] = (x[-1], y[-1])
    else:
        ax0.plot(x, y, linestyle='-', label=fighter, color=colors[i])
        label_positions[fighter] = (x[-1], y[-1])

    ax0.scatter(x, y, color=colors[i], s=40)
    for xi, yi in zip(x, y):
        ax0.text(xi, yi + 10, f"{int(yi)}", fontsize=8, ha='center', color='black')

# Ajusta texto dos nomes com overlap
texts = []
for fighter, (x_label, y_label) in label_positions.items():
    texts.append(ax0.text(x_label + 0.2, y_label, fighter, fontsize=10, color='black'))

adjust_text(texts, ax=ax0)

ax0.set_xlim([min_ano, max_ano + 2])
ax0.set_ylim(bottom=1500, top=2500)
ax0.set_xlabel("Ano")
ax0.set_ylabel("Pontuação Elo (Máxima no Ano)")
ax0.set_title("Evolução Anual do Elo Máximo dos 10 Melhores Lutadores")
ax0.grid(True)

# === 4. Criar a tabela ===
ax1 = plt.subplot(gs[1])
ax1.axis('off')

column_labels = ['Lutador', 'Peak Elo', 'Elo em 2025', 'Variação %']
cell_data = []
color_map = []

for _, row in tabela_info.iterrows():
    peak = int(row['Peak Elo'])
    atual = int(row['Elo em 2025']) if isinstance(row['Elo em 2025'], (int, float)) else 'N/A'
    var_label = row['Variação']
    var_color = row['Cor']

    cell_data.append([row['Lutador'], peak, atual, var_label])
    color_map.append(var_color)

# Cria a tabela
tabela = ax1.table(
    cellText=cell_data,
    colLabels=column_labels,
    loc='center',
    cellLoc='center',
    colLoc='center'
)
tabela.auto_set_font_size(False)
tabela.set_fontsize(10)
tabela.scale(1, 1.5)

# Aplica a cor de fundo na coluna de variação
for i, color in enumerate(color_map, start=1):
    tabela[(i, 3)].set_facecolor(color)

# === 5. Mostrar tudo ===
plt.tight_layout()
plt.show()

# %%
# Define os lutadores a acompanhar
lutadores = ['gordon-ryan', 'nicholas-meregali']

# Armazena as tabelas de cada lutador
tabelas_max_ano = []

for lutador in lutadores:
    # Filtra lutas onde o lutador aparece
    lutas = df_fights[
        (df_fights['fighter'] == lutador) | (df_fights['opponent'] == lutador)
    ].copy().sort_values(by=['year', 'id_fight'])

    # Cria coluna com Elo pós-luta correto
    lutas['elo_post'] = lutas.apply(
        lambda row: row['fighter_elo_post'] if row['fighter'] == lutador else row['opponent_elo_post'],
        axis=1
    )

    # Filtra até 2025
    lutas = lutas[lutas['year'] <= 2025]

    # Agrupa por ano e pega o Elo máximo do ano
    max_por_ano = lutas.groupby('year')['elo_post'].max().reset_index()
    max_por_ano.columns = ['year', lutador]

    tabelas_max_ano.append(max_por_ano)

# Junta as duas tabelas em uma única com merge por ano
tabela_final = pd.merge(tabelas_max_ano[0], tabelas_max_ano[1], on='year', how='outer').sort_values(by='year')

tabela_final
# Out:
#    year  gordon-ryan  nicholas-meregali
# 0  2016       1832.0                NaN
# 1  2017       2133.0             1902.0
# 2  2018       2203.0             1997.0
# 3  2019       2339.0             2285.0
# 4  2020       2364.0             2218.0
# 5  2021       2377.0             2258.0
# 6  2022       2458.0             2370.0
# 7  2023       2460.0             2473.0
# 8  2024       2483.0             2485.0

# %%
fighters_to_compare = ['gordon-ryan', 'nicholas-meregali']
years_to_track = range(2014, 2026)  # 2014 até 2025

plt.figure(figsize=(15, 8))

for fighter in fighters_to_compare:
    fighter_data = df_fights[(df_fights['fighter'] == fighter) | (df_fights['opponent'] == fighter)]
    fighter_data = fighter_data.sort_values(by=['year', 'id_fight'])

    elo_values_by_year = {}
    for year in years_to_track:
        year_data = fighter_data[fighter_data['year'] == year]
        if not year_data.empty:
            last_elo_of_year = (
                year_data.iloc[-1]['fighter_elo_post']
                if year_data.iloc[-1]['fighter'] == fighter
                else year_data.iloc[-1]['opponent_elo_post']
            )
            elo_values_by_year[year] = last_elo_of_year
        else:
            elo_values_by_year[year] = elo_values_by_year.get(year - 1, 1500)

    years = list(elo_values_by_year.keys())
    elos = list(elo_values_by_year.values())

    # Linha com bolinhas
    plt.plot(years, elos, label=fighter, marker='o', linestyle='-')

    # Valor do Elo acima de cada ponto
    for x, y in zip(years, elos):
        plt.text(x, y + 10, f"{int(y)}", ha='center', fontsize=9)

plt.xlabel("Year")
plt.ylabel("Elo Rating")
plt.title("Top 1 vs. Top 2 - Elo Rating Trajectories (2014-2025)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Principais Resultados da Análise de Dados**
#
# **Cálculo da Pontuação Elo:** As pontuações Elo foram calculadas com sucesso para cada lutador com base nos resultados das lutas, utilizando um K-factor de 40.
#
# A coluna id_fight foi usada para garantir a ordem cronológica das lutas. Duas novas colunas (fighter_elo_post e opponent_elo_post) foram adicionadas ao DataFrame para armazenar as pontuações Elo pós-luta.
#
# **Top 10 Lutadores:** Os 10 melhores lutadores foram identificados com base na maior pontuação Elo alcançada em todas as lutas. Uma visualização mostra suas trajetórias de pontuação Elo ao longo do tempo. Nicholas Meragali teve a maior pontuação Elo (2485).
#
# **Distribuição do Elo:** A distribuição das pontuações finais Elo é positivamente assimétrica, com uma pontuação média em torno de 1500. A presença de outliers sugere que alguns lutadores têm pontuações significativamente mais altas ou mais baixas do que a maioria.
#
# **OBS:**
#
#
# **Refinar o Modelo Elo:** Experimentar com diferentes K-factors ou métodos de cálculo de pontuação Elo para ver se eles melhoram a precisão e o poder preditivo do modelo. Considerar incorporar classes de peso ou outros detalhes das lutas para rankings mais detalhados.

# %%
final_elo_df_sorted
# Out:
#                 Lutador  Elo Final
# 248         gordon-ryan       2483
# 292   nicholas-meregali       2445
# 501         erich-munis       2419
# 528       tainan-dalpra       2399
# 599        jansen-gomes       2389
# ...                 ...        ...
# 1664      oliver-geddes       1289
# 7013      marlon-tanaka       1288
# 5547     thiago-andrade       1285
# 790     wellington-dias       1236
# 4131    charles-mcguire       1182
#
# [11481 rows x 2 columns]

# %% [markdown]
# Calculando **brier score.**

# %%
def calcular_brier_score(df_fights, elo_ratings):
  """Calcula o Brier Score do sistema de ranking Elo.

  Args:
    df_fights: DataFrame contendo os dados das lutas.
    elo_ratings: Dicionário contendo os ratings Elo de todos os lutadores.

  Returns:
    O Brier Score do sistema de ranking Elo.
  """
  brier_score = 0
  total_lutas = 0

  for index, fight in df_fights.iterrows():
    fighter1 = fight['fighter']
    fighter2 = fight['opponent']
    resultado = fight['result']

    elo1 = elo_ratings[fighter1]
    elo2 = elo_ratings[fighter2]

    # Calcular a probabilidade de vitória do fighter1
    prob1 = 1 / (1 + 10**((elo2 - elo1) / 400))

    # Calcular a contribuição da luta para o Brier Score
    if resultado == 'W':
      brier_score += (1 - prob1)**2  # (Resultado real - probabilidade prevista)^2
    elif resultado == 'L':
      brier_score += (0 - prob1)**2
    else: # Empate
      brier_score += (0.5 - prob1)**2

    total_lutas += 1

  # Calcular o Brier Score médio
  brier_score /= total_lutas

  return brier_score

# Calcular e exibir o Brier Score
brier_score = calcular_brier_score(df_fights, elo_ratings)
print(f"Brier Score do sistema de ranking Elo: {brier_score}")
# Out:
# Brier Score do sistema de ranking Elo: 0.13976628793013118

# %% [markdown]
# ## Clusterização para separar em grupos distintos

# %%
# Extraia os ratings Elo finais
elo_data = final_elo_df_sorted[['Lutador', 'Elo Final']]

# Crie um novo DataFrame com os ratings Elo
X = elo_data[['Elo Final']]

# Define o intervalo de valores de K que vamos testar
K = range(1, 20)

# Inicializa o visualizador KElbowVisualizer
visualizer = KElbowVisualizer(KMeans(random_state=42), k=K)

# Ajusta o visualizador aos dados
visualizer.fit(X)

# Mostra o gráfico do método Elbow
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Aplicar o algoritmo KMeans com K=3
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_

# Adicionar os rótulos dos clusters ao DataFrame
elo_data['Cluster'] = labels

# Analisar os resultados
# Estatísticas descritivas
cluster_stats = elo_data.groupby('Cluster')['Elo Final'].describe()
print(cluster_stats)

plt.scatter(elo_data['Elo Final'], elo_data.index, c=elo_data['Cluster'], cmap='viridis')
plt.title('Clusters de Lutadores')
plt.xlabel('Elo Final')
plt.ylabel('Lutador')
plt.colorbar(label='Cluster') # Adiciona uma barra de cores
plt.show()
# Out:
#            count         mean         std     min     25%     50%     75%  \
# Cluster
# 0        10840.0  1483.976015   26.670926  1182.0  1479.0  1486.0  1493.0
# 1          154.0  2009.298701  137.350805  1853.0  1911.0  1966.5  2079.5
# 2          487.0  1695.581109   74.781417  1590.0  1630.0  1682.0  1753.5
#
#             max
# Cluster
# 0        1589.0
# 1        2483.0
# 2        1849.0

# %%
}# Padronizar nomes de colunas em elo_data
elo_data = elo_data.rename(columns={
    'Lutador': 'fighter',
    'Cluster': 'fighter_cluster'
})

# Agora fazer o merge com df_fights
df_fights = df_fights.merge(elo_data[['fighter', 'fighter_cluster']], on='fighter', how='left')

# %%
elo_data.to_csv('elo_data.csv', index=False)

# %%
# prompt: quantos lutadores sao cluster 0,1 e 2.

cluster_counts = elo_data['fighter_cluster'].value_counts().sort_index()
print("Número de lutadores por cluster:")
cluster_counts
# Out:
# Número de lutadores por cluster:
# Cluster
# 0    10840
# 1      154
# 2      487
# Name: count, dtype: int64

# %%
elo_data
# Out:
#                 fighter  Elo Final  fighter_cluster
# 248         gordon-ryan       2483                1
# 292   nicholas-meregali       2445                1
# 501         erich-munis       2419                1
# 528       tainan-dalpra       2399                1
# 599        jansen-gomes       2389                1
# ...                 ...        ...              ...
# 1664      oliver-geddes       1289                0
# 7013      marlon-tanaka       1288                0
# 5547     thiago-andrade       1285                0
# 790     wellington-dias       1236                0
# 4131    charles-mcguire       1182                0
#
# [11481 rows x 3 columns]

# %%
# prompt: faça a media do elo final de cada fighter_cluster 1,0 e 2, use a coluna Elo Final

# Faça a média do elo final para cada cluster
media_elo_por_cluster = elo_data.groupby('fighter_cluster')['Elo Final'].mean()

# Exiba a média do elo final para cada cluster
print("Média do Elo Final por Cluster:")
media_elo_por_cluster
# Out:
# Média do Elo Final por Cluster:
# fighter_cluster
# 0    1483.976015
# 1    2009.298701
# 2    1695.581109
# Name: Elo Final, dtype: float64

# %%
# Calcular número de lutas por atleta em cada cluster
lutas_por_atleta = df_fights.groupby(['fighter', 'fighter_cluster']).size().reset_index(name='n_lutas')
media_lutas_por_atleta = lutas_por_atleta.groupby('fighter_cluster')['n_lutas'].mean().reset_index()
media_lutas_por_atleta = media_lutas_por_atleta.rename(columns={'n_lutas': 'Número Médio de Lutas por Atleta'})
avg_opponent_elo_per_cluster = media_elo_por_cluster.reset_index()
avg_opponent_elo_per_cluster = avg_opponent_elo_per_cluster.rename(columns={'Elo Final': 'Nível Médio de Oponentes'})

# Calcular estatísticas por cluster
cluster_stats = df_fights.groupby('fighter_cluster').agg(
    win_rate=('result', lambda x: (x == 'W').mean()),  # % de vitórias
    sub_rate=('result', lambda x: (x == 'W').sum() / ((x != 'D').sum() if (x != 'D').sum() > 0 else 1))  # Finalizações por luta
).reset_index()

# Merge com média de lutas por atleta e ELO médio dos oponentes
cluster_stats = cluster_stats.merge(media_lutas_por_atleta, on='fighter_cluster')
cluster_stats = cluster_stats.merge(avg_opponent_elo_per_cluster, on='fighter_cluster')


# Renomear colunas
cluster_stats = cluster_stats.rename(columns={
    'win_rate': '% de Vitórias',
    'sub_rate': 'Finalizações por Luta'
})

# Converter para percentual
cluster_stats['% de Vitórias'] = (cluster_stats['% de Vitórias'] * 100).round(1)
cluster_stats['Finalizações por Luta'] = (cluster_stats['Finalizações por Luta'] * 100).round(1)

# Reorganizar colunas
cols_ordem = ['fighter_cluster', 'Número Médio de Lutas por Atleta', '% de Vitórias',
              'Nível Médio de Oponentes', 'Finalizações por Luta']
cluster_stats = cluster_stats[cols_ordem]

# Mostrar resultado
print(cluster_stats)
# Out:
#    fighter_cluster  Número Médio de Lutas por Atleta  % de Vitórias  \
# 0                0                         53.647399           55.1
# 1                1                        114.725490           79.3
# 2                2                         72.646766           68.7
#
#    Nível Médio de Oponentes  Finalizações por Luta
# 0               1483.976015                   55.5
# 1               2009.298701                   80.0
# 2               1695.581109                   69.4

# %%
cluster_stats.set_index('fighter_cluster').plot(kind='bar', figsize=(10, 6))
plt.title("Métricas por Cluster de Lutadores")
plt.ylabel("Valores")
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Renomear os clusters para melhor visualização
cluster_stats['fighter_cluster_name'] = cluster_stats['fighter_cluster'].astype(str).replace({
    '0': 'Cluster 0',
    '1': 'Cluster 1',
    '2': 'Cluster 2'
})

# Defina suas cores para cada cluster
color_map = {
    'Cluster 0': '#4c72b0',  # azul
    'Cluster 1': '#55a868',  # verde
    'Cluster 2': '#c44e52'   # vermelho
}

# Métricas a serem plotadas, incluindo o ELO Médio original
vars_to_plot = [
    'Número Médio de Lutas por Atleta',
    '% de Vitórias',
    'Nível Médio de Oponentes', # Mudado para a coluna
    'Finalizações por Luta'
]

fig, axes = plt.subplots(1, len(vars_to_plot), figsize=(4 * len(vars_to_plot), 5))

for ax, col in zip(axes, vars_to_plot):
    # Ordenar para garantir que as barras fiquem na ordem 0, 1, 2
    stats_sorted = cluster_stats.sort_values('fighter_cluster')
    clusters = stats_sorted['fighter_cluster_name']
    values = stats_sorted[col]

    # Para cada barra, escolhe a cor baseada no cluster
    colors = [color_map[c] for c in clusters]
    ax.bar(clusters, values, color=colors)
    ax.set_title(col)
    ax.set_xticklabels(clusters, rotation=0, ha='center')
    ax.set_xlabel('Cluster')
    ax.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-57-ee3ce242597e>:38: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# <ipython-input-57-ee3ce242597e>:38: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# <ipython-input-57-ee3ce242597e>:38: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# <ipython-input-57-ee3ce242597e>:38: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# ## Resultados e Discussão

# %% [markdown]
# O gráfico do histórico de **Peak Elo Holder** mostra a evolução anual da pontuação **ELO máxima dos 10 principais atletas do Jiu-Jitsu mundial**, permitindo visualizar tendências de ascensão, estabilidade e variações de desempenho ao longo dos anos.
#
# Podemos observar que nomes como **Nicholas Meregali e Gordon Ryan** atingiram patamares históricos de ELO, superando a marca de **2.480 pontos** em seus auges competitivos. O acompanhamento ano a ano mostra períodos de crescimento rápido, geralmente associados à chegada do atleta na elite do esporte ou a sequências invictas em grandes competições.
#
# A tabela ao lado destaca o "**Peak** Elo" (maior pontuação já atingida), o ELO em 2025 e a variação percentual em relação ao pico. É notável que atletas como **Erich Munis, Tainan Dalpra, Jansen Gomes e Adam Wardzinski** alcançaram seu ELO máximo no próprio ano de 2025, demonstrando que ainda estão em fase ascendente ou em seu melhor momento de carreira, o que é sinalizado com o marcador "**Peak**".
#
# Por outro lado, atletas como **Gabrieli Pessanha**, que perdeu para a Porfirio no Brasileiro, teve uma diminuição do elo pela diferença do mesmo entre as atletas. **Victor Hugo e Micael Galvão** apresentam queda percentual em relação ao seu melhor **ELO**, indicando possível fase de transição, redução no volume de competições ou alternância de resultados recentes. Essas variações negativas são destacadas na tabela em vermelho, chamando a atenção para períodos de oscilação ou desafios enfrentados na manutenção da performance máxima.
#
# Outro ponto importante é a presença de nomes consolidados, como **Marcus "Buchecha" Almeida,** que teve um desempenho tão grande, que mesmo após sua aposentadoria ainda marca o ranking.

# %% [markdown]
# ![Captura de tela_2-6-2025_14125_colab.research.google.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Gordon Ryan e Nicholas Meregali** — os dois principais nomes do Jiu-Jitsu competitivo na última década. A análise temporal entre** 2014 e 2025** evidencia não apenas o domínio de ambos, mas também o dinamismo da rivalidade e das fases distintas de ascensão e consolidação no topo.
#
# Gordon Ryan apresenta uma curva de evolução bastante acentuada a partir de **2015**, com um crescimento contínuo até alcançar a liderança absoluta do ranking de ELO. Seu ápice ocorre em **2023** e é mantido até **2025**, atingindo a pontuação máxima de **2483** pontos. A trajetória revela um domínio quase ininterrupto, marcado por grandes sequências de vitórias e desempenho estável, consolidando-o como referência máxima da modalidade no período.
#
# **Nicholas Meregali**, por sua vez, inicia sua ascensão mais tardiamente, ganhando ritmo a partir de 2017. Seu crescimento é notável, atingindo o pico de **2460** pontos em 2023, pouco atrás de **Gordon Ryan**, e se mantendo na faixa dos **2445** pontos até **2025**. Embora também tenha apresentado uma evolução impressionante, sua curva revela períodos de oscilação e um ligeiro distanciamento em relação ao líder do ranking.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Clusters:**
#
# A imagem abaixo apresenta a distribuição dos lutadores em relação ao seu ELO final, após a aplicação do algoritmo de clusterização K-means. É possível visualizar a separação clara em três grupos principais:
#
# **Cluster 0 (roxo)**: Atletas com ELO final mais baixo, predominando na faixa de 1300 a 1600 pontos. Representa o grupo com maior quantidade de lutadores, correspondendo ao perfil de praticantes iniciantes ou com histórico competitivo mais restrito.
#
# **Cluster 1 (amarelo**): Lutadores com ELO significativamente elevado, na faixa dos 2000 pontos ou mais, e que ocupam uma faixa bastante restrita do total de atletas. Este grupo concentra os grandes campeões e competidores de elite.
#
# **Cluster 2 (verde)**: Atletas intermediários, com ELO final entre aproximadamente 1600 e 2000 pontos. Esse grupo abrange lutadores experientes e competitivos, mas que ainda não atingiram o topo absoluto do ranking.
#
# A segmentação evidencia a pirâmide de competitividade típica de esportes de alto rendimento: muitos atletas na base e poucos nomes no topo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **A segunda imagem** mostra as principais métricas para cada cluster, permitindo comparar de forma objetiva o perfil de cada grupo:
#
# **Número Médio de Lutas por Atleta:**
# O **Cluster 1**, composto pelos atletas de elite, apresenta o maior volume médio de lutas **(114,7)**, refletindo experiência acumulada e presença constante em competições. O Cluster 0, por outro lado, tem a menor média **(53,6),** típica de atletas iniciantes ou menos ativos. O Cluster 2 aparece em posição intermediária, com média de 72,6 lutas
#
# **% de Vitórias:**
# A taxa de vitórias acompanha a hierarquia dos clusters. O grupo de elite tem uma impressionante média de 79,3% de vitórias, enquanto o grupo intermediário (Cluster 2) mantém 68,7% e o grupo iniciante apenas 55,1%.
#
# **Nível Médio de Oponentes:**
# O nível dos adversários enfrentados segue o padrão: atletas do Cluster 1 enfrentam, em média, oponentes com ELO em torno de 2009, demonstrando que não apenas vencem muito, mas também competem contra o mais alto nível. O Cluster 2 encara oponentes de nível intermediário (1695), enquanto o Cluster 0 enfrenta adversários em média de ELO 1483.
#
# **Finalizações por Luta:**
# A capacidade ofensiva dos atletas é refletida no número de finalizações por luta. O Cluster 1 apresenta, em média, 80 finalizações por atleta, bem acima dos demais grupos (Cluster 2: 69,4 e Cluster 0: 55,5), reforçando o domínio técnico dos lutadores de elite.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
